# %%
#importing necessary modules - pandas, nltk, regex, spacy, and RNG
import pandas as pd
import nltk
from nltk.tokenize import word_tokenize
from nltk.tag import pos_tag
import re
import random
import spacy
from spacy import displacy
from collections import Counter
import en_core_web_sm

nlp = en_core_web_sm.load()
nltk.download("punkt")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/adenweiser/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
# Setting up notebook to display multiple outputs in one cell
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
# Reading in and processing the gg2013 tweets file
tweets = pd.read_json('gg2013.json')

#takes in a tweet and removes the retweet and any hyperlinks
def clean_tweet(tweet_text):
    retweet_re = "^[rR][tT] @[a-zA-Z0-9_]*: "
    hyperlink_re = "http://[a-zA-Z0-9./-]*"
    return re.sub(retweet_re, "", re.sub(hyperlink_re, "", tweet_text))

#read in tweets and make them nice and clean
for i in range(0, len(tweets)):    
    tweets.at[i, 'text'] = clean_tweet(tweets.loc[i]['text'])
tweets

# Ceremony Name
ceremony_name = "Golden Globes 2013"
# Out:
#                                                      text  \
# 0                  JLo's dress! #eredcarpet #GoldenGlobes
# 1       What's making Sofia Vergara's boobs stay like ...
# 2       Kerry Washington is EVERYTHING. Dying over her...
# 3          Anne Hathaway has got me living. #GoldenGlobes
# 4       Jennifer Lopez's lace dress? Thoughts? #Golden...
# ...                                                   ...
# 174638  I was sad that Mandy Patinkin didn't win #Gold...
# 174639  Jennifer Lawrence aceptando su premio #GoldenG...
# 174640  Golden Globes, lots of fashion messes...but gl...
# 174641  Did they have mug shots at the golden globes?!...
# 174642  Says @BenAffleck: "I also didn't get the Actin...
#
#                                                      user                  id  \
# 0           {'screen_name': 'Dozaaa_xo', 'id': 557374298}  290620657987887104
# 1         {'screen_name': 'theAmberShow', 'id': 14648726}  290620657887219713
# 2             {'screen_name': 'SweetyPW', 'id': 35498686}  290620657828524032
# 3       {'screen_name': '_NicoleEdwards', 'id': 144430...  290620657799159809
# 4       {'screen_name': 'lolaogunnaike', 'id': 134953223}  290620657778188288
# ...                                                   ...                 ...
# 174638        {'screen_name': 'dana1204', 'id': 18091543}  290675889379876864
# 174639  {'screen_name': 'IamTrisEverdeen', 'id': 55126...  290675889128230914
# 174640   {'screen_name': 'Dpharmakis23', 'id': 852045842}  290675893024747523
# 174641  {'screen_name': 'reynaramirez22', 'id': 22732662}  290675888763314178
# 174642    {'screen_name': 'goldenglobes', 'id': 18667907}  290675893494484992
#
#               timestamp_ms
# 0      2013-01-14 00:45:38
# 1      2013-01-14 00:45:38
# 2      2013-01-14 00:45:38
# 3      2013-01-14 00:45:38
# 4      2013-01-14 00:45:38
# ...                    ...
# 174638 2013-01-14 04:25:07
# 174639 2013-01-14 04:25:07
# 174640 2013-01-14 04:25:08
# 174641 2013-01-14 04:25:08
# 174642 2013-01-14 04:25:08
#
# [174643 rows x 4 columns]

# %%
tweets_with_host = [] #list of strings containing the word "host", "hosts", or "hosting"
    
for i in range(0, len(tweets)):
    tweet_text = tweets.loc[i]['text']
    if re.search("host(s*)", tweet_text.lower()):
        tweets_with_host.append(tweet_text)
# Out:
# ['Looking forward to watching Tina Fey and Amy Poehler host the #GoldenGlobes',
#  "It's our hosts Tina Fey and Amy Poehler! #goldenglobes #redcarpet ",
#  "Tonight's dual hosting duties represent the culmination of a decade of Amy and Tina partnerships.  #GoldenGlobes",
#  'My green suede tuxedo pinching a bit here at the Velvet Rope Awards honoring best in crowd control. Topo Gigio + I hosting #GoldenGlobes',
#  'Tina Fey &amp; Amy Poehler Talk #GoldenGlobes Hosting, Drinking Game  ',
#  '@goldenglobes Best choice for host ever.  Nice job GG people.',
#  '“We’re going to keep things loose,” said Amy Poehler of her and co-host Tina Fey’s plan for the evening. #GoldenGlobes ',
#  '#GoldenGlobes hosts Tina Fey, Amy Poehler show off matching "husband and wife" outfits on red carpet ',
#  '#GoldenGlobes hosts Tina Fey, Amy Poehler show off matching "husband and wife" outfits on red carpet ',
#  "Tonight's dual hosting duties represent the culmination of a decade of Amy and Tina partnerships.  #GoldenGlobes",
#  '#PHOTO: Hosts Tina Fey and Amy Poehler arrive at the #GoldenGlobes ceremony, by Frederic J. Brown ',
#  "If the Red Carpet hosts asked one more woman what they're wearing i'm going to lose my mind #goldenglobes",
#  "Tonight's dual hosting duties represent the culmination of a decade of Amy and Tina partnerships.  #GoldenGlobes",
#  "It's our hosts Tina Fey and Amy Poehler! #goldenglobes #redcarpet ",
#  '#PHOTO: Hosts Tina Fey and Amy Poehler arrive at the #GoldenGlobes ceremony, by Frederic J. Brown ',
#  '#GoldenGlobes hosts Tina Fey, Amy Poehler show off matching "husband and wife" outfits on red carpet ',
#  'Like... Who cares about the relative viscosity of substances when Tina Fey and Amy Poehler are hosting the Golden Globes',
#  'Listen to "The Golden Globes and Red Carpet Fashion" hosted by Rolonda Watts on  #BlogTalkRadio  Designer Dalia MacPhee ',
#  'Excited for the #GoldenGlobes  Thinking Tina and Amy hosting should make for a fun evening!',
#  'Oh no, Jay Leno has just stolen hosting duties from Amy Poehler and Tina Fey. #GoldenGlobes',
#  "The only reason I'm going to watch #GoldenGlobes tonight is to see Tina and Amy host. Love those ladies!",
#  'Pop the champagne! Tina Fey and Amy Poehler host the #GoldenGlobes TONIGHT at 7ET/4PT!',
#  'The fact that Tina Fey and Amy Poehler are hosting the #GoldenGlobes &gt;&gt;&gt; #myfavoritewomen',
#  "Watching e's red carpet and with my eyes closed Kelly's cohost does not look how he sounds #goldenglobes",
#  'Tina Fey and Amy Poehler hosting #GoldenGlobes is a must see.  #GetGlue @goldenglobes',
#  "Looking forward to Tina Fey and Amy Poehler's hosting of the #GoldenGlobes",
#  "Tonight's 70th @GoldenGlobes are the first ones hosted by a woman or women alone. And Tina &amp; Amy are going to ROCK it. ",
#  "That black streak in Jay Leno's hair is from the one time he saw the ghost dick under his belly, right? #GoldenGlobes",
#  'take mc today &gt;&gt;&gt;&gt;&gt; get to roll in bed with tina fey and amy poehler hosting golden globes. SO WORTH IT',
#  'Tina Fey and Amy Poehler are hosting the Golden Globes? Yes. \ue106\ue106\ue106',
#  'Super excited for Tina Fey and Amy Pohler to host the #goldenglobes !!',
#  'The fact that Tina Fey AND Amy Poehler are teaming up as host for The Golden Globes tonight&gt;&gt;&gt;&gt;&gt;&gt;&gt;&gt;&gt;&gt;&gt;',
#  '2013 Golden Globes live: Tina Fey and Amy Poehler host Hollywood elite ',
#  'Host AND nominee?! We can’t wait to see Tina Fey at the #GoldenGlobes tonight! Join @NBC as we live tweet the entire event.',
#  't-5 min until @hurricanejac and I make our hosting debut for the Golden Globes',
#  "Tina Fey + Amy Poehler hosting the Golden Globes. You've got my attention. (@ Ingersoll Square Lofts) ",
#  '#SGS 2013 Golden Globes live: Tina Fey and Amy Poehler host Hollywood elite: Hollywood Foreign Press Association... ',
#  '2013 Golden Globes live: Tina Fey and Amy Poehler host Hollywood elite: Hollywood Foreign Press Association have... ',
#  '2013 Golden Globes live: Tina Fey and Amy Poehler host Hollywood elite: Hollywood Foreign Press Association have... ',
#  'The Golden Globes Red Carpet countdown is hosts by the anchors for the Today Show. So cost cutting? Ryan Seacrest have too much swag now?',
#  'In 1985, Ghostbusters was nominated for three Golden Globes. We won none. Unforgivable.',
#  'Excited to watch Amy and Tina host tonight #GoldenGlobes',
#  'So excited that the two funniest women on the planet are hosting the #goldenglobes!!! #tinafey #amypoehler 🎥',
#  'Watching the #GoldenGlobes for the simple fact that Amy Poehler is hosting. #topnotchcomedy',
#  "@robsalem So who's looking forward to Amy Poehler and Tina Fey as hosts? #GoldenGlobes",
#  'Moved my desktop computer into the only room with cable in the building so I can live blog my two ladies hosting the Golden Globes.',
#  'so excited for tina &amp; amy! the oscars are my main jam, but this hosting duo has me very hopeful!!  #goldenglobes',
#  '@SPANXinc they could be one of the best hostesses ever #SpanxRedCarpet #GoldenGlobes',
#  '#goldenglobes looking forward to Tina and Amy hosting!! 😂😆',
#  'What an awesome weekend of #NFLPlayoffs!!  Now time to watch my heroes, #TinaFey and #AmyPoehler host the #GoldenGlobes!!',
#  "Let's hope the #GoldenGlobes don't bury Tina/Amy tonight. They have two brilliant comedians/writers/actresses hosting. USE THEM.",
#  "Tonight's Golden Globes will be hosted Tina Fey and Amy Poehler. Full nominations here:  ",
#  'Tune in: Live Chat: Golden Globes 2013: From the red carpet to the hosts to the show -  ”',
#  "i am just too excited for this. if there are two women who should be hosting the golden globes, it's tiny fey and amy poehler #gonnabegood",
#  'OM #GoldenGlobes watch the #FashionSquad host a trunk show from the back of a @VW Jetta in this fab YouTube VIDEO: ',
#  'My #GoldenGlobes predictions: People will agree or disagree with the choices. The hosts will be above or below expectations.',
#  'Tina Fey &amp; Amy Poehler are hosting the #GoldenGlobes tonight and are going to destroy.',
#  'The #GoldenGlobes are starting! Who do you think will give the audience more chuckles as a host: #AmyPoehler or #TinaFey? Let us know!',
#  'Super-excited for @NotTinaFey and Amy Poehler hosting the #goldenglobes!!',
#  'Actually excited for the Golden Globes this year because Tine Fey and Amy Poehler are hosting. :D I love them. #SecondCity',
#  'tina fey and amy pohler are hosting the golden globes?! MY ENTERTAINMENT FOR THE NIGHT',
#  'Only my two heroes hosting the Golden Globes at the same time right now, whatever.',
#  "Got my wine, so I'm settled in to watch Tina Fey and Amy Poehler host the #GoldenGlobes",
#  'I actually do give a shit about the golden globes this year only because of the hosts.',
#  'No puede haber mejor host para los golden globes que tina fey!',
#  'So excited to see Amy Poehler host the Golden Globes tonight',
#  'Golden Globes hosted by my comedic idols',
#  'So excited for @amypoehler and @NotTinaFey to host the Golden Globes!!! Best. Duo. Ever. #GoldenGlobes',
#  "#TheHeat worships funny women, so we can't wait to see Amy Poehler and Tina Fey host the #GoldenGlobes. Kill it, ladies! #amyandtinarock!",
#  'So happy that Tina &amp; Amy are hosting! #GoldenGlobes',
#  "I enjoyed Giuliana Rancic's work better when she hosted Tales from the Crypt. #GoldenGlobes",
#  'Whats going on? I thought honey booboo was hosting. ( warm up joke. Doesnt count. Its like shadow boxing). #GoldenGlobes',
#  'About to watch these Golden Globes&gt;&gt;&gt; Just for the hosts:D',
#  "It's on! #GoldenGlobes time! Can't wait to see hosts Tina Fey and Amy Poehler kill it.",
#  'Golden Globes are starting. Best hosts possible. #ilovetinafey #iloveamypoehler',
#  'Hosts Tina Fey &amp; Amy Poehler take the stage. 70th annual #GoldenGlobes starting now! ',
#  'There was honestly no better decision made than choosing these two to host. #GoldenGlobes',
#  "Is Glenn Close's hair made of ghosts? #GoldenGlobes",
#  'Amy Poehler and Tina Fey hosting the #GoldenGlobes! perfection!',
#  'Me encantan las hosts de los #GoldenGlobes Tina Fey y Amy Polher',
#  'Best hosts ever! #GoldenGlobes',
#  'Only my two heroes hosting the Golden Globes at the same time right now, whatever.',
#  'This is gonna be a funny golden globes with these two hosts',
#  'Watching the Golden Globes because Tina Fey and Amy Poehler are hosting.',
#  'Tina and Amy co-hosting is a glimpse into what my personal heaven will be like. #GoldenGlobes',
#  'I am so excited for them to host :3 #GoldenGlobes',
#  'Whats going on? I thought honey booboo was hosting. ( warm up joke. Doesnt count. Its like shadow boxing). #GoldenGlobes',
#  'Tina &amp; Amy hosting the golden globes is going to be hilarious 😢',
#  'OMG Miss Norberry is hosting The Golden Globes! That is so fetch!',
#  'No pudieron escoger a mejores hosts que Tina y Amy. Son unos genios los de los Golden Globes.',
#  'Tina Fey and Amy Poehler hosting the Golden Globes is genius.',
#  'Love how the hosts are talking and you hear the TV crew counting them out. #GoldenGlobes',
#  "The #GoldenGlobes hasn't even started yet and I'm already wishing @toddbarry was hosting, not these #lesbians",
#  "Love Tina Fey's dress! &amp; I love that her &amp; Amy Poehler are hosting. #goldenglobes",
#  'Love NBC for picking these wonderful people to host. #GoldenGlobes',
#  '#goldenglobes liking the dresses of the hosts!',
#  'Love that Tina and Amy are hosting #GoldenGlobes #amazing',
#  'Tina Fey &amp; Amy Poehler host the 70th Annual #GoldenGlobes! Starting now! Tweet us your favorite moments of the show!',
#  'Why are the Little Mermaid and Princess Jasmine hosting the Golden Globes?',
#  'So happy Tina Fey and Amy Poehler are hosting the Golden Globes! Love them',
#  '#ACC Represent at the #GoldenGlobes with Tina Fey @UVA grad and Amy Poehler - @BostonCollege grad co-hosting',
#  'Sickest fucking host duo #comedicgold #goldenglobes',
#  'My two girl crushes hosting!  #GetGlue @goldenglobes',
#  "Tina Fey's hosting? Sweet! #goldenglobes #whynot",
#  'Whats going on? I thought honey booboo was hosting. ( warm up joke. Doesnt count. Its like shadow boxing). #GoldenGlobes',
#  'OMG Tina &amp; Amy are absolutely stunning hosts!!! #GoldenGlobes',
#  'Tina &amp; Amy hosting. The actors better watch out for the jokes :D #GoldenGlobes',
#  'Love that two smart and funny women are hosting the #GoldenGlobes! Well done TV and film!!!',
#  'Great 2 women are hosting the #GoldenGlobes *turns off TV*',
#  'Whats going on? I thought honey booboo was hosting. ( warm up joke. Doesnt count. Its like shadow boxing). #GoldenGlobes',
#  '2 hot chicas hosting the #goldenglobes. #girlpower!',
#  'I know the #GoldenGlobes are going To be fantastic by the fact that Tina fey and Amy poehler are hosting 😂',
#  'Whats going on? I thought honey booboo was hosting. ( warm up joke. Doesnt count. Its like shadow boxing). #GoldenGlobes',
#  'Hosts Tina Fey and Amy Poehler have graciously provided a Golden Globes drinking game. Bottoms up! | ',
#  "First and only Golden Globes where I don't care about reaction shots. Just keep showing me the hosts.",
#  'Amy Poehler -- Parks &amp; RACK!: "Park and Recreation" funny lady Amy Poehler arrived to the Golden Globes with her two lovely hosting s...',
#  'Super stoked for Tina Fey and Amy Poeler hosting the Golden Globes. Love them.',
#  'Ahh, I love Tina Fey and Amy Poehler! They could not of chosen a better pair to host The Golden Globes',
#  'Watching the Golden Globes hosted by Amy Pholer &amp; Tiny Fay',
#  'Having Tina Fey and Amy Poehler host the golden globes has to be the greatest choice ever',
#  'Tina fey and Amy poehler hosting the golden globes...ummm yes',
#  'Tina and Amy hostin golden globes ahhhhh let the humor begin',
#  'RT @TIME: Hosts Tina Fey and Amy Poehler have graciously provided a Golden Globes drinking game. Bottoms up! | ',
#  'omg tina fey and amy poehler hosting the golden globes &gt;&gt;&gt; #lovethem',
#  "Lololol look who's hosting the golden globes @megan_lindley @robynanne24 HERE COMES YO BABY MOMMAAAA",
#  'How come Tina Fey decided to look like a tranny hooker to host the golden globes?',
#  'I love watching the Golden Globes especially cause Tina and Amy are hosting omg\ue106\ue106',
#  'Ready for Tina and Amy to be hilarious hosts at the Golden Globes. its gunna be great',
#  'Was gonna watch The Golden Globes until I realized Tina Fey &amp; Any Poehler are hosting. They are NOT funny.',
#  'Tina Fey and Amy Poehler hosting the Golden Globes #gold',
#  'I love how they have the two funniest women in the world hosting the Golden Globes #smart',
#  'Tina and Amy are host perfection :) #GoldenGlobes',
#  'Whats going on? I thought honey booboo was hosting. ( warm up joke. Doesnt count. Its like shadow boxing). #GoldenGlobes',
#  'Jamas me ah gustado tina fey!, como la ponen de host? WTF #GoldenGlobes',
#  'Bill Murray is looking OOOOLD.  They better hurry and make that Ghostbusters movie before they have to cast him as a ghost #GoldenGlobes',
#  'So stoked Tina and Amy are hosting the #goldenglobes',
#  'I am so excited my heroes Tina Fey &amp; Amy Poehler are hosting the Golden Globes tonight. I truly adore them.',
#  '@Bama_Bitches our girls are hosting the golden globes!',
#  'Nothing like a real news team hosting the Golden Globes pre-game show - oh, sorry, that was the "Today" show team #NBCNews #WatchTheMedia',
#  '"When you run afoul of the Hollywood Foreign Press, they make you host this show two more times." #GoldenGlobes',
#  "The hosts of the #GoldenGlobes: Tina Fey (#Taurus) and Amy Poehler (#Virgo) -- They're very compatible, so expect a good show!",
#  'Tina Fey &amp; Amy Poehler host the 70th Annual #GoldenGlobes😌',
#  'This is a fantastic duo to be hosting the #goldenglobes',
#  "Amy Poehler and Tina Fey you both better be fucking good hosts because I'm watching this garbage #GoldenGlobes",
#  "Tonight's dual hosting duties represent the culmination of a decade of Amy and Tina partnerships.  #GoldenGlobes",
#  'Whats going on? I thought honey booboo was hosting. ( warm up joke. Doesnt count. Its like shadow boxing). #GoldenGlobes',
#  "We're watching the Globes for no particular reason other than we love the two hosts. #goldenglobes",
#  'hahahaha i love amy and tina hosting #goldenglobes',
#  'Hey, can we add on another sip for every host outfit change? #GoldenGlobes',
#  'Sign them up for more hosting!  Amy and Tina rock! #goldenglobes',
#  'just finished all of my homework, now watching the #goldenglobes. #amypoehler and #tinafey hosting. This should be epic.',
#  'Tina Faye and Amy polar hosting The golden globes 😂👍',
#  "the only reason I'm even watching the golden globes is because amy poehler and tina fey are hosting it",
#  'The fact that Amy Poehler and Tina Fey are hosting the golden globes #thisshouldbegood 😂😂',
#  'Seeing the golden globes and both hosts suck',
#  'Hosts Tina Fey and Amy Poehler have graciously provided a Golden Globes drinking game. Bottoms up! | ',
#  'Thank you #GoldenGlobes for giving up Tina Fey and Amy Poehler as hosts',
#  'Amy Poehler and Tina Fey are flawless hosts. #GoldenGlobes',
#  '“As we learned from Ricky Gervais, when you run afoul with the H.F.P.A., they ask you to host the #GoldenGlobes two more times.” Amy Poehler',
#  "I've never been more excited to watch anyone host an award show. Except every time @ActuallyNPH hosts The Tonys. #GoldenGlobes",
#  '“As we learned from Ricky Gervais, when you run afoul with the H.F.P.A., they ask you to host the #GoldenGlobes two more times.” Amy Poehler',
#  'Can we start a petition to have Poehler &amp; Fey host the Oscars too? #GoldenGlobes',
#  'Knew Amy was gonna say something snappy. LOL #GoldenGlobes #hosts',
#  'Perfect duo to host - always wickedly entertaining #goldenglobes',
#  'This is already brilliant. Amy &amp; Tina should host EVERYTHING! #goldenglobes',
#  'Tina Fey &amp; Amy Poehler look fabulous and are doing an awesome job hosting #GoldenGlobes!!!',
#  'Come ON, UK, why is there no channel showing Tina Fey&amp;Amy Poehler hosting #GoldenGlobes?? #frustrating',
#  "From watching football to watching the @goldenglobes.  With Tina Fey and Amy Poehler hosting, it's going to be hilarious!",
#  'Love seeing two strong, beautiful women hosting the #GoldenGlobes this year.',
#  'Tina Fey and Amy Poehler have kicked things off. What do you think of the hosts so far?  #GoldenGlobes',
#  "I like Tina Fey RT @goldenglobes: It's our hosts Tina Fey and Amy Poehler! #goldenglobes #redcarpet ",
#  'Tina Fey &amp; Amy Poehler 👭💘 #besthosts #GoldenGlobes ',
#  'So Tina and Amy are hosting every year right? #goldenglobes',
#  'Best. Hosts. Ever. #Fey #Poehler #goldenglobes',
#  'Best hosts ever. #GoldenGlobes',
#  'Amy Poehler and Tina fey, basically my two idols, hosting the Golden Globes, what could be better?',
#  'Can these two host every year, please! #GoldenGlobes',
#  'Tina Fey &amp; Amy Poehler Talk Golden Globes Hosting, Drinking Game: Tina Fey and Amy Poehler will co-host the Gold... ',
#  'Love seeing two strong, beautiful women hosting the #GoldenGlobes this year.',
#  'Amy and Tina hosting &gt;&gt;&gt; #GoldenGlobes',
#  'Amy and Tina hosting the #GoldenGlobes is a dream come true',
#  "It's time for the #GoldenGlobes! Are you watching hosts @TinaFey123 and Amy Poehler? #FunnyGals @goldenglobes",
#  'Wow, Oscar host joke on Hathaway and Franko!! Holy shit! #goldenglobes',
#  'Tina Fey &amp; Amy Pohler are killing it! Perfect host choice! #GoldenGlobes #FaveAwardShow',
#  'Best hosts EVER!!! #GoldenGlobes',
#  'Tina &amp; Amy to host everything, ever, please. #GoldenGlobes',
#  'Omg, loving these hosts. Major ranking going on rn. #GoldenGlobes',
#  "Let's have Amy and Tina host every awards show, every year. They are killing it! #goldenglobes",
#  'These ladies will never host again. And it is 100% worth it. #GoldenGlobes',
#  '#GoldenGlobes only watching because of the hosts! #LoveEm',
#  'Amy &amp; Tina are making everyone laugh they are the best hosts for the #goldenglobes. :)',
#  'Amy and Tina have just earned their repeat invite to co-host the #GoldenGlobes again. After less than five minutes!',
#  'Is Tina Fey hosting the #GoldenGlobes in a Little Mermaid costume?',
#  'Um, best award show hosts ever? Thank god for Tina and Amy. Thank god! #goldenglobes',
#  "Tina Fey and Amy Poehler are friggin' killing it hosting the Golden Globes. xD #SNL #GoldenGlobes @SaintParis",
#  'Tina Fey and Amy Pohler are absolutely hilarious. great choices for hosts #GoldenGlobes',
#  '2x lady hosts at the #goldenglobes, best life choice ever.',
#  'I just love how much FUN they are having hosting this show! This is how it should be. #GoldenGlobes',
#  '@District_Court and I are hosting the Golden Globes! We are so witty and pretty :)',
#  'Tina Fey and amy pohler are hilarious hosting the golden globes!',
#  'Tina Fey and Amy Poehler have kicked things off. What do you think of the hosts so far?  ',
#  'these lame ass jokes from these lame ass hosts on the golden globes &lt;&lt;&lt;&lt;&lt;',
#  'Tina Fey &amp; Amy Poehler hosting The Golden Globes? #Perfect',
#  'Amy poehler and Tina fey hosting the golden globes😂😂😂😂😂😭😭😭😂😭😭😭😂😭😭😭😂😂😂',
#  'So this is how it is when super funny people host in a non self-congratulatory way. #goldenglobes',
#  'Now these are hosts! #goldenglobes',
#  'The girls of Weekend Update are always amazing. Great hosting so far haha #GoldenGlobes',
#  'Tina and Amy are already killing it. Please host everything. #GoldenGlobes',
#  'see what happens when you let actual funny people host award shows, Hollywood? #GoldenGlobes',
#  'So this is how it is when super funny people host in a non self-congratulatory way. #goldenglobes',
#  'Oh yes, they made a great decision to have Tina and Amy host. #GoldenGlobes',
#  'Tina Fey and Amy Poehler are killing it tonight as the hosts of the #GoldenGlobes ! Hiiiilaaaaaarious!',
#  'So this is how it is when super funny people host in a non self-congratulatory way. #goldenglobes',
#  'I love Amy and Tina hosting. #GoldenGlobes',
#  'This host combination is quite literally my favorite thing in the world #goldenglobes',
#  '"I have not seen someone so alone and abandoned in a performance since you hosted the Oscars with James Franco." DYING. #GoldenGlobes',
#  'I love Amy poeler and Tina fey as hosts! Love love love!!!! #goldenglobes',
#  'I love Tina and Amy hosting together. I love them highfiving each other when they nail a joke. Which is often. #goldenglobes',
#  "I'm in love with this awards show already. Let Queen Amy and Queen Tina host ALL the awards shows. #GoldenGlobes",
#  'The #goldenglobes ... Hosted by #bridesmaids',
#  'I want Tina Fey and Amy Poehler to host my life. #goldenglobes',
#  'Onlyy a few minutes in but the #goldenglobes have the best funniest host ever!',
#  'Tina Fey and Amy Poehler are already the best hosts from the #GoldenGlobes',
#  "It's hard not to love Tina Fey and Amy Poehler as hosts so far #GoldenGlobes. I liked the corny Hunger Games/Lif of Pi joke",
#  'Loving these two. Great choice for hosts! #goldenglobes',
#  'They could not have picked a more perfect hosting pair #GoldenGlobes',
#  '“As we learned from Ricky Gervais, when you run afoul with the H.F.P.A., they ask you to host the #GoldenGlobes two more times.” Amy Poehler',
#  "#TinaFey looks fabulous hosting the #GoldenGlobes in her teal green dress!  She's workin her curves!",
#  'Can Amy and Tina host the #GoldenGlobes every year? This is comedy gold!',
#  'god bless the person who decided Tina &amp; Amy would be hosts #goldenglobes',
#  'Tina Fey &amp; Amy Poehler best award hosts #GoldenGlobes',
#  'Love these ladies! So nice to see strong, funny, smart women hosting. #goldenglobes',
#  'Give a Golden Globe to whoever decided to let these two host. #goldenglobes',
#  'They should have paid Tina and Amy the budget of The Hobbit to host the #Oscars.  #KILLING IT #GoldenGlobes',
#  "It's #awards season again! SO excited to watch #TinaFey and #AmyPoehler host the #GoldenGlobes!",
#  'Tina Fey and Amy Poehler should host everything ever, for all time. #goldenglobes',
#  'The 70th annual #goldenglobes, hosted by @amypoehler and @TinaFey123, are underway.',
#  'Tina and Amy are perfection, best hosts that I can recall! #GoldenGlobes',
#  "I think we've found the best hosts ever! #GoldenGlobes",
#  'Amy &amp; Tina = the best hosts ever! #GoldenGlobes',
#  'Love the hosts! #GoldenGlobes',
#  'Love the hosts #GoldenGlobes',
#  'Omg I love that Amy Pohler and Tina Fey are hosting the #GoldenGlobes #toofunny',
#  "5 minutes in and I'm ready to call it: Best. Hosts. Ever. #GoldenGlobes",
#  'Tina and Amy are great hosts! This is hysterical #goldenglobes',
#  "It's time for the #GoldenGlobes! Are you watching hosts @TinaFey123 and Amy Poehler? #FunnyGals @goldenglobes",
#  'Tina and Amy should host the GG EVERY YEAR. EVERY. YEAR. DO YOU HEAR ME? #GoldenGlobes',
#  "Amy Poehler and Tina Fey are every bit as flawless as I knew they'd be. They will be hosting everything ever from now on, yes? #GoldenGlobes",
#  'Amy and Tina cohosting the #GoldenGlobes reminds me of when #SNL was funny.',
#  "Let's just let these two host everything. #GoldenGlobes",
#  'FLAWLESS hosting - as expected! #goldenglobes',
#  'So this is how it is when super funny people host in a non self-congratulatory way. #goldenglobes',
#  'So this is how it is when super funny people host in a non self-congratulatory way. #goldenglobes',
#  'Damn it these two ladies are killing it tonight hosting. James Cameron torture joke by far the best. #GoldenGlobes',
#  'You see? Funny, genuinely charming people hosting? You see how this works, @TheAcademy? It works, EXCELLENTLY. #GoldenGlobes',
#  'Co-hosts Tina Fey and Amy Poehler are killing it in their opening monologue so far. #GoldenGlobes',
#  '"I have never seen someone so lost and abandoned since you hosted the Oscars with James Franco." True life, Tina. True life. #GoldenGlobes',
#  'love that Amy Poehler and Tina Fey are the hosts of the Golden Globes. laughing my ass off since the first second ...',
#  "Tina Fey &amp; Amy Poehler hosting the Golden Globes is so perfect I can't.",
#  'I love that @NotTinaFey  &amp; @AmyPoehler are hosting the Golden Globes!',
#  'Amy Pohler hosting the Golden Globes right now &gt;&gt;&gt;&gt; #tofunny',
#  'NW The Golden Globes...they are great hosts lol',
#  "Amy Poehler and Tina Fey are KILLLLLLING this Golden Globes hosting. I'm crying laughing.",
#  "Couldn't have picked better hosts for the golden globes !",
#  'Amy Poehler and Tina Fey are cracking me up right now! 😂😂\n#GoldenGlobes \nBest hosts the golden globes have had in a while!!',
#  "I'm presenting at the Golden Globes tonight. The lovely and hilarious Amy Poehler and Tina Fey are hosting. You should watch!",
#  'I may or may not be watching the Golden Globes just because Tina and Amy are hosting...',
#  'Tina Fey and Amy Poehler are killing it as co-host of the Golden Globes',
#  'Omg Amy Poehler and Tina Fay are the best hosts ever! #goldenglobes',
#  'Can Tina Fey &amp; Amy Poehler host my life?? #goldenglobes',
#  '"Quentin Tarantino is here, the star of all my sexual nightmares!" - Tina Fey. Ok, can we just call it now: Best. Hosts. Ever. #GoldenGlobes',
#  'Tina and Amy are killing it! They need to host every year!  #GetGlue @goldenglobes',
#  '"Quentin Tarantino is here, the star of all my sexual nightmares!" - Tina Fey. Ok, can we just call it now: Best. Hosts. Ever. #GoldenGlobes',
#  "Amy Poehler and Tina Fey are every bit as flawless as I knew they'd be. They will be hosting everything ever from now on, yes? #GoldenGlobes",
#  'Tina Fey and Amy Poehler are the perfect #GoldenGlobes hosts.',
#  'Amy Poehler and Tina Fey should host all the time #GoldenGlobes',
#  'I am fuckin impressed with yo hostin ladies #goldenglobes',
#  "SNL is showing everyone how to host a show.  go get 'em girls. #goldenglobes",
#  "Amy Poehler &amp; Tina Fey have me laughing soooo hard! They're hilarious hosting this show!!! #GoldenGlobes",
#  'Tina Fey and Amy Poehler are doing an awesome job hosting the globes this year, I love them together! #funnywomen #goldenglobes',
#  '"Quentin Tarantino is here, the star of all my sexual nightmares!" - Tina Fey. Ok, can we just call it now: Best. Hosts. Ever. #GoldenGlobes',
#  '"Quentin Tarantino is here, the star of all my sexual nightmares!" - Tina Fey. Ok, can we just call it now: Best. Hosts. Ever. #GoldenGlobes',
#  '"Quentin Tarantino is here, the star of all my sexual nightmares!" - Tina Fey. Ok, can we just call it now: Best. Hosts. Ever. #GoldenGlobes',
#  '@fiddlecub I only cared about the #GoldenGlobes when it was hosted by @rickygervais',
#  "We know it's early, but we're gonna call it now: Tina Fey and Amy Poehler get rave reviews for her #goldenglobes hosting gig. #hysterical",
#  '"Quentin Tarantino is here, the star of all my sexual nightmares!" - Tina Fey. Ok, can we just call it now: Best. Hosts. Ever. #GoldenGlobes',
#  'Why do I feel like Tina and Amy are acting just like Kate and Angie would if they hosted #babymama #GoldenGlobes',
#  'RT @OfficiallyAnty LMFAO they are killing this hosting gig! #goldenglobes',
#  '"Quentin Tarantino is here, the star of all my sexual nightmares!" - Tina Fey. Ok, can we just call it now: Best. Hosts. Ever. #GoldenGlobes',
#  '"Quentin Tarantino is here, the star of all my sexual nightmares!" - Tina Fey. Ok, can we just call it now: Best. Hosts. Ever. #GoldenGlobes',
#  'Amy and Tina should host everything always and forever. #GoldenGlobes',
#  "Omg stop. I haven't laughed this much in forever. Why haven't they ever hosted a show before??? #amypoehler #tinafey #GoldenGlobes",
#  'tina fey and amy poehler hosting the golden globes &gt;&gt;&gt;&gt;&gt;',
#  'These are probably the best hosts the Golden Globes have ever had.',
#  'Tina Fey &amp; Amy Poehler....really good pairing to host the Golden Globes. Funny ladies.',
#  'Love that these hilarious ladies are hosting the golden globes',
#  "They couldn't have picked better people to host the golden globes.",
#  "Tina Fey and Amy Poehler hosting the Golden Globes. It's a wonderful night.",
#  'Tina and Amy hosting the Golden Globes &gt;&gt;',
#  '"Quentin Tarantino is here, the star of all my sexual nightmares!" - Tina Fey. Ok, can we just call it now: Best. Hosts. Ever. #GoldenGlobes',
#  'Lol. Love Tina &amp; Amy as hosts. #GoldenGlobes',
#  '"Quentin Tarantino is here, the star of all my sexual nightmares!" - Tina Fey. Ok, can we just call it now: Best. Hosts. Ever. #GoldenGlobes',
#  'Tina and Amy should host the GG EVERY YEAR. EVERY. YEAR. DO YOU HEAR ME? #GoldenGlobes',
#  'Tina Fey and Amy Poehler killing it as #GoldenGlobes hosts! Boss Ladies!',
#  "Fact: It's a great year for women in film, according to the @GoldenGlobes hosts Amy Poehler and Tina Fey #GoldenGlobes",
#  'Can Tina and Amy host EVERY award show from now on. @GoldenGlobes',
#  "It's time for the #GoldenGlobes! Are you watching hosts @TinaFey123 and Amy Poehler? #FunnyGals @goldenglobes",
#  'Fey and Poehler are killing it. Best award hosts. #GoldenGlobes',
#  '"Quentin Tarantino is here, the star of all my sexual nightmares!" - Tina Fey. Ok, can we just call it now: Best. Hosts. Ever. #GoldenGlobes',
#  'Amy and Tina are killing it as hosts right now!! #goldenglobes',
#  'They keep hiring funny people to host, which proves the #goldenglobes knows jack shit about awards shows.',
#  '"Quentin Tarantino is here, the star of all my sexual nightmares!" - Tina Fey. Ok, can we just call it now: Best. Hosts. Ever. #GoldenGlobes',
#  '"Quentin Tarantino is here, the star of all my sexual nightmares!" - Tina Fey. Ok, can we just call it now: Best. Hosts. Ever. #GoldenGlobes',
#  '“@angegeee: Loving Tina and Amy as hosts!” - yes!!!!! #GoldenGlobes',
#  'Ok Tina Fey y Amy Poehler deberian hostear todos los premios !! #GoldenGlobes',
#  'Love seeing two strong, beautiful women hosting the #GoldenGlobes this year.',
#  "The hosts of the #GoldenGlobes: Tina Fey (#Taurus) and Amy Poehler (#Virgo) -- They're very compatible, so expect a good show!",
#  '"Quentin Tarantino is here, the star of all my sexual nightmares!" - Tina Fey. Ok, can we just call it now: Best. Hosts. Ever. #GoldenGlobes',
#  '"Quentin Tarantino is here, the star of all my sexual nightmares!" - Tina Fey. Ok, can we just call it now: Best. Hosts. Ever. #GoldenGlobes',
#  'So this is how it is when super funny people host in a non self-congratulatory way. #goldenglobes',
#  "If Tina Fey and Amy Poehler hosted every awards show from now until forever, I'd be a happy lady. #GoldenGlobes",
#  'These ladies should host everything. #goldenglobes',
#  'Tina Fey &amp; Amy Poehler are killing it at the #GoldenGlobes . Great pick for hosts!',
#  'Probably the best hosts ever #GoldenGlobes',
#  'Tina and Amy should host everything. #goldenglobes',
#  'Tina Fey &amp; Amy Poehler are HYSTERICAL! Dynamic Duo! #GoldenGlobes #hosts #comedy',
#  'Tina Fey and Amy Poehler hosting the #GoldenGlobes together? Best idea ever!',
#  '"Quentin Tarantino is here, the star of all my sexual nightmares!" - Tina Fey. Ok, can we just call it now: Best. Hosts. Ever. #GoldenGlobes',
#  '“@BellaMarci: LOVE Tina and Amy hosting #GoldenGlobes !! Hilarious!! 👏👍😝🎥📺” no their not...👎👎',
#  '. @goldenglobes - great choice of hosts! #TinaFey &amp; #AmyPoehler Rock!\n#GoldenGlobes',
#  "Can they host every year? I can't even handle how hilarious they are. #GoldenGlobes",
#  '"Quentin Tarantino is here, the star of all my sexual nightmares!" - Tina Fey. Ok, can we just call it now: Best. Hosts. Ever. #GoldenGlobes',
#  '"Quentin Tarantino is here, the star of all my sexual nightmares!" - Tina Fey. Ok, can we just call it now: Best. Hosts. Ever. #GoldenGlobes',
#  'Amy Poehler and Tina Fey are amazing as hosts!! #GoldenGlobes2013 #GoldenGlobes',
#  'Amy &amp; Tina are the best hosts #GoldenGlobes',
#  '+1000000 RT @adryenn: The hosts of the #GoldenGlobes are killing it! Awesome! #omginsider',
#  "It's our hosts Tina Fey and Amy Poehler! #goldenglobes #redcarpet ",
#  '"Quentin Tarantino is here, the star of all my sexual nightmares!" - Tina Fey. Ok, can we just call it now: Best. Hosts. Ever. #GoldenGlobes',
#  'Amy Poehler and Tina Fey should host every show ever! #GoldenGlobes',
#  'Loving the golden globes host 😂',
#  "Okay, it's safe to say that Tina Fey and Amy Poehler are hosting next year's Golden Globes, too. #Hilarious",
#  'First time golden globes has two hosts. Tina Fey and her scar. #RBRGG',
#  'Tina and Amy hosting the Golden Globes &gt;&gt;&gt;',
#  "Ready for this great idea? @coolkarl704 and I host the Golden Globes. Oh my god that'd be great.",
#  "5 minutes in and I'm already laughing out loud at Amy Poehler and Tina Fey hosting the year's Golden Globes ... go girls!",
#  'Amy Poehler and Tina Fey hosting the golden globes #sofunny',
#  '"Quentin Tarantino is here, the star of all my sexual nightmares!" - Tina Fey. Ok, can we just call it now: Best. Hosts. Ever. #GoldenGlobes',
#  'Tina Fey and Amy Poehler should host every awards show. #noseriously #goldenglobes',
#  "They're amazing! RT @ckanal: Tina Fey + Amy Poehler are hilarious. Thank you whoever scheduled them to host #goldenglobes",
#  '"Quentin Tarantino is here, the star of all my sexual nightmares!" - Tina Fey. Ok, can we just call it now: Best. Hosts. Ever. #GoldenGlobes',
#  'Al Roker poops his pants and gets to host the red carpet at the golden globes, I poop mine and get kicked out of the cinema #GoldenGlobes',
#  '"Quentin Tarantino is here, the star of all my sexual nightmares!" - Tina Fey. Ok, can we just call it now: Best. Hosts. Ever. #GoldenGlobes',
#  'Amy Poehler &amp; Tina Fey are killing it. They should host every award show. #GoldenGlobes',
#  '"Quentin Tarantino is here, the star of all my sexual nightmares!" - Tina Fey. Ok, can we just call it now: Best. Hosts. Ever. #GoldenGlobes',
#  'Tina Fey &amp; Amy Poehler are HYSTERICAL! Dynamic Duo! #GoldenGlobes #hosts #comedy',
#  "SNL is showing everyone how to host a show.  go get 'em girls. #goldenglobes",
#  "Why haven't Tina Fey and Amy Poehler hosted every award show since the beginning of time? They are amazing! #goldenglobes",
#  'Tina Fey and Amy Poehler need to host EVERYTHING from now on. #GoldenGlobes',
#  'Can Tina and Amy host everything? Thx. #GoldenGlobes',
#  'Loving #TinaFey &amp; #AmyPoehler as funny hosts on #GoldenGlobes',
#  'Can they please host every award show ever??? HILARIOUS. #goldenglobes',
#  'I vote Tina Fey &amp; Amy Poehler for #GoldenGlobes hosts every. year.',
#  'They are the perfect host...so hilarious. #GoldenGlobes',
#  'I think Tina Fey and Amy Poehler should host the #goldenglobes every year!  So funny',
#  'Please let them host forever. And ever. #GoldenGlobes',
#  'Tina Fey and Amy Poehler need to host #GoldenGlobes every year for the rest of time 👏❤',
#  'To recap: red gowns, nude gowns, unusual busts, Kevin Dior and girl crushes on our comedienne hosts. #goldenglobes',
#  "SNL is showing everyone how to host a show.  go get 'em girls. #goldenglobes",
#  'Ok I am loving these two as hostesses. #goldenglobes',
#  'De risas viendo los #GoldenGlobes con hostess Tina Fey &amp; Amy Polard',
#  'Tina Fey and Amy Poehler need to host EVERYTHING from now on. #GoldenGlobes',
#  'OMG best pairing of hosts ever #Fey #Poehler #goldenglobes',
#  'tina fey and amy poehler should host everything ever.  they should host the world. #redcarpet #goldenglobes',
#  'I am in love with their hosting #GoldenGlobes',
#  "Amazing hosts I can't even handle it. #GoldenGlobes",
#  'Tina Fey and Amy Poehler need to host #GoldenGlobes every year for the rest of time 👏❤',
#  "Ron Riggle is not hosting #GoldenGlobes. Let's all pause for a moment and give thanks.",
#  'Tina Fey and Amy Poehler were the absolute perfect choice for hosts! #GoldenGlobes',
#  '"Quentin Tarantino is here, the star of all my sexual nightmares!" - Tina Fey. Ok, can we just call it now: Best. Hosts. Ever. #GoldenGlobes',
#  '"Quentin Tarantino is here, the star of all my sexual nightmares!" - Tina Fey. Ok, can we just call it now: Best. Hosts. Ever. #GoldenGlobes',
#  "They're literally just BFFs chilling hosting the Globs I LOVE THEM BE MY FRIENDS TOO #GoldenGlobes",
#  'Tina Fey and Amy Poehler. Best hosts in the history of award show hosts. Hands down. Making my night. #GoldenGlobes',
#  'Love seeing two strong, beautiful women hosting the #GoldenGlobes this year.',
#  "They're great. RT @killa_kamkam: LOVING Tina Fey and Amy Poheler hosting the Golden Globes! I've actually laughed out loud! #goldenglobes",
#  'Amy Poehler and Tina Fey are certainly killing it! #BestHost #GoldenGlobes',
#  'Amy and Tina are killing it. Can they host everything from now on please? #GoldenGlobes',
#  '"Quentin Tarantino is here, the star of all my sexual nightmares!" - Tina Fey. Ok, can we just call it now: Best. Hosts. Ever. #GoldenGlobes',
#  '"Quentin Tarantino is here, the star of all my sexual nightmares!" - Tina Fey. Ok, can we just call it now: Best. Hosts. Ever. #GoldenGlobes',
#  'Omg Amy Poehler and Tina Fay are the best hosts ever! #goldenglobes',
#  'Best host of  #GoldenGlobes ever!!',
#  'Tina and Amy were the best choices for hosts #ever #goldenglobes',
#  "Amy Poehler and Tina Fey are every bit as flawless as I knew they'd be. They will be hosting everything ever from now on, yes? #GoldenGlobes",
#  'Tina Fey and Amy Poehler to host ALL the awards. #GoldenGlobes',
#  'Do you love Tina and Amy hosting so far?? #GoldenGlobes ',
#  '"Quentin Tarantino is here, the star of all my sexual nightmares!" - Tina Fey. Ok, can we just call it now: Best. Hosts. Ever. #GoldenGlobes',
#  "I'm so happy Amy Pohler and Tina Fey are hosting the Golden Globes #sofunny #womenpower",
#  'Amy Poehler and Tina Fey are hosting the Golden Globes. Enough said.',
#  'I want to host the Golden Globes',
#  "The Golden Globes couldn't have picked better hosts #TinaFeyAmyPoehler",
#  'So happy to see my two best friends Tina Fey and Amy Poehler hosting the Golden Globes.',
#  "I want to get a Golden Globe WHILE I'm hosting the Golden Globes.",
#  'Tina Fey and Amy Poehler are the best hosts. #goldenglobes',
#  'From here on out ALL awards shows are hosted by Amy and Tina. #GoldenGlobes',
#  'Mejores hosts del mundo mundial! Las amo a las dos! #GoldenGlobes',
#  'Tina Fey &amp; Amy Poehler are KILLING it on the #GoldenGlobes already! Can they host everything ever, please?',
#  '"Quentin Tarantino is here, the star of all my sexual nightmares!" - Tina Fey. Ok, can we just call it now: Best. Hosts. Ever. #GoldenGlobes',
#  'See America, we just needed to have women host to laugh our asses off. #amypoehler #tinafey #goldenglobes and Tina Fey is boom shaka laka!',
#  'Amy and Tina hosting = best idea ever. #goldenglobes',
#  'STOP IT. Tina Fey and Amy Poehler should host everything, hopefully, next, my life. #GoldenGlobes',
#  "Get comfy ladies you'll be hosting for a long time #tinaandamyrule #GoldenGlobes",
#  'Oh my god, Tina and Amy are KILLING IT. This is perfection. Please host all the things, ladies. #GoldenGlobes',
#  'Amy Poehler and Tina Fey: best hosts ever. #goldenglobes',
#  '"Quentin Tarantino is here, the star of all my sexual nightmares!" - Tina Fey. Ok, can we just call it now: Best. Hosts. Ever. #GoldenGlobes',
#  '"Quentin Tarantino is here, the star of all my sexual nightmares!" - Tina Fey. Ok, can we just call it now: Best. Hosts. Ever. #GoldenGlobes',
#  'Amy poehler and Tina fey are hilarious! What a great hosting duo. #GoldenGlobes',
#  "I can't breathe...Daniel Day Lewis...ET...favorite hosts ever. #GoldenGlobes",
#  'I vote for Tina and Amy to host everything from here on out #GoldenGlobes',
#  'Loving Tina Fey and Amy Poehler hosting the #GoldenGlobes!!',
#  'I could not pick two better hosts for any kind of event than Amy Poehler and Tina Fey #GoldenGlobes',
#  '"Quentin Tarantino is here, the star of all my sexual nightmares!" - Tina Fey. Ok, can we just call it now: Best. Hosts. Ever. #GoldenGlobes',
#  'Can Tina and Amy host the oscars? #goldenglobes',
#  'These two should host everything. #GoldenGlobes',
#  'RT @fuggirls: Can Tina and Amy, like, host my life? - J #GoldenGlobes',
#  "Totally loving Tina &amp; Amy hosting tonight.  They're hilarious!  #GoldenGlobes",
#  'RT @Dany_Jarvis Tina and Amy should host the GG EVERY YEAR. EVERY. YEAR. DO YOU HEAR ME? #GoldenGlobes',
#  "Every awards show's hosts should be Tina Fey and Amy Poehler. #DEAD #GoldenGlobes 😂",
#  'Watching the Golden Globes just because Amy Poehler &amp; Tina Fey are the hosts 🎥📺',
#  'Oh my god Amy Polar &amp; Tina Fey hosting The Golden Globes hilarious!',
#  'Tina fey and Amy poehler hosting the golden globes. &gt;&gt;&gt;',
#  'Best hosts ever at the golden globes',
#  'Tina Fey and Amy Poeler are perfect at hosting the golden globes. Just hilarious #meangirlscastreunited',
#  "I'm dying. Tina and Amy were the best choices to host the golden globes.",
#  'Can Tina Fey and Amy Poehler please please please host everything?? Who do I ask about this? #goldenglobes',
#  'Tina Fey &amp; Amy Poehler already the best hosts of #GoldenGlobes EVER',
#  "Amy P. And Tina Fey best host's ever!! #goldenglobes",
#  'Ok getting Daniel Day-Louis to do "ETs finger" certifies Amy &amp; Tina as best hosts ever. #GoldenGlobes',
#  'Tina Fey &amp; Amy Poehler already the best hosts of #GoldenGlobes EVER',
#  'Is it too early to say Amy and Tina should host this every year? #GoldenGlobes',
#  'Tina Fey and Amy Poehler are great hosts #GoldenGlobes',
#  "So far I've laughed more in the first 8 minutes of Tina &amp; Amy hosting the #GoldenGlobes than I have in all other Globes combined.",
#  'I think Tina Fey and Amy Poehler should host everything. #GoldenGlobes',
#  'next year @MichelleDBeadle will be hosting the #GoldenGlobes &amp; the #Browns will make the #superbowl... calling it now!',
#  '2 very fine/funny women Tina Fey and Amy Poehler hosting the #GoldenGlobes last tweet was a joke both would approve.',
#  "He's not wrong. RT @BillDixonish: I think Tina Fey &amp; Amazing Breasts is the best hosting team ever!  #goldenglobes",
#  'Tina Fey + Amy Poehler are hilarious. Thank you whoever scheduled them to host #goldenglobes',
#  "If Amy Poehler and Tina Fey hosted every awards show, I'd have nothing left to complain about anymore. #GoldenGlobes",
#  'Love Tina Fey and Amy Poehler! The perfect hosts #GoldenGlobes @smrtgrls',
#  '"Quentin Tarantino is here, the star of all my sexual nightmares!" - Tina Fey. Ok, can we just call it now: Best. Hosts. Ever. #GoldenGlobes',
#  'So this is how it is when super funny people host in a non self-congratulatory way. #goldenglobes',
#  "They don't have to host everything, put can Fey and Poehler write all award shows from now on? Thanks. #goldenglobes #blogherpop",
#  'Two Girls From Chicago improv hosting the golden globes? The Universe just may be righting itself! #IO #SecondCity #GoldenGlobes',
#  'Tina Fey and Amy Poehler hosting the Golden Globes... Funny ass bitches',
#  'Tina Fey &amp; Amy Poehler are AMAZING hosts of the Golden Globes!!!!! @HollywoodLife',
#  'Putting Tina Fey &amp; Amy Poehler together as hosts for the Golden Globes was GENIUS. I love them so much. #goldenglobes',
#  'I am so happy about the golden globes hosts. Heck yes.',
#  "I'd love to watch Tina and Amy host the Golden Globes, but not with the pathetic slate of nominations the HFPA provided.",
#  '"Quentin Tarantino is here, the star of all my sexual nightmares!" - Tina Fey. Ok, can we just call it now: Best. Hosts. Ever. #GoldenGlobes',
#  'Thanks for the funny hosts, HFPA! #goldenglobes',
#  'Can Tina and Amy host all awards shows? Or maybe alternate with @ActuallyNPH each year? #GoldenGlobes',
#  'Loving Tina &amp; Amy as hosts! #GoldenGlobes',
#  '"Quentin Tarantino is here, the star of all my sexual nightmares!" - Tina Fey. Ok, can we just call it now: Best. Hosts. Ever. #GoldenGlobes',
#  '@HmelMel gorgeous and funniest hosts ever #goldenglobes',
#  'So I nominate Amy Poehler and Tina Fey to host EVERY award show. #GoldenGlobes',
#  '"Quentin Tarantino is here, the star of all my sexual nightmares!" - Tina Fey. Ok, can we just call it now: Best. Hosts. Ever. #GoldenGlobes',
#  'Tina Fey + Amy Poehler are hilarious. Thank you whoever scheduled them to host #goldenglobes',
#  'Loving #tinafey and #amypoehler as the hosts of #2013goldenglobes. #goldenglobes #fashion',
#  'I love when they get comedians to host award shows #goldenglobes',
#  'Yup. RT @birchbox Can we all just agree that no one else should ever host anything ever again? #GoldenGlobes',
#  'Tina Fey and Amy Poehler hosting together on Golden Globes is a whole lot of awesome #babymama',
#  'Amy poehler and Tina fey packed more funny into 8 minutes than any other golden globes host combined.',
#  'They could not choose better hosts for the Golden Globes!! Well done Amy &amp; Tina!!!',
#  'no 2 better people to host the Golden Globes than Tina Fey and Amy Poehler',
#  '"Quentin Tarantino is here, the star of all my sexual nightmares!" - Tina Fey. Ok, can we just call it now: Best. Hosts. Ever. #GoldenGlobes',
#  'Tina Fey + Amy Poehler are hilarious. Thank you whoever scheduled them to host #goldenglobes',
#  'I love Tina Fey and Amy Poehler. In everything. They need to host the #OSCARS, as in THIS YEAR. #GoldenGlobes',
#  'Fey/Poehler should host everything on TV, forever and ever. #GoldenGlobes',
#  'Dear heads of every Academy ever: Please always have Tina Fey and Amy Poehler host your shows. Please. #killerintro #GoldenGlobes',
#  'Can we all just agree that no one else should ever host anything ever again? #GoldenGlobes',
#  'Can Tina and Amy host everything? Thx. #GoldenGlobes',
#  '"Quentin Tarantino is here, the star of all my sexual nightmares!" - Tina Fey. Ok, can we just call it now: Best. Hosts. Ever. #GoldenGlobes',
#  'Tina Fey and Amy Poehler are the perfect choice for hosting the Golden Globes.',
#  'Amy Poehler and Tina Fey are by far the best Golden Globes Hosts. Ever. #GoldenGlobes',
#  "Okay, it's safe to say that Tina Fey and Amy Poehler are hosting next year's Golden Globes, too. #Hilarious",
#  'BEST. MONOLOGUE. EVER. HFPA, you need to hire Amy Poehler and Tina Fey to host the Golden Globes again and again and again. #GoldenGlobes',
#  'Is it too early to say Amy and Tina should host this every year? #GoldenGlobes',
#  'Can Tina and Amy host everything? Thx. #GoldenGlobes',
#  'Tina and Amy need to host EVERYTHING EVER ALWAYS. #GoldenGlobes',
#  'Best hosts ever for the Golden Globes, I never ever f**** ever laughed so much',
#  '"@hilmonstah: I want a Fey/Poehler hosting reprise for the #Oscars already. MAKE IT HAPPEN UNIVERSE. #GoldenGlobes"',
#  'Dear heads of every Academy ever: Please always have Tina Fey and Amy Poehler host your shows. Please. #killerintro #GoldenGlobes',
#  'Tina Fey and Amy Poehler should host every year #KillingIt #GoldenGlobes',
#  'Tina Fey + Amy Poehler are hilarious. Thank you whoever scheduled them to host #goldenglobes',
#  "SNL is showing everyone how to host a show.  go get 'em girls. #goldenglobes",
#  '"Quentin Tarantino is here, the star of all my sexual nightmares!" - Tina Fey. Ok, can we just call it now: Best. Hosts. Ever. #GoldenGlobes',
#  'Can we all just agree that no one else should ever host anything ever again? #GoldenGlobes',
#  'Amy Poehler and Tina Fey, #GoldenGlobes hosters. Simply amazing :)',
#  'I would like to formally invite Tina and Amy to host the rest of my life. #goldenglobes',
#  '"Quentin Tarantino is here, the star of all my sexual nightmares!" - Tina Fey. Ok, can we just call it now: Best. Hosts. Ever. #GoldenGlobes',
#  'I want Tina and Amy to host my life. Just commentary running the background. #GoldenGlobes',
#  'Can Tina Fey and Amy Poehler narrate/host my life? #GoldenGlobes',
#  'Can Tina Fey &amp; Amy Poehler host my life?? #goldenglobes',
#  "#TinaFey &amp; #AmyPohler are absolutely gorgeous and absolutely killin' it hosting the #GoldenGlobes tonight #hilarious",
#  '#besthostsever  Amy and Tina killing it at the Golden Globes',
#  'Those crazy chicks Tina and Amy are kicking ass hosting the #goldenglobes',
#  'Absolutely RT @AnnBac9: Yes! “@BOREDmommy: Tina Fey and Amy Poehler need to host EVERYTHING from now on. #GoldenGlobes”',
#  'Can Tina and Amy host everything? Thx. #GoldenGlobes',
#  'Can Tina and Amy host everything? Thx. #GoldenGlobes',
#  'Can Tina and Amy host everything? Thx. #GoldenGlobes',
#  'LOL they can talk as fast as they want, still the perfect pair of hosts #goldenglobes',
#  'Can Tina and Amy host everything? Thx. #GoldenGlobes',
#  'Can Tina and Amy host everything? Thx. #GoldenGlobes',
# ...
#  "If Amy Poehler and Tina Fey hosted every awards show, I'd have nothing left to complain about anymore. #GoldenGlobes",
#  'Ok They are good host lol #GoldenGlobes',
#  'This monologue is beyond incredible. Can Tina Fey and Amy Poehler host everything, please? #goldenglobes',
#  'So this is how it is when super funny people host in a non self-congratulatory way. #goldenglobes',
#  'Amy and Tina are the perfect people to host this show #GoldenGlobes',
#  'Golden Globes hosts Tina Fey and Amy Poehler receive nods for their opening routine, taking aim at Quentin Tarantino and Anne Hathaway.',
#  'The fact that Amy Poehler and Tina Fey are hosting the Golden Globes&gt;&gt;&gt;&gt;&gt;&gt; #lovethem #GoldenGlobes',
#  'Can Tina and Amy host everything? Thx. #GoldenGlobes',
#  'Tina Fey and Amy Poehler should host everything all the time. Forever! #GoldenGlobes',
#  'Tina and Amy were fabulous in the opening of the Golden Globes - Great choice as hosts #GoldenGlobes',
#  "Tina Fey &amp; Amy Poehler - the best! Watch out all other awards' hosts! #goldenglobes",
#  'Tina and Amy forever #besthosts #GoldenGlobes',
#  'To recap: red gowns, nude gowns, unusual busts, Kevin Dior and girl crushes on our comedienne hosts. #goldenglobes',
#  'This! RT @David_Braden Bring the hosts back! #goldenglobes',
#  'Tina Fey and Amy Poehler hosting the #GoldenGlobes again was an A+ idea.',
#  'Who else is loving Tina Fey and Amy Poehler hosting the #GoldenGlobes?',
#  'So this is how it is when super funny people host in a non self-congratulatory way. #goldenglobes',
#  'Can Tina and Amy host everything? Thx. #GoldenGlobes',
#  'Oh my god, I love Amy Poehler! She is literally sitting in the audience of The Golden Globes wearing hillbilly teeth! Best host ever!',
#  'Can Tina and Amy just host my life? #GoldenGlobes',
#  'Can Tina and Amy host everything? Thx. #GoldenGlobes',
#  'Who else is loving Tina Fey and Amy Poehler hosting the #GoldenGlobes?',
#  'Tina and amy...best GG hosts ever. #dyingoflaughter #goldenglobes',
#  'So, we all agree: Tina Fey and Amy Poehler should host everything from now on? #GoldenGlobes',
#  'Anyone else wishing @danawhite had hosted the Red Carpet at the #GoldenGlobes? F bomb city!',
#  'Can Tina and Amy host everything? Thx. #GoldenGlobes',
#  'The #GoldenGlobes have the best camera shots! Hilarious audience/hosts!',
#  'Tina &amp; Amy should host EVERY awards show. #goldenglobes #justsaying #toofunny #hfpa',
#  'My two best friends are hosting the Golden Globes. #inmydreams',
#  '@SmartPoptart I turned on the tv and u were hosting the golden globes #uramypoehler',
#  'Tina and Amy are the perfect co-hosts!! #GoldenGlobes',
#  "Am I the only one who misses @rickygervais hosting the Golden Globes?! If he still was, it'd be on LIVE in the UK right now. #Amirite",
#  "Tonight's dual hosting duties represent the culmination of a decade of Amy and Tina partnerships.  #GoldenGlobes",
#  'Well this Hollywood shindig would be much better if only Lucille Ball were hosting. #goldenglobes',
#  "Fifteen minutes into the #goldenglobes and we're ready to dub it the best ever! Tina Fey and Amy Poehler: please host everything always.",
#  "This is probably the first time I've ever been pissed at not seeing more of the hosts. #GoldenGlobes",
#  'Dear heads of every Academy ever: Please always have Tina Fey and Amy Poehler host your shows. Please. #killerintro #GoldenGlobes',
#  'Watching Golden Globes and Tina and Amy are the perfect people to host!! #funnyladies #GoldenGlobes',
#  'I want it to be clear that i swore off Golden Globes a while ago, but Amy Poeler &amp; Tina Fey is hosting...it would be funny and interesting',
#  "I'm absolutely loving Tina Fey and Amy Poehler as hosts! The whole show should just be on them! #GoldenGlobes",
#  'Loving Tina and Amy at the #GoldenGlobes. They should host all future award shows for their smart, sassy humor',
#  'Tina &amp; Amy have the right to host every future event ever #GoldenGlobes',
#  'Tina Fey and Amy Poehler are already flawless while hosting the Golden Globes. And damn, they look good. #goldenglobes',
#  'Can Tina and Amy host everything? Thx. #GoldenGlobes',
#  'I wish Amy Poehler and Tina Fey hosted everything. #GoldenGlobes',
#  '@AshleyMcGovern RT @usweekly: #GoldenGlobes hosts Tina Fey, Amy Poehler show off matching "husband and wife" outfits on red carpet',
#  'Whats going on? I thought honey booboo was hosting. ( warm up joke. Doesnt count. Its like shadow boxing). #GoldenGlobes',
#  'I wish Amy Poehler and Tina Fey hosted everything. #GoldenGlobes',
#  "It's kind of uppsetting that Tina Fey and Amy Poehler are hosting the Golden Globes.",
#  'So my 2 favorite women are hosting the golden globes!',
#  'Tina Fey &amp; Amy Poehler Are Already The Best Golden Globes Hosts Of All Time! ',
#  'Tina Fey, Amy Poehler pal it up as Globes hosts. Read about their antics here: ',
#  'My dream is to host the Golden Globes one day #LoveIt #Hopefully',
#  'Hosting the Golden Globes is clearly a job for SNL alum. Leave it to them. #GoldenGlobes',
#  "Tina Fey and Amy Poehler = best host combo ever. I'm dying. #GoldenGlobes",
#  '"We do get pretty naked." - Tina Fey, on hosting tonight\'s ceremony. #GoldenGlobes #RedCarpet',
#  'Totally agree! RT @ASCPR: Girl Power! Loving the @goldenglobes @tinafey &amp; @amypohler - best hosts ever!!!',
#  'Can Tina and Amy host everything? Thx. #GoldenGlobes',
#  '"Quentin Tarantino is here, the star of all my sexual nightmares!" - Tina Fey. Ok, can we just call it now: Best. Hosts. Ever. #GoldenGlobes',
#  'Tina &amp; Amy need to host the #GoldenGlobes for 4 more years after tonight!',
#  "Can we just have 3 hours of Tina &amp; Amy?? They're killin it!! They should host everything. #GoldenGlobes",
#  'Tina Fey and Amy Poehler should host everything. Funny ladies! #goldenglobes',
#  'Who ever decided Tina Fey and Amy Poehler would host the Golden Globes: YOU ARE THE GREATEST PERSON ALIVE',
#  'To recap: red gowns, nude gowns, unusual busts, Kevin Dior and girl crushes on our comedienne hosts. #goldenglobes',
#  'I wish Amy Poehler and Tina Fey hosted everything. #GoldenGlobes',
#  'amendment to amy and tina hosting every future awards show...throw in neil patrick harris for an awards shows on steroids #goldenglobes',
#  'Amy Poehler is my new favorite person. Hilarious! Her and Tina Fey are the best hosts everrr!! #GoldenGlobes',
#  'I would like to formally invite Tina and Amy to host the rest of my life. #goldenglobes',
#  'Can Tina and Amy host everything? Thx. #GoldenGlobes',
#  'I wish Amy Poehler and Tina Fey hosted everything. #GoldenGlobes',
#  "I love Ricky gervais. I missed that he didn't have an  #hbo \nspecial this year like the years he hosted the #goldenglobes",
#  "Tina Fey and Amy Poehler are hilarious.  I can't even! 😂😂😂 Can they please host every year? #GoldenGlobes",
#  'Whats going on? I thought honey booboo was hosting. ( warm up joke. Doesnt count. Its like shadow boxing). #GoldenGlobes',
#  'I wish Amy Poehler and Tina Fey hosted everything. #GoldenGlobes',
#  "Weird that they're having Elmo host this year. #notwatching #goldenglobes",
#  'Before anyone starts in, I am not biased against women hosting the Golden Globes, I am actually a huge fan of Tina Fey and Amy Poelher.',
#  'Tina Fey and Amy Poehler hosting the Golden Globes &gt;&gt;&gt;',
#  '2013 Golden Globes live: Tina Fey and Amy Poehler host Hollywood elite  via @guardian #goldenglobes',
#  'Tina Fey and Amy Poehler are literally the perfect people to host the golden globes everything they say makes me laugh for 5 mins straight',
#  'Amy Poehler and Tina Fey are my favorite Golden Globes hostesses.',
#  '2013 #GoldenGlobes host predictions - Matt Pinfield and a canteloupe',
#  'Can Tina and Amy host everything? Thx. #GoldenGlobes',
#  'I wish Amy Poehler and Tina Fey hosted everything. #GoldenGlobes',
#  '"Quentin Tarantino is here, the star of all my sexual nightmares!" - Tina Fey. Ok, can we just call it now: Best. Hosts. Ever. #GoldenGlobes',
#  'So excited to see Amy Poehler host the Golden Globes tonight',
#  "I'm presenting at the Golden Globes tonight. The lovely and hilarious Amy Poehler and Tina Fey are hosting. You should watch!",
#  "SNL is showing everyone how to host a show.  go get 'em girls. #goldenglobes",
#  'Love Tina and Amy hosting the #GoldenGlobes. Amazing.',
#  'RT @kumailn: So this is how it is when super funny people host in a non self-congratulatory way. #goldenglobes',
#  "ok, if you say Tina Fey and Amy Poehler aren't funny hosts at the #GoldenGlobes you must be mistaken.",
#  'Amy Poehler and Tina Fey are amazing #GoldenGlobes hosts! They are too funny!',
#  "Tina Fey and Amy Phoehler are killing it as hosts of the Golden Globes. Don't you think so?",
#  'Me too, they rock- “@xoamelia: I would like to formally invite Tina and Amy to host the rest of my life. #goldenglobes”',
#  'So, two women host the Golden Globes and we get over active bladder commercials. Ah, feminism... @goldenglobes',
#  "I wouldn't mind if Tina Fey and Amy Poehler hosted the Golden Globes every year.",
#  "OK, enough Golden Globes chatter from me. Off to host karaoke at Toby's tonight. Pretty sure it'll be more entertaining than half this show.",
#  'best hosts ever! #goldenglobes',
#  'Really loving Amy and Tina as hosts for #goldenglobes.  Will you show @gabrielledoug and @Aly_Raisman during the show?. present an award?.',
#  'Tina Fey and Amy Poehler. Let the women do it. Host the Golden Globes. Run the World',
#  "Watching Tina Fey host the #GoldenGlobes? Download BOSSYPANTS so you can keep laughing when the show's over ",
#  'Hey, this woman was hilarious. Let her host the MTV Movie Awards. #GoldenGlobes',
#  'Tina Fey and Amy Poehler. Let the women do it. Host the Golden Globes. Run the World',
#  'They could not have picked two better people to host the golden globes.',
#  'OMG Tina Fey and Amy Pohler should host the Golden Globes every year!! Sooo damn funny!!!',
#  'Awkward? Both #GoldenGlobes hosts are nominated in the same category: ',
#  '2013 Golden Globes live: Tina Fey and Amy Poehler host Hollywood elite ',
#  'Those women hosting the Golden Globes reminded me of that movie Baby Momma. That shit sucked....',
#  'Tina Fey and Amy Poehler. Let the women do it. Host the Golden Globes. Run the World',
#  'Hostess with the mostest! Amy Poehler killed it in @stellamccartney @goldenglobes #goldenglobes ',
#  'Tina Fey and Amy Poehler. Let the women do it. Host the Golden Globes. Run the World',
#  'Tina Fey and Amy Poehler. Let the women do it. Host the Golden Globes. Run the World',
#  'Is there a WH petition yet to replace Seth MacFarlane with Tina Fey &amp; Amy Poehler as Oscar hosts? #GoldenGlobes',
#  'Can Tina Fey and Amy Poehler just cohost my life? #GoldenGlobes',
#  'I wish Amy Poehler and Tina Fey hosted everything. #goldenglobes',
#  'YESSS! RT “@NancyLeeGrahn: Tina Fey and Amy Poehler. Let the women do it. Host the #GoldenGlobes. Run the World”',
#  'I wish Amy Poehler and Tina Fey hosted everything. #GoldenGlobes',
#  'Amy Poehler and Tina Fey knocked it out of the park with that opening skit! They are the best #GoldenGlobes hosts yet! #KillerIntro #Funny',
#  'Tina and Amy are by far my favorite #GoldenGlobes hosts so far!',
#  'Amy and tina can host the #goldenglobes every year!',
#  '@SheSaidImprov are real excited for Amy Poehler and Tina Fey to host the #GoldenGlobes!!  Maybe too excited? Nah.\n',
#  'I would like to formally invite Tina and Amy to host the rest of my life. #goldenglobes',
#  'More like WORST exotic Marigold Hotel #nailedit #comedy #imhostingnextyear #goldenglobes',
#  'Tina and Amy must host every awards show from now on. Love them! #GoldenGlobes',
#  '@MikeJackBauer hosting the Golden Globes',
#  'Tina Fey &amp; Amy Poehler Are Already The Best Golden Globes Hosts Of All Time! ',
#  'Shoutout to my girl Tina hosting the Golden Globes. #twiny',
#  'OMG Tina n Amy are too freaking funny!! They just need to host all the shows this year.  #GetGlue @goldenglobes',
#  "If you hadn't heard, Poehler and Fey are hosting the #GoldenGlobes and it promises to be spectacular. I must watch it in full when possible.",
#  'Watching #GoldenGlobes love Amy pohler and Tina fey hosting.',
#  'The #GoldenGlobes should be a one person show, hosted by the incomparable Jessica Lange.',
#  'Completely entertained watching the #GoldenGlobes. #besthostsever',
#  'Watching Tina Fey and Amy Poehler host the Golden Globes! #LosAngeles #GoldenGlobes',
#  'update: ill be hosting next years golden globes',
#  'Tina Fey and Amy Poehler should host everything from now on. #GoldenGlobes',
#  "Weird that they're having Elmo host this year. #notwatching #goldenglobes",
#  '"Quentin Tarantino is here, the star of all my sexual nightmares!" - Tina Fey. Ok, can we just call it now: Best. Hosts. Ever. #GoldenGlobes',
#  'Can we all just agree that no one else should ever host anything ever again? #GoldenGlobes',
#  'Indeed a good idea RT @ckanal: Tina Fey + Amy Poehler are hilarious. Thank you whoever scheduled them to host #goldenglobes',
#  'Loving Tina Fey &amp; Amy Poehler hosting the #GoldenGlobes!  They are hysterical!  (Loved the James Cameron line)',
#  'Rudd and Selma Hayek should host next year. #GoldenGlobes',
#  'Tina Fey and Amy Poehler. Let the women do it. Host the Golden Globes. Run the World',
#  'Tina Fey and Amy Poehler. Let the women do it. Host the Golden Globes. Run the World',
#  "I vote for Tina Fey and Amy Pohler to host every year, 10 minutes in and they're already kickin ass! #goldenglobes #girlpower",
#  'Can Paul Rudd just host the show with Tina &amp; Amy? #GoldenGlobes',
#  "But seriously, can we get Tina and Amy to host the Oscars? I'm sure Seth will understand. #GoldenGlobes",
#  'Tina Fey and Amy Poehler. Let the women do it. Host the Golden Globes. Run the World',
#  'Having Amy Poehler and Tina Fey host the Golden Globes was seriously the best idea EVER!! #HILARIOUS #Epic @goldenglobes',
#  "Why do the Golden Globes always look like they're hosted in a Carnival Cruise ship ballroom?",
#  '“@NancyLeeGrahn: Tina Fey and Amy Poehler. Let the women do it. Host the Golden Globes. Run the World."',
#  "Are y'all liking Tina &amp; Amy hosting? #GoldenGlobes @rickygervais was my all time fave",
#  'Tina fey and amy poehler are the best two hosts. #goldenglobes #dynamicduo',
#  "@DavidSpade Who's basement is this being hosted in? #GoldenGlobes",
#  "I really like @rickygervais's new blonde hair! #GoldenGlobes #host",
#  '@mags_doc we would do this RT: @usweekly: #GoldenGlobes hosts Fey, Poehler show off matching "husband and wife" outfits ',
#  'Amy and Tina are great hosts, what a great show opening! #GoldenGlobes',
#  'Could not have picked better hosts for the golden globes 👏👏',
#  'Tina Fey and Amy Poehler. Let the women do it. Host the Golden Globes. Run the World',
#  'Tina and Amy just killed it. Can they please host everything ever? #GoldenGlobes',
#  "I think everyone looks fabulous. Except my fav. E host. Can't win em all. #GoldenGlobes",
#  '.#ACC Represent at the #GoldenGlobes with Tina Fey @UVA grad and Amy Poehler - @BostonCollege grad co-hosting #bestpopcultureconference',
#  'Dear heads of every Academy ever: Please always have Tina Fey and Amy Poehler host your shows. Please. #killerintro #GoldenGlobes',
#  '"Paul Rudd and Salma Hayek for Golden Globes hosts 2014" hahahahahahahaha',
#  'Amy and Tina are like the best pair to host a show #GoldenGlobes',
#  'Killing it! "@MilkStudios: .@goldenglobes hosts @amypoehler &amp; @tinafey123 are killing it tonight !"',
#  'Tina Fey and Amy Poleher should probably always host every award show. #GoldenGlobes #rockinitladies',
#  'Fey &amp; Poehler should host all the award shows: Oscars, Grammys, Image Awards, Lady of Soul, etc. #GoldenGlobes',
#  'watching the #goldenglobes for the flawless lady hosts',
#  '"Quentin Tarantino is here, the star of all my sexual nightmares!" - Tina Fey. Ok, can we just call it now: Best. Hosts. Ever. #GoldenGlobes',
#  'Where r Tina and Amy I thought they were hosting the WHOLE show #goldenglobes',
#  'Tina Fey &amp; Amy Poehler... Great hosting #GoldenGlobes ... They should always host them!',
#  ...]

# %%
entities = {}
for tweet in tweets_with_host:
    parsed_tweet = nlp(tweet)
    for entity in parsed_tweet.ents:
        if entity.label_ == "PERSON":
            person = entity.text
            if person in entities:
                entities[person] += 1
            else:
                entities[person] = 1
entities
# Out:
# {'Tina Fey': 527,
#  'Amy Poehler': 614,
#  'Amy': 518,
#  'GoldenGlobes': 1522,
#  'Tina Fey’s': 2,
#  'Frederic J. Brown': 3,
#  'Rolonda Watts': 1,
#  'Dalia MacPhee': 1,
#  'Jay Leno': 6,
#  'Kelly': 1,
#  "Amy Poehler's": 15,
#  "Jay Leno's": 1,
#  '\ue106\ue106\ue106': 1,
#  'Amy Pohler': 20,
#  'Tina Fey + Amy Poehler': 11,
#  'SGS': 1,
#  'Ryan Seacrest': 2,
#  'TinaFey': 12,
#  'Golden Globes': 28,
#  "Giuliana Rancic's": 1,
#  'Golden': 1,
#  'iloveamypoehler': 1,
#  "Glenn Close's": 1,
#  'Amy Polher': 1,
#  'Norberry': 1,
#  'Tina': 144,
#  "Tina Fey's": 3,
#  'Amy Poehler - @BostonCollege': 3,
#  'Amy Poeler': 3,
#  'Amy Pholer &': 1,
#  'Tiny Fay': 1,
#  'Amy hostin': 1,
#  'omg tina': 1,
#  'Jamas': 1,
#  'gustado tina': 1,
#  'Bill Murray': 3,
#  'Globes': 6,
#  'tinafey': 1,
#  'Tina Faye': 1,
#  'Ricky Gervais': 15,
#  'Tina Fey&amp;Amy Poehler': 1,
#  'Tina Fey RT': 1,
#  'Oscar': 6,
#  'Hathaway': 2,
#  'Franko': 1,
#  'LoveEm': 1,
#  'James Franco': 5,
#  'Queen Amy': 1,
#  'Queen Tina': 1,
#  'god': 1,
#  'James Cameron': 8,
#  'Omg Amy Poehler': 2,
#  'Tina Fay': 4,
#  'Quentin Tarantino': 95,
#  'fuckin': 1,
#  'Amy Poehler &': 7,
#  '@fiddlecub': 1,
#  'Kate': 1,
#  'Angie': 1,
#  'jack': 1,
#  'Dynamic Duo': 2,
#  'RBRGG': 1,
#  'Al Roker': 1,
#  'Kevin Dior': 4,
#  'Amy Polard': 1,
#  'Ron Riggle': 1,
#  'Amy Poheler': 2,
#  'shaka laka': 1,
#  'Daniel Day Lewis': 2,
#  'Amy P.': 1,
#  'Daniel Day-Louis': 1,
#  'blogherpop': 1,
#  'besthostsever  ': 1,
#  '@OfficialAdele': 1,
#  'Matt Lauer': 1,
#  'Amy + Tina': 2,
#  'Anne Hathaway': 7,
#  'w/ james franco': 1,
#  'Brava': 1,
#  '💖': 1,
#  'Tina Fey/ Amy Poehler': 1,
#  'Soooooo': 1,
#  'Amy Poelher': 3,
#  'Bravo Tina': 1,
#  'Amy Hilarious': 1,
#  'Downton': 1,
#  'rickygervis': 1,
#  'zeebox': 1,
#  'Maggie Smith': 7,
#  'Amy Poehlr': 1,
#  'Liz': 1,
#  'TinaAmy': 1,
#  'Amy Poehler/Tina Fey': 2,
#  '@NYDNgossip': 1,
#  'RT @Finessemitchell': 1,
#  'sofunny': 1,
#  'Host Guiliana': 1,
#  'Hilarious': 2,
#  'Lucille Ball': 1,
#  'Amy Poeler &': 1,
#  'neil patrick harris': 1,
#  'Ricky': 3,
#  'Matt Pinfield': 1,
#  'Amy Phoehler': 1,
#  'Awkward': 1,
#  'Seth MacFarlane': 4,
#  'Jessica Lange': 1,
#  'Rudd': 1,
#  'Paul Rudd': 54,
#  'Seth': 3,
#  'Salma Hayek': 1,
#  'rockinitladies': 1,
#  'Martin Freeman': 4,
#  'Mel Gibson': 3,
#  'Arnold': 2,
#  'Tony Mendez': 2,
#  'Kristin Wigg': 2,
#  'Adele': 11,
#  'Adele Hi-': 1,
#  'Daniel Craig': 1,
#  'RT @kellidaisy': 1,
#  'Jennifer Lawrence': 7,
#  'Bill Clinton': 7,
#  'hostia el Clinton': 1,
#  'Clinton': 1,
#  'Bill': 1,
#  '@rebeccamakonnen': 1,
#  'Bill Rodham Clinton': 1,
#  'Rebel Wilson': 4,
#  'GoldenGlobes Best': 1,
#  'Reagan': 1,
#  "Hillary Clinton's": 2,
#  'Ellen': 2,
#  'Maggie Smi': 7,
#  'Will Ferrel': 7,
#  'Kristin Wiig': 9,
#  'Taylor Swift': 3,
#  'Will Ferrell': 684,
#  'Kristen Wiig': 685,
#  'Wiig': 10,
#  'Will': 1,
#  'Kristen': 14,
#  'Will Farrell': 7,
#  'Kristin': 7,
#  'Maya': 1,
#  'Ellen DeGeneres': 1,
#  'kristinwiig': 1,
#  'Kristen Wig': 9,
#  'RT @NYDNgossip': 1,
#  'Kristen Wigg': 5,
#  'GoldenGlobes2014': 2,
#  'RT@nbcsnl': 1,
#  'RT @theTVaddict': 1,
#  'snl': 2,
#  'Kiersten Wig': 1,
#  'kristinwiigandwillferrell': 1,
#  "Amy Poelher's": 43,
#  'Quentin Tarantin': 15,
#  'Will Ferrill': 1,
#  'Quentin Tara': 1,
#  'Amy Host': 1,
#  'Perez': 1,
#  'Quentin': 3,
#  'Quentin Tar': 2,
#  'Neil Patrick Harris': 2,
#  'kristen wiig': 1,
#  'Tommy Lee Jones': 1,
#  'Kristin Wiig &': 1,
#  'RT @MKMathews': 1,
#  'Kristen Bell': 1,
#  'Oprah Winfrey': 1,
#  'Megan Fox': 1,
#  'jimmy': 1,
#  'BeverlyHilton': 2,
#  "Kristen Wiig's": 1,
#  'Demi Moore': 1,
#  'Will Farell': 1,
#  'Amy Poelher’s': 2,
#  'Lorne Michaels': 9,
#  'Helena Bonham Carter': 9,
#  'Lorne': 9,
#  'de mala': 2,
#  'hostia de Tommie Lee Jones': 2,
#  'Martin Short': 1,
#  'kristin': 1,
#  'RT @willestyle': 1,
#  'Fred Armisen': 1,
#  '😉': 1,
#  'EntertainmentKingandQueen': 1,
#  'Les Miles': 2,
#  'Love Wiig': 1,
#  'Farrell': 1,
#  'Stallone': 4,
#  'Schwarzenegger': 4,
#  'Jimmy Fallon': 5,
#  '@GhostfaceKnitta': 1,
#  'Opening Monologue': 11,
#  '@ybbilbaert': 1,
#  'Daniel W. Shrigley': 1,
#  'Host': 2,
#  'Soo Kristen': 1,
#  'Cohen': 13,
#  'Bien': 1,
#  'Tiny Fey': 2,
#  'Borat': 1,
#  'Howie Mandel': 2,
#  'nascar': 2,
#  'Kevin Costner': 3,
#  'Ed Harris': 3,
#  'George Clooney': 2,
#  'GoldenGlobe': 1,
#  "George clooney's": 1,
#  'glush': 2,
#  "George Clooney's": 7,
#  'han salido': 1,
#  'Aziz Ansari - another': 1,
#  'Robert Downey Jr.': 3,
#  'Matt Ryan': 1,
#  'tina Faye': 7,
#  'GeorgeClooney': 1,
#  'Godiva': 1,
#  'tim': 1,
#  'Mau': 1,
#  'Lea Michele': 2,
#  'WBN2013': 1,
#  "Michael J. Fox's": 3,
#  'Glenn Close': 4,
#  'Robert Downey': 1,
#  'Jr.': 1,
#  'Lena Dunham': 1,
#  "Robert Downey Jr.'s": 3,
#  'Tina Fey/Amy Poehler': 1,
#  "Jodie Foster's": 1,
#  'Ohhh lol': 1,
#  'Ghost Protocol': 1,
#  'GORGEOUS': 1,
#  'Nuzzle w/George Clooney': 1,
#  'Craig': 1,
#  'Jodie': 1,
#  'Kristen Stewart': 1,
#  "Estelle Getty's": 1,
#  'WorstDressed 10)Tina Fey': 1,
#  "L'Wren Scott": 1,
#  'Adam Corolla': 1,
#  'Seth Macfarlane': 2,
#  'Monologue': 1,
#  'Ben Affleck': 2,
#  'Ryan': 1,
#  'Adam Carolla': 1,
#  'Sarah Palin': 1,
#  'Leslie Knope': 1,
#  'Que': 1,
#  'livestreampls': 1,
#  'bagel bites': 1,
#  'RT @YahooTV': 1,
#  "Regina George's": 1,
#  'Booooooo': 1,
#  'ThisTweetWouldBeTheHost': 7,
#  'Jodie Foster': 9,
#  'Hahah': 1,
#  'GoldenBert': 4,
#  'Award Shows': 2,
#  'QT': 1,
#  'John Sheardown': 1,
#  'Actual Hosting': 1,
#  'Si Robertson': 1,
#  'Phil Robertson': 1,
#  'julia Roberts': 1,
#  'Lori': 1,
#  'Dear Seth': 1,
#  'Jen Garner': 1,
#  'GoldenGlobes  - Tina': 1,
#  'Job': 1,
#  'Sofia Vergara': 1,
#  'Glad': 1,
#  'Loved Amy': 1,
#  'Claire Danes': 1,
#  "Seth MacFarlane's": 2,
#  'Robert Downey Jr': 6,
#  'Bruce Wayne': 6,
#  'Greatest': 2,
#  'jodie foster': 1,
#  'jennifer lawrence': 1,
#  'RT@ThatEricAlper Nobody': 1,
#  'Tina Fey Hosting': 1,
#  'Soooo Tina Fey': 1,
#  'Vivier': 1,
#  '@fredleighton': 1}

# %%
# Out:
# <re.Match object; span=(0, 4), match='host'>
