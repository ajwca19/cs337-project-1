# %%
#importing necessary modules - pandas, nltk, regex, spacy, and RNG
import pandas as pd
import nltk
from nltk.tokenize import word_tokenize
from nltk.tag import pos_tag
import re
import random
import spacy
from spacy import displacy
from collections import Counter
import en_core_web_sm

nlp = en_core_web_sm.load()
nltk.download("punkt")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/adenweiser/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
# Setting up notebook to display multiple outputs in one cell
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
# Reading in and processing the gg2013 tweets file
tweets = pd.read_json('gg2013.json')

#takes in a tweet and removes the retweet and any hyperlinks
def clean_tweet(tweet_text):
    retweet_re = "^[rR][tT] @[a-zA-Z0-9_]*: "
    hyperlink_re = "http://[a-zA-Z0-9./-]*"
    hashtag_re = "#[a-zA-Z0-9_]+"
    return re.sub(hyperlink_re, "", re.sub(hashtag_re, "", tweet_text))

#read in tweets and make them nice and clean
for i in range(0, len(tweets)): 
    cleaned_tweet = clean_tweet(tweets.loc[i]['text'])
    tweets.at[i, 'text'] = cleaned_tweet
tweets

# Ceremony Name
ceremony_name = "Golden Globes 2013"
# Out:
#                                                      text  \
# 0                                          JLo's dress!
# 1       What's making Sofia Vergara's boobs stay like ...
# 2       RT @FabSugar: Kerry Washington is EVERYTHING. ...
# 3                       Anne Hathaway has got me living.
# 4                 Jennifer Lopez's lace dress? Thoughts?
# ...                                                   ...
# 174638  RT @authorViviAnna: I was sad that Mandy Patin...
# 174639  RT @_ItzelMartinez_: Jennifer Lawrence aceptan...
# 174640  Golden Globes, lots of fashion messes...but gl...
# 174641  Did they have mug shots at the golden globes?!...
# 174642  Says @BenAffleck: "I also didn't get the Actin...
#
#                                                      user                  id  \
# 0           {'screen_name': 'Dozaaa_xo', 'id': 557374298}  290620657987887104
# 1         {'screen_name': 'theAmberShow', 'id': 14648726}  290620657887219713
# 2             {'screen_name': 'SweetyPW', 'id': 35498686}  290620657828524032
# 3       {'screen_name': '_NicoleEdwards', 'id': 144430...  290620657799159809
# 4       {'screen_name': 'lolaogunnaike', 'id': 134953223}  290620657778188288
# ...                                                   ...                 ...
# 174638        {'screen_name': 'dana1204', 'id': 18091543}  290675889379876864
# 174639  {'screen_name': 'IamTrisEverdeen', 'id': 55126...  290675889128230914
# 174640   {'screen_name': 'Dpharmakis23', 'id': 852045842}  290675893024747523
# 174641  {'screen_name': 'reynaramirez22', 'id': 22732662}  290675888763314178
# 174642    {'screen_name': 'goldenglobes', 'id': 18667907}  290675893494484992
#
#               timestamp_ms
# 0      2013-01-14 00:45:38
# 1      2013-01-14 00:45:38
# 2      2013-01-14 00:45:38
# 3      2013-01-14 00:45:38
# 4      2013-01-14 00:45:38
# ...                    ...
# 174638 2013-01-14 04:25:07
# 174639 2013-01-14 04:25:07
# 174640 2013-01-14 04:25:08
# 174641 2013-01-14 04:25:08
# 174642 2013-01-14 04:25:08
#
# [174643 rows x 4 columns]

# %%
tweets_with_fashion_mention = [] #list of strings containing fashion-related-words
    
def is_fashion_relevant(tweet_text):
    fashion_keywords = ["dress", "outfit", "fashion", "red carpet", "suit", "look", "jewelry", "accessor[y|ies]"]
    for keyword in fashion_keywords:
        if re.search(keyword, tweet_text.lower()):
            return True
    return False

for i in range(0, len(tweets)):
    tweet_text = tweets.loc[i]['text']
    if is_fashion_relevant(tweet_text) and not re.search("^[Rr][Tt]", tweet_text):
        tweets_with_fashion_mention.append(tweet_text)

# %%
#TAG ENTITIES
entities_counts = {} #dictionary with key: entity name and value: number of appearances in tweets
entities_clusters = {} #dictionary with key: entity name and value: name of "representative" entity
parsed_tweets = []
for tweet in tweets_with_fashion_mention:
    parsed_tweet = nlp(tweet)
    parsed_tweets.append(parsed_tweet)
    for entity in parsed_tweet.ents:
        if entity.label_ == "PERSON" and re.match("[a-zA-Z0-9\.'’+-_@/]+", entity.text) and not re.search("\(|\)", entity.text):
            person = entity.text
            if person in entities_clusters:
                entities_counts[person] += 1
            else:
                entities_counts[person] = 1
                entities_clusters[person] = person
entities_counts

entities_to_remove = set()
entities_clusters = sorted(entities_clusters, key = lambda e : entities_counts[e], reverse = True)
for entity_a in entities_clusters:
    #print("\n\n\n ENTITY A: " + entity_a)
    for entity_b in entities_clusters:
        #print("\n ENTITY B: " + entity_b + "\n_____________\n")
        if entities_counts[entity_a] >= entities_counts[entity_b]:
            #entity a is more popular than entity b
            entity_a_tokens = entity_a.split(" ")
            entity_b_tokens = entity_b.split(" ")
            for entity_a_token in entity_a_tokens:
                #print("entity a token: " + entity_a_token)
                if len(entity_a_token) >= len(entity_b) and re.search(entity_a_token, entity_b):
                    #entities are a match! cluster them accordingly
                    #print("clustering: " + entity_b + " in group led by " + entities_clusters[entity_a] + "\n")
                    entities_clusters[entity_b] = entities_clusters[entity_a]
                    entities_to_remove.add(entity_b)
                    break
            for entity_b_token in entity_b_tokens:
                #print("entity b token:" + entity_b_token)
                if len(entity_b_token) >= len(entity_a) and re.search(entity_b_token, entity_a):
                    #entities are a match! cluster them accordingly
                    #print("clustering: " + entity_b + " in group led by " + entities_clusters[entity_a] + "\n")
                    entities_clusters[entity_b] = entities_clusters[entity_a]
                    entities_to_remove.add(entity_b)
                    break
entities_clusters
entities_to_remove

#combine counts in the entity_counts dictionary
for non_rep in entities_to_remove:
    entities_counts[entities_clusters[non_rep]] += entities_counts.pop(non_rep)

#entities_counts
# Out:
# {"Jennifer Lopez's": 21,
#  'Hugh Jackman': 18,
#  'Salmon Fishing': 3,
#  'Kerry Washington': 67,
#  'Miu Miu': 8,
#  'Natalie Morales': 2,
#  'Awkward Savannah': 1,
#  "Kerry Washington's": 17,
#  'Jlo': 21,
#  "Jennifer Lawrence's": 26,
#  'Ben Affleck': 66,
#  'George Clooney': 45,
#  'Helen Mirren': 11,
#  'Drag': 1,
#  'Jennifer Lopez': 87,
#  'Anjelica Huston': 1,
#  "Sienna Miller's": 6,
#  'Jennifer Lawrence': 187,
#  'Rachel Weisz': 3,
#  'Kristen Wiig': 28,
#  'Anne Hathaway': 151,
#  "Helen Mirren's": 3,
#  'Yuck': 5,
#  "Anne Hathaway's": 35,
#  'Kate Hudson': 193,
#  'Marion Cotillard': 17,
#  'Ewan McGregor': 4,
#  'Sienna Miller': 21,
#  "Looooove Anne Hathaway's": 1,
#  'Audrey': 1,
#  'Ricky Gervais': 4,
#  'Sofia Vergara': 28,
#  "Kate Hudson's": 61,
#  'Tina Fey': 179,
#  'Amy Poehler': 65,
#  'Matt Lauer': 4,
#  'Lea Michele': 51,
#  'Jessica Chastain': 63,
#  'Meryl Streep': 4,
#  'Paranorman': 1,
#  'Nicole Kidmans': 1,
#  'Anne Hathaways': 2,
#  'Kristin Wiig': 8,
#  'Leonardo Dicaprio': 4,
#  'Nicole Kidman': 37,
#  'Harry Winston': 2,
#  'Halle Berry': 65,
#  'Jessica Chastain/': 1,
#  'Al Roker': 6,
#  'Hysterical': 1,
#  'Claire Danes': 105,
#  'Kevin Dior': 2,
#  "Jessica Chastain's": 13,
#  'Jessica': 6,
#  'Jessica Chastian': 2,
#  'David': 1,
#  'Leonardo DiCaprio': 13,
#  'Kidman': 1,
#  'Lucy Liu': 77,
#  'Hayden Panettiere': 10,
#  'Roberto Cavalli': 4,
#  'Leo DiCaprio': 4,
#  'Julianne Moore': 49,
#  'Jessica Rabbit': 3,
#  'Salma Hayek': 24,
#  '@HeIenMirren': 1,
#  'Miranda Kerr': 14,
#  'jessica chastain': 2,
#  'Julianna': 1,
#  'Jon Hamm': 11,
#  "i'mma": 1,
#  '@siennamiller': 1,
#  'Adele': 136,
#  'Marshall': 1,
#  'Orlando Bloom': 9,
#  'Stacy Kiebler': 4,
#  'Amy': 85,
#  'Bradley Cooper': 49,
#  "Julianna Margulies'": 1,
#  'Sofia Vagara': 1,
#  'XOXO Gossip Guy': 1,
#  'Globes': 7,
#  'Emily Blunt': 20,
#  'George klooneys': 1,
#  'Ann Taylor': 1,
#  'Hathway': 1,
#  'Felt': 1,
#  'Katie Couric': 2,
#  'Rob Pattinson': 3,
#  "Steve Odekerk's": 1,
#  'Thumb': 1,
#  'Alexander McQueen  ': 3,
#  "Nicole Richie's": 1,
#  'Thatcher': 1,
#  'Seacrest': 1,
#  'Lol': 4,
#  'Damn @LeoDiCaprio': 1,
#  'Lol  ': 1,
#  'Amy Adams': 27,
#  'Marchesa': 2,
#  'anne hathaway': 6,
#  'Jessica Alba': 130,
#  '@cocoperez': 4,
#  'Stacey Keibler': 3,
#  "Julianna Marguiles'": 1,
#  'Hellloo Salma HAYAK': 1,
#  'Looking Fab': 1,
#  'Leonardo di Caprio': 1,
#  'Met Ball': 1,
#  'Burberry': 6,
#  'Stacy Keibler': 6,
#  'Mel Gibson': 59,
#  'Jack': 1,
#  'Sophia Vergara': 6,
#  'Jen': 3,
#  'Jolie': 1,
#  'Sofia Vergera': 1,
#  'Bollywood': 1,
#  'Aziz Ansari': 2,
#  '@msleamichele': 46,
#  'Lea': 14,
#  'Katherine McPhee': 7,
#  'kerry washington': 3,
#  'Blunt': 2,
#  'John Hamm': 2,
#  'Colombian Fran Drescher': 1,
#  'Isla Fisher': 6,
#  'Nicole': 3,
#  "Sofia Vergara's": 2,
#  "Amanda Seyfried's": 3,
#  'matt lauer': 1,
#  "Lorraine O'Neal": 1,
#  'Benedict Cumberbatch - Red Carpet': 1,
#  'Sarah Hyland': 3,
#  'semana teremos looks de  por lá': 1,
#  'the Sofia Vergara': 1,
#  "Lucy Liu's": 74,
#  '@Bartonth07': 1,
#  "@kellidaisy Anne's": 1,
#  "Zosia Mamet's": 1,
#  'Nicole Richie': 24,
#  'Julianne Hough': 24,
#  'Ariel Winter': 13,
#  '@Andrew_Brawley Looks': 1,
#  'Ariel...  ': 1,
#  'Alyssa Sutter': 1,
#  'Gilliana': 1,
#  'Golden Globes': 84,
#  'Taylor Swift': 123,
#  'Atelier Gown  ': 1,
#  'Amanda Seifried': 1,
#  'ainda ta': 1,
#  'Kelly Osbourne': 7,
#  'Zac Posen': 2,
#  'Taylor': 44,
#  'Lucy Lui': 11,
#  'Nana Greenbergs': 2,
#  '-BP': 1,
#  'JE MEURS AVEC': 1,
#  'MEC BORDEL': 1,
#  'Sienna': 2,
#  'Lucy Luis': 2,
#  'Kelly': 3,
#  'Que': 7,
#  'la presi': 1,
#  'antejos negros': 1,
#  'EStá': 1,
#  'Giuliana Rancic': 4,
#  'Haley Berry': 1,
#  'Que decepción las dos': 1,
#  'Qué': 3,
#  'RT @essencemag': 1,
#  "Amy Poehler's": 19,
#  'Sally': 3,
#  'Julia Louis Dreyfus': 2,
#  'Megan Fox Is Cranky': 1,
#  'Michael Cinco': 1,
#  'Omg Sara Hyland': 1,
#  "Jay Leno's": 1,
#  'Alexander McQueen': 6,
#  'Buahaha xD': 1,
#  '@cfda': 1,
#  'the Gretchen Wiener': 1,
#  'Jay Leno': 4,
#  'Julianna Margulies': 6,
#  'Jeremy Renner': 10,
#  'Que Hace @ALDORENDON': 1,
#  "Ann Hathaway's": 3,
#  'Ross': 1,
#  'Nurse Hathaway': 1,
#  'McQueen': 4,
#  "Lena Dunham's": 10,
#  'WOOOOW': 1,
#  'J. Lo': 8,
#  'Qué tal su': 1,
#  'Premio al más hortera': 1,
#  'Love Anne Hathaway': 1,
#  'Gorge': 3,
#  'Jesus': 8,
#  '@haydenpanettier': 1,
#  'Dustin Hoffman': 9,
#  "Lucy Luis's": 1,
#  'Guliana Rancic': 1,
#  "Emily Blunt's": 4,
#  'NICOLE RICHIE': 1,
#  'tan fan de las Red Carpet': 1,
#  'Esto de mirar': 1,
#  '[ Sofia Vergara': 1,
#  'Jennifer Lawrence Paid': 1,
#  'Tom Ford': 13,
#  'Ahora': 1,
#  'Rob': 14,
#  'Ryan Seacrest': 4,
#  'Linda Gray @': 1,
#  'Nene Leakes': 2,
#  'Gloria': 1,
#  'Definitivamente Gloria': 1,
#  'Aaaaaaaaaaaaah': 1,
#  'Sarah Paulson': 7,
#  'Lana Banana': 1,
#  'Michelle Dockery': 15,
#  '@popcouturejjw4': 1,
#  'julianne margulis': 1,
#  'me"-Dustin Hoffmann': 1,
#  '@Burberry': 17,
#  'Helena Bonham Carter': 8,
#  'Any Poehler': 1,
#  'Anne Hathaway de @Chanel': 1,
#  "Julianna Moore's Custom": 1,
#  'Alyssa Milano': 1,
#  'Longoria': 1,
#  'Seyfried': 1,
#  "bill belichick's": 1,
#  'Aubergine': 1,
#  'Ravens': 1,
#  'Eva Longoria': 38,
#  'Amanda Seyfried': 30,
#  'Paul Rudd': 18,
#  "Julianne Moore's": 8,
#  "Dustin Hoffman's": 1,
#  'Guilliana': 1,
#  "Loved Nicole Kidman's": 1,
#  'Winner': 1,
#  "Kate Capshaw's": 1,
#  'Crimson Chin': 1,
#  'Hayden': 3,
#  '@MARIELhaenn @robzangardi  ': 1,
#  'every1': 1,
#  "Loving Stacy Keibler's": 1,
#  'Saw Jay Leno': 1,
#  'Frankenstein': 3,
#  'w/ Sofia Vergara': 1,
#  'Katharine McPhee': 6,
#  "vanno d'accordo": 1,
#  'io volevo vederla': 1,
#  'volevo porca miseria': 1,
#  'RT @tomandlorenzo Nicole Kidman': 1,
#  'Alexander McQueen  2013': 1,
#  'Jodie Foster': 98,
#  'Yoplait': 1,
#  'Lisa Kudrow': 1,
#  'Guiliana': 3,
#  '@BCBGMAXAZRIA @Sarah_Hyland': 1,
#  'George Clooneys': 1,
#  'Stacey': 1,
#  'Naomi Watts': 7,
#  'alguien tiene': 1,
#  'dirección para': 1,
#  "Natalie Morales'": 1,
#  '@FashionBlogg': 1,
#  'esa tela de tapiz de Carolina Herrera': 1,
#  'gusta el nuevo estilo de Kelly Osbourne': 1,
#  "Amy Adams'": 2,
#  "Sally Fields'": 1,
#  'RT @BlogXilla': 1,
#  "Tina Fey's": 35,
#  'Tina': 69,
#  'Taylor Swift 1.': 1,
#  'Award': 3,
#  'Bella': 1,
#  'nuevo look Lea Michelle': 1,
#  'Bill Murray': 76,
#  'Xmas': 1,
#  'Jamie Kennedy': 1,
#  'Chillin': 1,
#  'Barbara': 3,
#  'Photo Gallery - Yahoo': 13,
#  'Tina Feys': 4,
#  'Upper Darby': 1,
#  "Bill Murray's": 4,
#  'Tina Fey + Amy Poehler': 1,
#  'Murray': 2,
#  'Jennifer Garner': 37,
#  'Amy Phoeler': 1,
#  '@melduckie': 1,
#  'GORGEOUS': 8,
#  'Bill murrahy looks old': 1,
#  'Ahhhhhhmaaaazing': 1,
#  'Claire Danes Looking': 1,
#  'Olivia Munn': 6,
#  'Nic Kidman': 1,
#  '@kzarrilli': 1,
#  "Albert Finney's": 1,
#  '@niecie797 @mini_mo': 1,
#  'bill murray': 2,
#  'cielo': 1,
#  'Tarantino': 7,
#  'Jessica Rabbit  ': 1,
#  'Zooey Deschanel': 41,
#  'Rosario Dawson': 14,
#  'Taylor Swift     ': 1,
#  'Jennifer Lawerence': 1,
#  'Amy Pohler': 3,
#  "Loving Amy's": 1,
#  "Tina Fey'S": 1,
#  'wowza': 1,
#  'kristen wiig': 1,
#  'Glenn Close': 32,
#  'Loretta Switt-esque': 1,
#  'Damn Tina Fey': 1,
#  'Damn Helen Mirren': 1,
#  'de la red carpet': 1,
#  'Ariel': 3,
#  'Liz Lemon': 1,
#  'taylor': 14,
#  'sarah hyland': 1,
#  'Selena Gomez': 8,
#  'Vanessa Hudgen': 1,
#  'Robert Downey Jr': 10,
#  'Mortimer': 2,
#  'RT @xosdlc': 1,
#  'David Faustino': 1,
#  'Dayummm Tina Fey': 1,
#  'robert pattinson': 1,
#  "Via BBC's": 1,
#  'BUT Miranda Kerr': 1,
#  'Tiny Fey': 1,
#  'Sienna Miller Golden Globes': 10,
#  'Kristen Bell': 19,
#  'Waaaah': 1,
#  'Ini': 1,
#  'Fufufu': 1,
#  'Jessica Chastain Golden': 2,
#  'Allison Williams Golden': 2,
#  'Natalie': 1,
#  'Matt': 1,
#  'Al': 1,
#  'Robby': 1,
#  'Richard Gere': 5,
#  'Mel': 8,
#  'Garnier': 1,
#  "Margaery Tyrell's": 1,
#  'Barbie': 2,
#  'Megan Fox': 50,
#  'Giorgio Armani': 2,
#  "Amy Adam's": 1,
#  'Gibson': 1,
#  'Ben': 10,
#  'ANNE': 1,
#  'Grinch': 1,
#  '@evalongoria': 1,
#  'Jessica Rabbit-esque': 1,
#  'Amy Poehlers': 1,
#  'Jennifer Garner - Affleck': 1,
#  'de Anne Hathaway': 1,
#  'Jenn Garner': 1,
#  'Robert Pattinson': 31,
#  'Julia': 4,
#  'Amy Poehler - Ladies': 1,
#  'Hilary Swank': 1,
#  '@carlymckinley': 1,
#  'Lucy Liu’s': 1,
#  '@popsugar': 3,
#  'Woooow': 1,
#  '@JennmOneto Favorite': 1,
#  'heboh tereak2': 1,
#  'mato anne hathaway': 1,
#  'Quentin Tarantino': 12,
#  'Yum': 1,
#  'Zooey Deschanel Recalls Joint Wardrobe Malfunction': 3,
#  'Donna Karan Atelier': 3,
#  'Ang Lee': 8,
#  'Mandy Patinkin': 5,
#  'BILL MURRAY': 1,
#  'Vera Wang': 1,
#  'Aziz Ansari Spoofs': 5,
#  'Daniel Day Lewis': 5,
#  '@EmilyB Tina': 1,
#  'Tintin': 1,
#  'Daniel Day-Lewis': 11,
#  '@1Mhari': 1,
#  'Kate Hudsons': 3,
#  'Rebecca Miller': 1,
#  'donna karan': 1,
#  'Kate': 14,
#  'Tasty': 1,
#  'das indicadas': 4,
#  'Nicole Kidman de de McQueen': 1,
#  'Ahhhhhhhh Lea': 1,
#  'kate hudson': 3,
#  "kate hudson's": 1,
#  "Lea Michele's": 9,
#  "Leonardo Dicaprio's": 1,
#  'Bradley': 3,
#  '@EvaLongoria': 10,
#  'un link de los Golden Globes': 2,
#  'Adele - Golden Globes': 2,
#  'Lea Michelle': 23,
#  'Freaken': 1,
#  'Goldie Hawn': 1,
#  'a Bob Mackie': 1,
#  'Ann': 2,
#  'Je...': 1,
#  'Photo Gallery -': 1,
#  'Tommy Lee Jones': 78,
#  'Alexis Carrington': 1,
#  'Tommy lee jones': 5,
#  "Taylor Swift's": 11,
#  '@stephfedorov': 1,
#  'Leo': 10,
#  'Selma Hayek': 10,
#  'Flash Gordon': 1,
#  'Babyface': 1,
#  "Rob Pattinson's": 2,
#  'Omg Christoph Waltz': 1,
#  'Daniel Craig': 11,
#  'Leonardo': 4,
#  'Christoph Waltz': 10,
#  'Debra Messing': 7,
#  'Tom': 2,
#  'Marky Mark': 1,
#  'Abe Lincoln': 1,
#  'Hudson': 1,
#  '@katehudson': 2,
#  '@Katehudson': 1,
#  'Rip Van Winkle': 1,
#  'Damn Leonardo Dicaprio': 2,
#  'RT': 1,
#  'ardan los ojos': 1,
#  'Jew Hunter': 1,
#  '@redbookmag': 1,
#  'bradley cooper': 1,
#  'Glee': 2,
#  'Leo Dicaprio': 1,
#  'Mierda': 1,
#  'Mmm Leonardo': 1,
#  'wow jennifer': 1,
#  'Omg Kerry Washington': 1,
#  'Kerry Washington KILLS': 1,
#  'Kerry': 9,
#  'Dennis Quaid': 12,
#  '@MsSarahPaulson': 1,
#  'Kerry w': 1,
#  'Hey Kerry': 1,
#  'Blake': 1,
#  'Leonardo Decaprio': 1,
#  'dick Lea': 1,
#  'Hayden Paneittiere': 1,
#  'Dennis Quads': 1,
#  'Dennis': 1,
#  '@KateHudson': 1,
#  'GORGEOUS  ': 1,
#  'Ariel RT@NickFlora:': 1,
#  'Kerri Washington': 1,
#  'Lucy Lieu': 1,
#  'Benedict': 7,
#  'Dennis Quaids': 1,
#  'Lena Dunham': 40,
#  "Jessica Alba's": 13,
#  'Maggie Smith': 3,
#  'jessica alba': 1,
#  'Malibu Barbie': 1,
#  'James Cameron': 3,
#  'Archie Panjabi': 1,
#  'Yessss': 1,
#  'Assistindo': 1,
#  'Randy Quaid': 1,
#  'Oliver Stone': 1,
#  'Sofia Vargara': 1,
#  'yo veo el': 1,
#  'GOREGOUS': 1,
#  'WANNA': 1,
#  'Beautifulllllllll': 1,
#  'a Ben Affleck': 1,
#  'Lo': 2,
#  'mal koegjfkejgegjt': 1,
#  'Hug': 1,
#  'Miren Adele': 1,
#  'Monique Lhuillier': 3,
#  'Vanessa Hudgens': 5,
#  'Michael Kors': 5,
#  'Mark Cuban': 1,
#  'Coldwell Banker': 1,
#  'Django Unchained': 1,
#  'Taylor Swift Gorgeous On The Red Carpet': 1,
#  'Estamos': 2,
#  'Ed Hardy': 1,
#  'Sofia Veraga': 1,
#  'Halle Berry Golden Globes Dress': 7,
#  'Halley Berry': 3,
#  'Eric Stonestreet': 1,
#  'Julia Louis-Dreyfus Keep': 1,
#  'Julianne Moore Golden': 11,
#  'Eva': 5,
#  'Nene': 2,
#  "Eva Longoria's": 16,
#  'Don Cheadle': 10,
#  'Sam Fox': 9,
#  'dresssss&gt;&gt;&gt;&gt': 1,
#  'Michael J Fox': 4,
#  'sam fox...': 1,
#  'Michael J. Fox': 8,
#  'Eva longoria': 4,
#  "Michael J Fox's": 12,
#  "Michael J. Fox's": 20,
#  'MICHAEL J. FOX': 1,
#  'Sam fox looks': 1,
#  'Angelina Jolie': 3,
#  "Michael J. Fox'": 2,
#  'Damn Eva Longoria': 1,
#  'Sam': 2,
#  'WOWOWOWOWOWOWOWW Eva Longoria': 1,
#  'Alex P Keaton': 1,
#  'Pure Fah-shon': 1,
#  'Julian Moore': 2,
#  'Brian Austin Green': 1,
#  'Kerrys': 3,
#  'Kim Kardashian': 1,
#  'Helena Bonham Carter Golden Globes Dress': 7,
#  'Tony Parker': 1,
#  'Michael': 2,
#  'Glad': 3,
#  'GoldenGlobes': 1,
#  'Alex P. Keaton': 1,
#  "Loving Eva's": 1,
#  'Patrick Adams': 1,
#  '@zacposen': 1,
#  'Jonathan': 3,
#  'Danny Strong': 1,
#  'A. Richard Gere': 1,
#  'B. Leo': 1,
#  'RT @amyodell': 1,
#  'Versace': 5,
#  "Halle Berry's": 16,
#  'John Shearer  ': 1,
#  '@evalongoria smokin': 1,
#  'Linda': 1,
#  'Marty MCfly': 1,
#  'Bitch': 1,
#  'Angie': 1,
#  'James Bond': 2,
#  'Kaley Cuoco': 2,
#  'Diulang': 1,
#  'ini Megan': 1,
#  'Quaalude': 1,
#  'Jennifer Lawrence Amy Adams': 1,
#  'Pica Nutalli': 1,
#  'Si los  Fuesen': 1,
#  'haria el tierrudo de la': 1,
#  'mistook sarah paulson': 1,
#  'ALLYN GOLDEN': 1,
#  "Allison Williams'": 1,
#  "Nicole Kidman's": 4,
#  'Chris Farley': 1,
#  "Sienna  Miller's": 1,
#  'Micheal J. Fox': 1,
#  '@KeithUrban Woo': 1,
#  'Jessica Lange': 12,
#  'Katharine McPhee Flashes': 2,
#  'Sideboob': 2,
#  'Adele Debuts Post-Baby Body': 12,
#  'Jullianne Hough': 1,
#  'Taylor Swift Wears Sexy': 4,
#  'Zac Posen Gown': 2,
#  'Eva L': 2,
#  'JULIANNE MOORE': 1,
#  'jeeeez': 1,
#  'Oscar Snubs': 10,
#  '@NewsOnKidman': 1,
#  'Mary': 2,
#  'Julianne': 4,
#  'Joan Rivers': 8,
#  'Jullian Moore': 1,
#  'Julianne Morre': 2,
#  'Look Julianne': 1,
#  "Julianne Hough's": 7,
#  'Vanessa': 1,
#  'Julieanne Moore': 1,
#  '@mtvstyle': 3,
#  'Taylor Swifts': 2,
#  'kinda blah  ': 1,
#  'encantaron las tendencias': 1,
#  '-Emily Blunt  ': 1,
#  'Catherine Zeta - Jones': 1,
#  'Catherine Zeta-Jones': 4,
#  'Bi Polar Zeta-Jones': 1,
#  "Catherine Zeta-Jones'": 2,
#  'Catherine': 2,
#  "Catherine Zeta Jones'": 2,
#  'Marty McFly': 2,
#  'Catherine Zeta Jones': 9,
#  'catherine zeta jonest': 1,
#  'Catherine Zeta': 1,
#  'Catharine Zeta-Jones': 1,
#  'Catherine Zeta Johns': 1,
#  '@Coops_tv': 1,
#  'Julianne moore': 1,
#  'Darcy St. Fudge': 1,
#  'mañana Joan Rivers': 1,
#  'hará sentir': 1,
#  'Les Misérables': 1,
#  "Catherine Zeta-Jones's": 1,
#  'Peter Pan': 1,
#  'Kelly Osborn': 1,
#  'sienna miller': 1,
#  'Lovin Old Hollywood': 1,
#  'Huff': 1,
#  "J. Lo's": 9,
#  'venus williams': 1,
#  'angelina jolie looks': 1,
#  'Kelly O. es de Fashion': 1,
#  '@NeNeLeakes Getty Images': 1,
#  'TSwift': 1,
#  '@RSVPMagazine Jennifer Lawrence': 1,
#  'amp;Hallie Berry': 1,
#  'Catherine zeta jones': 1,
#  'catherine zeta jones': 1,
#  'Allison': 1,
#  'Ann Hathaway': 6,
#  'Julianna Moore': 1,
#  'Halle Barry': 1,
#  'Donna Karan': 2,
#  'Hayden Panettier': 1,
#  "Sarah Palin's": 1,
#  'Doily': 1,
#  'Robert Downey Jr.': 9,
#  'Safe Haven': 1,
#  'Francesca Eastwood': 1,
#  'Tracy Pollen': 1,
#  'j.lo': 2,
#  'Ohmygod Taylor': 1,
#  "Tom Ford's": 1,
#  'Katherine Zeta Jones': 1,
#  'Enamel Earring': 1,
#  'Robert Pattinson News - Rob': 1,
#  'Presenters Robert': 1,
#  'eva longoria': 1,
#  'Liza Minelli': 4,
#  'Zsa Zsa Gabor': 1,
#  'Liza Minelli LOL': 1,
#  'MICHAEL J': 1,
#  'Keepin': 1,
#  'mañana': 1,
#  'Liza': 1,
#  'Liborace': 1,
#  'Michael J Foxs': 1,
#  'Jeremy Irons': 21,
#  'Taylor Swift - Golden': 1,
#  'Halle Looks': 1,
#  'Ooh': 1,
#  'Helen Hunt': 9,
#  '@Eva Longoria Look': 1,
#  'Thandie Newton': 2,
#  'Hall Berry': 1,
#  "Rosario Dawson's": 6,
#  'Jennifer Lawrance': 1,
#  'Liza Minnelli': 1,
#  'Ohhhhhh Rosario Dawson': 1,
#  'Sorry Rosario Dawson': 1,
#  "Liza Minelli's": 1,
#  "Terri Schiavo's": 1,
#  'Hillary Clinton': 2,
#  'Ro-Daws': 1,
#  'judy jetson': 1,
#  'Gross': 1,
#  'Silver Fox': 1,
#  'Matt Leblanc': 4,
#  'Helen': 1,
#  'Rosie Huntington-Whiteley': 1,
#  'Matt LeBlanc': 5,
#  'Vivienne Westwood Couture': 1,
#  'Salma': 3,
#  'Latinas': 1,
#  "Damien Lewis's": 1,
#  'Steve': 1,
#  "Kaley Cuoco's": 2,
#  'DAANNGGGG': 1,
#  'Deborah Lippman': 1,
#  'Steven': 1,
#  'Joey': 2,
#  'Will McAvoy': 1,
#  'Selma Hayak': 2,
#  'Damien Lewis': 2,
#  'Hugh Laurie': 1,
#  'Brody': 3,
#  'Damian Lewis': 2,
#  'Steve Buscemi': 2,
#  'Golden Globe': 3,
#  'Marty Jr': 1,
#  'Marion Cotillard de @Dior': 2,
#  'Jajaja': 1,
#  'Holllaaaa': 1,
#  '@joandiminich': 1,
#  'Não vou': 1,
#  'muito': 1,
#  'Mmm Leonardo DiCaprio': 1,
#  'Jackie Weaver': 1,
#  'Regina George': 1,
#  '@ivllagecanada': 1,
#  "Salma Hayek's": 1,
#  'Kerry @GoldenGlobes Dress': 2,
#  'Allen Luddon': 1,
#  'da Taylor': 1,
#  'ela tá': 1,
#  'mais linda': 1,
#  'Whoah': 1,
#  'Saudades Justin Bieber': 1,
#  'gato de': 1,
#  'Harry Potter': 2,
#  'paul': 1,
#  'Claire': 6,
#  'Ava': 1,
#  'Clare Danes': 4,
#  "Jennifer Garner's": 6,
#  'Vivienne Westwood': 2,
#  '@AnnTaylor': 5,
#  'Tina Looking': 1,
#  'Hopes She': 3,
#  "Claire Danes'": 8,
#  'Calvin Klein': 5,
#  'Michael J. Foxs': 1,
#  'Mine': 1,
#  'Selena': 1,
#  'jennifer lawrence': 3,
#  'mel gibson': 1,
#  'Dana Brody': 1,
#  "Zooey Deschanel's": 2,
#  'Evan Longoria': 1,
#  'Mel Gib': 1,
#  'Helen McCrory': 1,
#  "Katharine McPhee's": 1,
#  "Kelly Osbourne's": 1,
#  'jamie': 1,
#  "Morena Baccarin's": 1,
#  'Halle Berry Allen': 1,
#  'Olivia Longoria Allen': 1,
#  'Saw Claire Danes': 1,
#  'Angela Chase': 1,
#  '@SavannahGuthrie You': 1,
#  'Holler Homeland': 1,
#  "Love Anne Hathaway's": 2,
#  'Adele Debuts': 2,
#  'ko lang': 1,
#  'tinignan e.pati yung blog sa golden': 1,
#  'ako ng': 1,
#  'Dana': 1,
#  'kannie': 1,
#  '@CELEBUZZ': 4,
#  'Emily Blunt de @MichaelKors': 1,
#  'Megan Fox - Here': 1,
#  "John Goodman's": 1,
#  'Jon': 1,
#  'Jon Bon Jovi': 3,
#  '@kerrywashington': 3,
#  'Givenchy': 1,
#  'john goodman': 1,
#  'Tony Mendez': 4,
#  'Guy': 1,
#  'RT @RollingOut': 1,
#  'John Goodman': 4,
#  'Betty White': 4,
#  'Ben Afleck': 2,
#  'lt;3 John Goodman': 1,
#  'jon Bon Jovi': 1,
#  'Clooney': 2,
#  'Dick Tracy': 1,
#  'Jennifer Lopez - Golden': 8,
#  'Jessica Chastain - Golden': 1,
#  'Sienna Miller &': 1,
#  'Jennifer Lopez SEMPRE': 1,
#  'hora de escolher': 1,
#  'Jennifer': 17,
#  'JoLo': 1,
#  'J-Lo': 10,
#  'Se fue': 1,
#  'como salía': 1,
#  'J Lo': 12,
#  'Jennifer Lopez - WOW': 1,
#  "Ben Affleck's": 4,
#  'Cher': 3,
#  'Jo Lo': 1,
#  'J.lo': 3,
#  "Jason Statham's": 2,
#  "J Lo's": 5,
#  'Jenny': 3,
#  'Lovin': 3,
#  'Selena Gomez Looks': 1,
#  'Dang': 2,
#  'Raquel Welch': 1,
#  'Hey J Lo': 1,
#  "Scarlett O'Hara": 1,
#  "J-Lo's": 4,
#  'Beyonce': 3,
#  '@MsLeaMichele': 2,
#  'God Bless Jennifer Lopez': 1,
#  "Jennifer Lopez'": 3,
#  'J.Lo': 3,
#  'Jay-Lo': 1,
#  'Granny': 1,
#  'Jennifer Anniston': 1,
#  'John Williams': 1,
#  'Gosshhh Anne': 1,
#  'Jennifer Lopez=': 1,
#  'Makeup Look': 1,
#  'Cake Boss': 1,
#  'RT @Lyfelong': 1,
#  'viendo la': 1,
#  'abuuuurrrroooo': 1,
#  'Michael Danna': 1,
#  'Tony Hawk': 1,
#  'Rockin': 1,
#  'Jason Statham': 6,
#  'Rosie Perez': 1,
#  'Spanx': 1,
#  'Elie Saab': 10,
#  'Ah-ma-zing': 1,
#  'RT @OKMagazine': 1,
#  'Bahahahaha RT @MARLONLWAYANS': 1,
#  'Parks': 2,
#  'Ok Eva Longoria': 1,
#  'Yoshiki': 1,
#  "Jennifer Lopez 's": 1,
#  'RT @ETonlineAlert Gleeks': 1,
#  'Bob Mackie Barbie': 1,
#  'jon bon': 1,
#  'Jennifer Looks': 1,
#  'Klingon': 1,
#  'Lace': 2,
#  'Mychael Danna "': 1,
#  'Lasheng': 1,
#  'Lols': 1,
#  'Mira @JLo': 1,
#  'dale chica': 1,
#  'Liked Skyfall': 1,
#  'Latina': 2,
#  'EMILY': 1,
#  '@rolandsmartin Jennifer': 1,
#  'Jennifer Lopez Shows': 1,
#  'Tay Tay': 2,
#  'XD': 1,
#  'pat': 1,
#  'Best Song': 1,
#  'Statham': 1,
#  'Jon Jon': 1,
#  'dk': 1,
#  'oooooh taylor': 1,
#  'ella ganó': 1,
#  'su mismo': 1,
#  'Greg': 1,
#  'Eliza Doolittle': 1,
#  'Hubba': 1,
#  "Jon Bon Jovi's": 1,
#  'Woahhhhhh': 1,
#  'Jody Foster': 7,
#  'Twitter': 4,
#  'Aaarrgghhh': 1,
#  "Leonardo DiCaprio's": 1,
#  'Globes Taylor Swift': 1,
#  'Julliane Hough': 1,
#  'Claire Danes - Golden': 1,
#  'Amy Adams - Golden': 1,
#  'Lol Taylor Swift': 1,
#  'Lol You': 1,
#  'Idk': 1,
#  '@GLEEonFOX Lea Michele Is Ethereal': 2,
#  'Allison Williams': 7,
#  'Gave Adele': 1,
#  'Adele ganhou merecidamente': 1,
#  'Ela arrasa': 1,
#  'ya adele': 1,
#  'Eddie Redmayne': 6,
#  'Yay Adele': 1,
#  'RT Adele Debuts': 1,
#  'Jennifer Lopez Golden Globes': 1,
#  'Moi aussi.': 1,
#  'Taylor Swift’s': 1,
#  'Harry Styles': 1,
#  "Marion Cottiard's": 1,
#  'Salma n Eva': 1,
#  'Paul Epworth': 1,
#  'lea michele': 1,
#  'Adele FTW': 1,
#  'Omg Jessica': 1,
#  'Kevin Costner': 23,
#  'Ohhh Jessica': 1,
#  'Jeeeez': 1,
#  'Benedict Cumberbatch': 5,
#  'TIm Gunn': 1,
#  'Johnny': 6,
#  'RT @LanceUlanoff': 1,
#  'Kiefer Sutherland': 1,
#  'Michelle Williams': 1,
#  'Fuuuuuuuuuuuuuuuuuuuuuuu Y U LOOK SO': 1,
#  'jessica albas': 1,
#  'Song': 1,
#  'Keifer Sutherland': 1,
#  'Bonham Carter': 3,
#  'J.Lo  ': 1,
#  'David Bowie': 1,
#  'Damn Johnny': 1,
#  'Terry Allen': 1,
#  'Lila': 1,
#  'Johnny Depp - ha': 1,
#  'Lady Gaga': 1,
#  'Costner': 2,
#  "Kevin Costner's": 1,
#  'Louis CK': 2,
#  'Reality Bites': 1,
#  'Hubby': 1,
#  'Adele Taylor': 1,
#  'Kiebler': 1,
#  'Sharing': 1,
#  '@KChenoweth hahaha': 1,
#  '-GM': 1,
#  'Any Polher': 1,
#  'Naeem Kahn': 1,
#  'Juilianne Hough': 1,
#  'Harvey Weinstein': 1,
#  "Looove JAlba's": 1,
#  'kevin costner': 1,
#  "Jessica Abla's": 1,
#  'Clinton': 12,
#  'Swift': 1,
#  'Bill Clinton': 40,
#  'Hilary Clinton': 1,
#  'Bill': 5,
#  'Darrell Hammond': 1,
#  'Jennifer Lopez Shows Serious Skin': 1,
#  'Clint Eastwood': 1,
#  'Bubba': 2,
#  'Hillary': 1,
#  'Willy Clinton': 1,
#  'George W': 1,
#  'Ooooo': 2,
#  'Gorgas': 1,
#  "Bill Clinton's": 1,
#  '@jerrycferrara \nAdele': 1,
#  'bill clinton': 2,
#  'Fitter': 1,
#  'Billy C. kinda': 1,
#  'Lewinsky': 1,
#  'Romulan': 1,
#  'feliz de que haya': 1,
#  'Spielberg': 2,
#  '@DGJGodwin': 1,
#  'spencerbarnesla': 1,
#  "Kristen Wig's": 1,
#  'Kristin': 5,
#  'Jamie Foxx': 9,
#  'Samuel Jackson': 1,
#  'encanta su': 1,
#  'Kristen': 13,
#  "Kristin Wiig's": 4,
#  'kristin wig': 1,
#  'Golden Globes - Us Magazine': 1,
#  'Bruce Willis': 1,
#  'Anjelica Houston': 2,
#  'Joker': 2,
#  'Eep': 1,
#  'Will Farrell': 2,
#  'Ron Burgundy': 1,
#  'muito casual': 1,
#  'concordo': 1,
#  'Kristin Wigg': 1,
#  'swag': 1,
#  'Anjelica': 1,
#  'A. Houston': 1,
#  'Ohhh Mini J. Fox': 1,
#  'Marty': 1,
#  'Mitt Romney': 1,
#  "Kristen Wiig's": 7,
#  'Colorful Jennifer': 1,
#  'RT @vogueoz\n': 1,
#  'NOOOOWW': 1,
#  'Kristen Wig': 4,
#  'Will Ferrell': 8,
#  'Diane Keaton': 1,
#  'Rona Pfeiffer': 1,
#  'Steven Spielberg': 1,
#  'Alison Williams': 2,
#  'Garth Brooks': 1,
#  'Will': 1,
#  'Tom Selleck': 1,
#  'Emmy Rossum': 1,
#  'Kristen Wing': 1,
#  'Kristen Wigg': 1,
#  'Hollywood Dentists': 1,
#  'Bahaha': 1,
#  "Liked Kristen's": 1,
#  'Tommy Lee': 6,
#  ...}
# {"Jennifer Lopez's": "Jennifer Lopez's",
#  'Hugh Jackman': 'Hugh Jackman',
#  'Salmon Fishing': 'Salmon Fishing',
#  'Kerry Washington': 'Kerry Washington',
#  'Miu Miu': 'Miu Miu',
#  'Natalie Morales': 'Natalie Morales',
#  'Awkward Savannah': 'Awkward Savannah',
#  "Kerry Washington's": "Kerry Washington's",
#  'Jlo': 'Jlo',
#  "Jennifer Lawrence's": "Jennifer Lawrence's",
#  'Ben Affleck': 'Ben Affleck',
#  'George Clooney': 'George Clooney',
#  'Helen Mirren': 'Helen Mirren',
#  'Drag': 'Drag',
#  'Jennifer Lopez': 'Jennifer Lopez',
#  'Anjelica Huston': 'Anjelica Houston',
#  "Sienna Miller's": "Sienna Miller's",
#  'Jennifer Lawrence': 'Jennifer Lawrence',
#  'Rachel Weisz': 'Rachel Weisz',
#  'Kristen Wiig': 'Kristen Wiig',
#  'Anne Hathaway': 'Anne Hathaway',
#  "Helen Mirren's": "Helen Mirren's",
#  'Yuck': 'Yuck',
#  "Anne Hathaway's": "Anne Hathaway's",
#  'Kate Hudson': 'Kate Hudson',
#  'Marion Cotillard': 'Marion Cotillard',
#  'Ewan McGregor': 'Ewan McGregor',
#  'Sienna Miller': 'Sienna Miller',
#  "Looooove Anne Hathaway's": "Anne Hathaway's",
#  'Audrey': 'Audrey Hepburn',
#  'Ricky Gervais': 'Ricky Gervais',
#  'Sofia Vergara': 'Sofia Vergara',
#  "Kate Hudson's": "Kate Hudson's",
#  'Tina Fey': 'Tina Fey',
#  'Amy Poehler': 'Amy',
#  'Matt Lauer': 'Matt Lauer',
#  'Lea Michele': 'Lea Michele',
#  'Jessica Chastain': 'Jessica Chastain',
#  'Meryl Streep': 'Meryl Streep',
#  'Paranorman': 'Paranorman',
#  'Nicole Kidmans': 'Nicole Kidman',
#  'Anne Hathaways': "Anne Hathaway's",
#  'Kristin Wiig': 'Kristin Wiig',
#  'Leonardo Dicaprio': 'Leonardo DiCaprio',
#  'Nicole Kidman': 'Nicole Kidman',
#  'Harry Winston': 'Harry Winston',
#  'Halle Berry': 'Halle Berry',
#  'Jessica Chastain/': "Jessica Chastain's",
#  'Al Roker': 'Al Roker',
#  'Hysterical': 'Hysterical',
#  'Claire Danes': 'Claire Danes',
#  'Kevin Dior': 'Kevin Dior',
#  "Jessica Chastain's": "Jessica Chastain's",
#  'Jessica': 'Jessica Lange',
#  'Jessica Chastian': "Jessica Chastain's",
#  'David': 'David',
#  'Leonardo DiCaprio': 'Leonardo DiCaprio',
#  'Kidman': 'Alexander McQueen',
#  'Lucy Liu': 'Lucy Liu',
#  'Hayden Panettiere': 'Hayden Panettiere',
#  'Roberto Cavalli': 'Roberto Cavalli',
#  'Leo DiCaprio': 'Leo',
#  'Julianne Moore': 'Julianne Moore',
#  'Jessica Rabbit': "Jessica Chastain's",
#  'Salma Hayek': 'Salma Hayek',
#  '@HeIenMirren': '@HeIenMirren',
#  'Miranda Kerr': 'Miranda Kerr',
#  'jessica chastain': 'jessica chastain',
#  'Julianna': 'Julianna',
#  'Jon Hamm': 'Jon Hamm',
#  "i'mma": "i'mma",
#  '@siennamiller': '@siennamiller',
#  'Adele': 'Adele',
#  'Marshall': 'Marshall',
#  'Orlando Bloom': 'Orlando Bloom',
#  'Stacy Kiebler': 'Stacy Kiebler',
#  'Amy': 'Amy',
#  'Bradley Cooper': 'Bradley Cooper',
#  "Julianna Margulies'": 'Julianna',
#  'Sofia Vagara': 'Sofia Vagara',
#  'XOXO Gossip Guy': 'XOXO Gossip Guy',
#  'Globes': 'Globes',
#  'Emily Blunt': 'Emily Blunt',
#  'George klooneys': 'George klooneys',
#  'Ann Taylor': "Ann Hathaway's",
#  'Hathway': 'Hathway',
#  'Felt': 'Felt',
#  'Katie Couric': 'Katie Couric',
#  'Rob Pattinson': 'Rob',
#  "Steve Odekerk's": "Steve Odekerk's",
#  'Thumb': 'Thumb',
#  'Alexander McQueen  ': 'Alexander McQueen',
#  "Nicole Richie's": 'Nicole Kidman',
#  'Thatcher': 'Thatcher',
#  'Seacrest': 'Ryan Seacrest',
#  'Lol': 'Lol',
#  'Damn @LeoDiCaprio': 'Damn @LeoDiCaprio',
#  'Lol  ': 'Lol',
#  'Amy Adams': 'Amy',
#  'Marchesa': 'Marchesa',
#  'anne hathaway': 'anne hathaway',
#  'Jessica Alba': 'Jessica Alba',
#  '@cocoperez': '@cocoperez',
#  'Stacey Keibler': 'Stacey Keibler',
#  "Julianna Marguiles'": 'Julianna',
#  'Hellloo Salma HAYAK': 'Salma Hayek',
#  'Looking Fab': 'Looking Fab',
#  'Leonardo di Caprio': 'Leonardo DiCaprio',
#  'Met Ball': 'Met Ball',
#  'Burberry': 'Burberry',
#  'Stacy Keibler': 'Stacy Keibler',
#  'Mel Gibson': 'Mel Gibson',
#  'Jack': 'Jack',
#  'Sophia Vergara': 'Sophia Vergara',
#  'Jen': 'Jen',
#  'Jolie': 'Jolie',
#  'Sofia Vergera': 'Sofia Vergera',
#  'Bollywood': 'Bollywood',
#  'Aziz Ansari': 'Aziz Ansari',
#  '@msleamichele': '@msleamichele',
#  'Lea': 'Lea Michelle',
#  'Katherine McPhee': 'Katherine McPhee',
#  'kerry washington': 'kerry washington',
#  'Blunt': 'Emily Blunt',
#  'John Hamm': 'John Hamm',
#  'Colombian Fran Drescher': 'Colombian Fran Drescher',
#  'Isla Fisher': 'Isla Fisher',
#  'Nicole': "Nicole Kidman's",
#  "Sofia Vergara's": "Sofia Vergara's",
#  "Amanda Seyfried's": "Amanda Seyfried's",
#  'matt lauer': 'matt lauer',
#  "Lorraine O'Neal": "Lorraine O'Neal",
#  'Benedict Cumberbatch - Red Carpet': 'Benedict',
#  'Sarah Hyland': 'Sarah Hyland',
#  'semana teremos looks de  por lá': 'semana teremos looks de  por lá',
#  'the Sofia Vergara': 'the Sofia Vergara',
#  "Lucy Liu's": "Lucy Liu's",
#  '@Bartonth07': '@Bartonth07',
#  "@kellidaisy Anne's": "@kellidaisy Anne's",
#  "Zosia Mamet's": "Zosia Mamet's",
#  'Nicole Richie': 'Nicole Richie',
#  'Julianne Hough': 'Julianne Hough',
#  'Ariel Winter': 'Ariel Winter',
#  '@Andrew_Brawley Looks': '@Andrew_Brawley Looks',
#  'Ariel...  ': 'Ariel...  ',
#  'Alyssa Sutter': 'Alyssa Sutter',
#  'Gilliana': 'Gilliana',
#  'Golden Globes': 'Golden Globes',
#  'Taylor Swift': 'Taylor Swift',
#  'Atelier Gown  ': 'Atelier Gown  ',
#  'Amanda Seifried': 'Amanda Seifried',
#  'ainda ta': 'ainda ta',
#  'Kelly Osbourne': 'Kelly Osbourne',
#  'Zac Posen': 'Zac Posen',
#  'Taylor': 'Taylor Swift',
#  'Lucy Lui': "Lucy Liu's",
#  'Nana Greenbergs': 'Nana Greenbergs',
#  '-BP': '-BP',
#  'JE MEURS AVEC': 'JE MEURS AVEC',
#  'MEC BORDEL': 'MEC BORDEL',
#  'Sienna': 'Sienna Miller’s',
#  'Lucy Luis': "Lucy Liu's",
#  'Kelly': 'Kelly Osbourne',
#  'Que': 'Que',
#  'la presi': 'la presi',
#  'antejos negros': 'antejos negros',
#  'EStá': 'EStá',
#  'Giuliana Rancic': 'Giuliana Rancic',
#  'Haley Berry': 'Hallie Berry',
#  'Que decepción las dos': 'Que',
#  'Qué': 'Qué',
#  'RT @essencemag': 'RT @xosdlc',
#  "Amy Poehler's": 'Amy',
#  'Sally': 'Sally Field',
#  'Julia Louis Dreyfus': 'Julia',
#  'Megan Fox Is Cranky': 'Stun',
#  'Michael Cinco': "Michael J. Fox'",
#  'Omg Sara Hyland': 'Omg Sara Hyland',
#  "Jay Leno's": "Jay Leno's",
#  'Alexander McQueen': 'Alexander McQueen',
#  'Buahaha xD': 'Buahaha xD',
#  '@cfda': '@cfda',
#  'the Gretchen Wiener': 'the Gretchen Wiener',
#  'Jay Leno': 'Jay Leno',
#  'Julianna Margulies': 'Julianna Margulies',
#  'Jeremy Renner': 'Jeremy Renner',
#  'Que Hace @ALDORENDON': 'Que',
#  "Ann Hathaway's": "Ann Hathaway's",
#  'Ross': 'Ross',
#  'Nurse Hathaway': 'Ann Hathaway',
#  'McQueen': 'Alexander McQueen',
#  "Lena Dunham's": 'Lena Dunham',
#  'WOOOOW': 'WOOOOW',
#  'J. Lo': 'J. Lo',
#  'Qué tal su': 'Qué',
#  'Premio al más hortera': 'Premio al más hortera',
#  'Love Anne Hathaway': 'Ann Hathaway',
#  'Gorge': 'Gorge',
#  'Jesus': 'Jesus',
#  '@haydenpanettier': '@haydenpanettier',
#  'Dustin Hoffman': 'Dustin Hoffman',
#  "Lucy Luis's": "Lucy Liu's",
#  'Guliana Rancic': 'Guliana Rancic',
#  "Emily Blunt's": "Emily Blunt's",
#  'NICOLE RICHIE': 'NICOLE RICHIE',
#  'tan fan de las Red Carpet': 'tan fan de las Red Carpet',
#  'Esto de mirar': 'Esto de mirar',
#  '[ Sofia Vergara': '[ Sofia Vergara',
#  'Jennifer Lawrence Paid': 'Jennifer Garner',
#  'Tom Ford': 'Tom Ford',
#  'Ahora': 'Ahora',
#  'Rob': 'Rob',
#  'Ryan Seacrest': 'Ryan Seacrest',
#  'Linda Gray @': 'Linda Gray @',
#  'Nene Leakes': 'Nene Leakes',
#  'Gloria': 'Gloria',
#  'Definitivamente Gloria': 'Gloria',
#  'Aaaaaaaaaaaaah': 'Aaaaaaaaaaaaah',
#  'Sarah Paulson': 'Sarah Paulson',
#  'Lana Banana': 'Lana Banana',
#  'Michelle Dockery': 'Michelle Dockery',
#  '@popcouturejjw4': '@popcouturejjw4',
#  'julianne margulis': 'julianne margulis',
#  'me"-Dustin Hoffmann': 'me"-Dustin Hoffmann',
#  '@Burberry': '@Burberry',
#  'Helena Bonham Carter': 'Helena Bonham Carter',
#  'Any Poehler': 'Any Poehler',
#  'Anne Hathaway de @Chanel': 'Ann Hathaway',
#  "Julianna Moore's Custom": 'Julianna',
#  'Alyssa Milano': 'Alyssa Milano',
#  'Longoria': 'Eva Longoria - Golden',
#  'Seyfried': 'Amanda Seyfried - Golden',
#  "bill belichick's": "bill belichick's",
#  'Aubergine': 'Aubergine',
#  'Ravens': 'Ravens',
#  'Eva Longoria': 'Eva Longoria',
#  'Amanda Seyfried': 'Amanda Seyfried',
#  'Paul Rudd': 'Paul Rudd',
#  "Julianne Moore's": "Julianne Moore's",
#  "Dustin Hoffman's": "Dustin Hoffman's",
#  'Guilliana': 'Guilliana',
#  "Loved Nicole Kidman's": 'Nicole Kidman',
#  'Winner': 'Winner',
#  "Kate Capshaw's": "Kate Hudson's",
#  'Crimson Chin': 'Crimson Chin',
#  'Hayden': 'Hayden Panettiere',
#  '@MARIELhaenn @robzangardi  ': '@MARIELhaenn @robzangardi  ',
#  'every1': 'every1',
#  "Loving Stacy Keibler's": "Loving Stacy Keibler's",
#  'Saw Jay Leno': 'Saw Jay Leno',
#  'Frankenstein': 'Frankenstein',
#  'w/ Sofia Vergara': 'w/ Sofia Vergara',
#  'Katharine McPhee': 'Katharine McPhee',
#  "vanno d'accordo": "vanno d'accordo",
#  'io volevo vederla': 'io volevo vederla',
#  'volevo porca miseria': 'volevo porca miseria',
#  'RT @tomandlorenzo Nicole Kidman': 'RT @xosdlc',
#  'Alexander McQueen  2013': 'Alexander McQueen',
#  'Jodie Foster': 'Jodie Foster',
#  'Yoplait': 'Yoplait',
#  'Lisa Kudrow': 'Lisa Kudrow',
#  'Guiliana': 'Guiliana',
#  '@BCBGMAXAZRIA @Sarah_Hyland': '@BCBGMAXAZRIA @Sarah_Hyland',
#  'George Clooneys': 'George Clooneys',
#  'Stacey': 'Stacey Keibler',
#  'Naomi Watts': 'Naomi Watts',
#  'alguien tiene': 'alguien tiene',
#  'dirección para': 'dirección para',
#  "Natalie Morales'": "Natalie Morales'",
#  '@FashionBlogg': '@FashionBlogg',
#  'esa tela de tapiz de Carolina Herrera': 'esa tela de tapiz de Carolina Herrera',
#  'gusta el nuevo estilo de Kelly Osbourne': 'Kelly Osbourne',
#  "Amy Adams'": 'Amy',
#  "Sally Fields'": 'Sally',
#  'RT @BlogXilla': 'RT @xosdlc',
#  "Tina Fey's": 'Tina Fey',
#  'Tina': 'Tina Fey',
#  'Taylor Swift 1.': 'Taylor Swift',
#  'Award': 'Award',
#  'Bella': 'Bella',
#  'nuevo look Lea Michelle': 'Lea Michelle',
#  'Bill Murray': 'Bill Murray',
#  'Xmas': 'Xmas',
#  'Jamie Kennedy': 'Jamie Kennedy',
#  'Chillin': 'Chillin',
#  'Barbara': 'Barbara',
#  'Photo Gallery - Yahoo': 'Photo Gallery - Yahoo',
#  'Tina Feys': 'Tina Fey',
#  'Upper Darby': 'Upper Darby',
#  "Bill Murray's": 'Bill Clinton',
#  'Tina Fey + Amy Poehler': 'Tina Fey',
#  'Murray': 'Bill Murray',
#  'Jennifer Garner': 'Jennifer Garner',
#  'Amy Phoeler': 'Amy',
#  '@melduckie': '@melduckie',
#  'GORGEOUS': 'GORGEOUS',
#  'Bill murrahy looks old': 'Bill Clinton',
#  'Ahhhhhhmaaaazing': 'Ahhhhhhmaaaazing',
#  'Claire Danes Looking': 'Yay',
#  'Olivia Munn': 'Olivia Munn',
#  'Nic Kidman': 'Nicole Kidman',
#  '@kzarrilli': '@kzarrilli',
#  "Albert Finney's": "Albert Finney's",
#  '@niecie797 @mini_mo': '@niecie797 @mini_mo',
#  'bill murray': 'bill murray',
#  'cielo': 'cielo',
#  'Tarantino': 'Quentin Tarantino',
#  'Jessica Rabbit  ': "Jessica Chastain's",
#  'Zooey Deschanel': 'Zooey Deschanel',
#  'Rosario Dawson': 'Rosario Dawson',
#  'Taylor Swift     ': 'Taylor Swift',
#  'Jennifer Lawerence': 'Jennifer Garner',
#  'Amy Pohler': 'Amy',
#  "Loving Amy's": "Loving Amy's",
#  "Tina Fey'S": 'Tina Fey',
#  'wowza': 'wowza',
#  'kristen wiig': 'kristen wiig',
#  'Glenn Close': 'Glenn Close',
#  'Loretta Switt-esque': 'Loretta Switt-esque',
#  'Damn Tina Fey': 'Tina Fey',
#  'Damn Helen Mirren': 'Helen Hunt',
#  'de la red carpet': 'de la red carpet',
#  'Ariel': 'Ariel Winter',
#  'Liz Lemon': 'Liz Lemon',
#  'taylor': 'taylor',
#  'sarah hyland': 'sarah hyland',
#  'Selena Gomez': 'Selena Gomez',
#  'Vanessa Hudgen': 'Vanessa Hudgens',
#  'Robert Downey Jr': 'Robert Downey Jr',
#  'Mortimer': 'Mortimer',
#  'RT @xosdlc': 'RT @xosdlc',
#  'David Faustino': 'David',
#  'Dayummm Tina Fey': 'Tina Fey',
#  'robert pattinson': 'robert pattinson',
#  "Via BBC's": "Via BBC's",
#  'BUT Miranda Kerr': 'BUT Miranda Kerr',
#  'Tiny Fey': 'Tiny Fey',
#  'Sienna Miller Golden Globes': 'Sienna Miller Golden Globes',
#  'Kristen Bell': 'Kristen Bell',
#  'Waaaah': 'Waaaah',
#  'Ini': 'Ini',
#  'Fufufu': 'Fufufu',
#  'Jessica Chastain Golden': "Jessica Chastain's",
#  'Allison Williams Golden': 'Allison Williams Golden',
#  'Natalie': "Natalie Morales'",
#  'Matt': 'Matt Lauer',
#  'Al': 'Al Roker',
#  'Robby': 'Robby',
#  'Richard Gere': 'Richard Gere',
#  'Mel': 'Mel Gibson',
#  'Garnier': 'Garnier',
#  "Margaery Tyrell's": "Margaery Tyrell's",
#  'Barbie': 'Barbie',
#  'Megan Fox': 'Megan Fox',
#  'Giorgio Armani': 'Giorgio Armani',
#  "Amy Adam's": 'Amy',
#  'Gibson': 'Mel Gibson',
#  'Ben': 'Ben Affleck',
#  'ANNE': 'ANNE HATHAWAY',
#  'Grinch': 'Grinch',
#  '@evalongoria': '@evalongoria',
#  'Jessica Rabbit-esque': "Jessica Chastain's",
#  'Amy Poehlers': 'Amy',
#  'Jennifer Garner - Affleck': 'Jennifer Garner',
#  'de Anne Hathaway': 'Ann Hathaway',
#  'Jenn Garner': 'Jenn Garner',
#  'Robert Pattinson': 'Robert Pattinson',
#  'Julia': 'Julia Roberts',
#  'Amy Poehler - Ladies': 'Amy',
#  'Hilary Swank': 'Hilary Swank',
#  '@carlymckinley': '@carlymckinley',
#  'Lucy Liu’s': "Lucy Liu's",
#  '@popsugar': '@popsugar',
#  'Woooow': 'Woooow',
#  '@JennmOneto Favorite': '@JennmOneto Favorite',
#  'heboh tereak2': 'heboh tereak2',
#  'mato anne hathaway': 'mato anne hathaway',
#  'Quentin Tarantino': 'Quentin Tarantino',
#  'Yum': 'Yum',
#  'Zooey Deschanel Recalls Joint Wardrobe Malfunction': 'Zooey Deschanel Recalls Joint Wardrobe Malfunction',
#  'Donna Karan Atelier': 'Donna Karan Atelier',
#  'Ang Lee': 'Ang Lee',
#  'Mandy Patinkin': 'Mandy Patinkin',
#  'BILL MURRAY': 'BILL MURRAY',
#  'Vera Wang': 'Vera Wang',
#  'Aziz Ansari Spoofs': 'Aziz Ansari Spoofs',
#  'Daniel Day Lewis': 'Daniel Day Lewis',
#  '@EmilyB Tina': 'Tina Fey',
#  'Tintin': 'Tintin',
#  'Daniel Day-Lewis': 'Daniel Day-Lewis',
#  '@1Mhari': '@1Mhari',
#  'Kate Hudsons': "Kate Hudson's",
#  'Rebecca Miller': 'Rebecca Miller',
#  'donna karan': 'donna karan',
#  'Kate': "Kate Hudson's",
#  'Tasty': 'Tasty',
#  'das indicadas': 'das indicadas',
#  'Nicole Kidman de de McQueen': 'Alexander McQueen',
#  'Ahhhhhhhh Lea': 'Lea Michele',
#  'kate hudson': 'kate hudson',
#  "kate hudson's": "kate hudson's",
#  "Lea Michele's": 'Lea Michele',
#  "Leonardo Dicaprio's": 'Leonardo DiCaprio',
#  'Bradley': 'Bradley Cooper',
#  '@EvaLongoria': '@EvaLongoria',
#  'un link de los Golden Globes': 'Globes',
#  'Adele - Golden Globes': 'Globes',
#  'Lea Michelle': 'Lea Michelle',
#  'Freaken': 'Freaken',
#  'Goldie Hawn': 'Goldie Hawn',
#  'a Bob Mackie': 'a Bob Mackie',
#  'Ann': 'Ann Hathaway',
#  'Je...': 'Jenny',
#  'Photo Gallery -': 'Photo Gallery -',
#  'Tommy Lee Jones': 'Tommy Lee Jones',
#  'Alexis Carrington': 'Alexis Carrington',
#  'Tommy lee jones': 'Tommy lee jones',
#  "Taylor Swift's": 'Taylor Swift',
#  '@stephfedorov': '@stephfedorov',
#  'Leo': 'Leo',
#  'Selma Hayek': 'Selma Hayek',
#  'Flash Gordon': 'Flash Gordon',
#  'Babyface': 'Babyface',
#  "Rob Pattinson's": 'Rob',
#  'Omg Christoph Waltz': 'Omg Christoph Waltz',
#  'Daniel Craig': 'Daniel Craig',
#  'Leonardo': 'Leonardo DiCaprio',
#  'Christoph Waltz': 'Christoph Waltz',
#  'Debra Messing': 'Debra Messing',
#  'Tom': 'Tom Ford',
#  'Marky Mark': 'Marky Mark',
#  'Abe Lincoln': 'Abe Lincoln',
#  'Hudson': "Kate Hudson's",
#  '@katehudson': '@katehudson',
#  '@Katehudson': '@Katehudson',
#  'Rip Van Winkle': 'Rip Van Winkle',
#  'Damn Leonardo Dicaprio': 'Leonardo DiCaprio',
#  'RT': 'RT @xosdlc',
#  'ardan los ojos': 'ardan los ojos',
#  'Jew Hunter': 'Jew Hunter',
#  '@redbookmag': '@redbookmag',
#  'bradley cooper': 'bradley cooper',
#  'Glee': 'Glee',
#  'Leo Dicaprio': 'Leo',
#  'Mierda': 'Mierda',
#  'Mmm Leonardo': 'Leonardo DiCaprio',
#  'wow jennifer': 'wow jennifer',
#  'Omg Kerry Washington': "Kerry Washington's",
#  'Kerry Washington KILLS': "Kerry Washington's",
#  'Kerry': "Kerry Washington's",
#  'Dennis Quaid': 'Dennis Quaid',
#  '@MsSarahPaulson': '@MsSarahPaulson',
#  'Kerry w': "Kerry Washington's",
#  'Hey Kerry': "Kerry Washington's",
#  'Blake': 'Blake',
#  'Leonardo Decaprio': 'Leonardo DiCaprio',
#  'dick Lea': 'Lea Michele',
#  'Hayden Paneittiere': 'Hayden Panettiere',
#  'Dennis Quads': 'Dennis Quads',
#  'Dennis': 'Dennis Quads',
#  '@KateHudson': '@KateHudson',
#  'GORGEOUS  ': 'GORGEOUS',
#  'Ariel RT@NickFlora:': 'Ariel Winter',
#  'Kerri Washington': 'Kerri Washington',
#  'Lucy Lieu': "Lucy Liu's",
#  'Benedict': 'Benedict',
#  'Dennis Quaids': 'Dennis Quads',
#  'Lena Dunham': 'Lena Dunham',
#  "Jessica Alba's": "Jessica Alba's",
#  'Maggie Smith': 'Maggie Smith',
#  'jessica alba': 'jessica alba',
#  'Malibu Barbie': 'Barbie',
#  'James Cameron': 'James Cameron',
#  'Archie Panjabi': 'Archie Panjabi',
#  'Yessss': 'Yessss',
#  'Assistindo': 'Assistindo',
#  'Randy Quaid': 'Randy Quaid',
#  'Oliver Stone': 'Oliver Stone',
#  'Sofia Vargara': 'Sofia Vargara',
#  'yo veo el': 'yo veo el',
#  'GOREGOUS': 'GOREGOUS',
#  'WANNA': 'WANNA',
#  'Beautifulllllllll': 'Beautifulllllllll',
#  'a Ben Affleck': 'Ben Affleck',
#  'Lo': 'J Lo',
#  'mal koegjfkejgegjt': 'mal koegjfkejgegjt',
#  'Hug': 'Hug',
#  'Miren Adele': 'Adele',
#  'Monique Lhuillier': 'Monique Lhuillier',
#  'Vanessa Hudgens': 'Vanessa Hudgens',
#  'Michael Kors': 'Michael Kors',
#  'Mark Cuban': 'Mark Cuban',
#  'Coldwell Banker': 'Coldwell Banker',
#  'Django Unchained': 'Django',
#  'Taylor Swift Gorgeous On The Red Carpet': 'Taylor Swift',
#  'Estamos': 'Estamos',
#  'Ed Hardy': 'Ed Hardy',
#  'Sofia Veraga': 'Sofia Veraga',
#  'Halle Berry Golden Globes Dress': 'Globes',
#  'Halley Berry': 'Halley Berry',
#  'Eric Stonestreet': 'Eric Stonestreet',
#  'Julia Louis-Dreyfus Keep': 'Julia',
#  'Julianne Moore Golden': 'Julianne Moore Golden',
#  'Eva': 'Eva Longoria - Golden',
#  'Nene': 'Nene Leakes',
#  "Eva Longoria's": "Eva Longoria's",
#  'Don Cheadle': 'Don Cheadle',
#  'Sam Fox': 'Sam Fox',
#  'dresssss&gt;&gt;&gt;&gt': 'dresssss&gt;&gt;&gt;&gt',
#  'Michael J Fox': 'Michael J Fox',
#  'sam fox...': 'sam fox...',
#  'Michael J. Fox': 'Michael J. Fox',
#  'Eva longoria': 'Eva Longoria',
#  "Michael J Fox's": "Michael J Fox's",
#  "Michael J. Fox's": "Michael J. Fox's",
#  'MICHAEL J. FOX': 'MICHAEL J. FOX',
#  'Sam fox looks': 'Sam Fox',
#  'Angelina Jolie': 'Angelina Jolie',
#  "Michael J. Fox'": "Michael J. Fox'",
#  'Damn Eva Longoria': 'Eva Longoria',
#  'Sam': 'Sam Fox',
#  'WOWOWOWOWOWOWOWW Eva Longoria': 'Eva Longoria',
#  'Alex P Keaton': 'Alex P Keaton',
#  'Pure Fah-shon': 'Pure Fah-shon',
#  'Julian Moore': 'Julian Moore',
#  'Brian Austin Green': 'Brian Austin Green',
#  'Kerrys': 'Kerrys',
#  'Kim Kardashian': 'Kim Kardashian',
#  'Helena Bonham Carter Golden Globes Dress': 'Globes',
#  'Tony Parker': 'Tony Parker',
#  'Michael': "Michael J. Fox'",
#  'Glad': 'Glad',
#  'GoldenGlobes': 'GoldenGlobes',
#  'Alex P. Keaton': 'Alex P. Keaton',
#  "Loving Eva's": "Loving Eva's",
#  'Patrick Adams': 'Patrick Adams',
#  '@zacposen': '@zacposen',
#  'Jonathan': 'Jonathan',
#  'Danny Strong': 'Danny Strong',
#  'A. Richard Gere': 'Al Roker',
#  'B. Leo': 'Leo',
#  'RT @amyodell': 'RT @xosdlc',
#  'Versace': 'Versace',
#  "Halle Berry's": "Halle Berry's",
#  'John Shearer  ': 'John Shearer  ',
#  '@evalongoria smokin': '@evalongoria',
#  'Linda': 'Linda Gray @',
#  'Marty MCfly': 'Marty Jr',
#  'Bitch': 'Bitch',
#  'Angie': 'Angie',
#  'James Bond': 'James Bond',
#  'Kaley Cuoco': 'Kaley Cuoco',
#  'Diulang': 'Diulang',
#  'ini Megan': 'Megan Fox - Here',
#  'Quaalude': 'Quaalude',
#  'Jennifer Lawrence Amy Adams': 'Jennifer Garner',
#  'Pica Nutalli': 'Pica Nutalli',
#  'Si los  Fuesen': 'Si los  Fuesen',
#  'haria el tierrudo de la': 'haria el tierrudo de la',
#  'mistook sarah paulson': 'mistook sarah paulson',
#  'ALLYN GOLDEN': 'ALLYN GOLDEN',
#  "Allison Williams'": "Allison Williams'",
#  "Nicole Kidman's": "Nicole Kidman's",
#  'Chris Farley': 'Chris Farley',
#  "Sienna  Miller's": 'Sienna Miller',
#  'Micheal J. Fox': 'Stun',
#  '@KeithUrban Woo': '@KeithUrban Woo',
#  'Jessica Lange': 'Jessica Lange',
#  'Katharine McPhee Flashes': 'Katharine McPhee Flashes',
#  'Sideboob': 'Sideboob',
#  'Adele Debuts Post-Baby Body': 'Adele',
#  'Jullianne Hough': 'Jullianne Hough',
#  'Taylor Swift Wears Sexy': 'Taylor Swift',
#  'Zac Posen Gown': 'Zac Posen Gown',
#  'Eva L': 'Eva Longoria',
#  'JULIANNE MOORE': 'JULIANNE MOORE',
#  'jeeeez': 'jeeeez',
#  'Oscar Snubs': 'Oscar Snubs',
#  '@NewsOnKidman': '@NewsOnKidman',
#  'Mary': 'Lady Mary',
#  'Julianne': "Julianne Hough's",
#  'Joan Rivers': 'Joan Rivers',
#  'Jullian Moore': 'Jullian Moore',
#  'Julianne Morre': 'Julianne Moore Golden',
#  'Look Julianne': 'Julianne Moore Golden',
#  "Julianne Hough's": "Julianne Hough's",
#  'Vanessa': 'Vanessa Hudgens',
#  'Julieanne Moore': 'Julieanne Moore',
#  '@mtvstyle': '@mtvstyle',
#  'Taylor Swifts': 'Taylor Swift',
#  'kinda blah  ': 'kinda blah  ',
#  'encantaron las tendencias': 'encantaron las tendencias',
#  '-Emily Blunt  ': 'Emily Blunt',
#  'Catherine Zeta - Jones': "Catherine Zeta-Jones'",
#  'Catherine Zeta-Jones': 'Catherine Zeta-Jones',
#  'Bi Polar Zeta-Jones': 'Bi Polar Zeta-Jones',
#  "Catherine Zeta-Jones'": "Catherine Zeta-Jones'",
#  'Catherine': 'Catherine Zeta Jones',
#  "Catherine Zeta Jones'": "Catherine Zeta-Jones'",
#  'Marty McFly': 'Marty McFly',
#  'Catherine Zeta Jones': 'Catherine Zeta Jones',
#  'catherine zeta jonest': 'catherine zeta jonest',
#  'Catherine Zeta': "Catherine Zeta-Jones'",
#  'Catharine Zeta-Jones': 'Catharine Zeta-Jones',
#  'Catherine Zeta Johns': "Catherine Zeta-Jones'",
#  '@Coops_tv': '@Coops_tv',
#  'Julianne moore': 'Julianne Moore Golden',
#  'Darcy St. Fudge': 'Darcy St. Fudge',
#  'mañana Joan Rivers': 'mañana Joan Rivers',
#  'hará sentir': 'hará sentir',
#  'Les Misérables': 'Les Misérables',
#  "Catherine Zeta-Jones's": "Catherine Zeta-Jones'",
#  'Peter Pan': 'Peter Pan',
#  'Kelly Osborn': 'Kelly Osbourne',
#  'sienna miller': 'sienna miller',
#  'Lovin Old Hollywood': 'Lovin',
#  'Huff': 'Huff',
#  "J. Lo's": "J. Lo's",
#  'venus williams': 'venus williams',
#  'angelina jolie looks': 'angelina jolie looks',
#  'Kelly O. es de Fashion': 'Kelly Osbourne',
#  '@NeNeLeakes Getty Images': '@NeNeLeakes',
#  'TSwift': 'TSwift',
#  '@RSVPMagazine Jennifer Lawrence': 'Jennifer Garner',
#  'amp;Hallie Berry': 'Hallie Berry',
#  'Catherine zeta jones': "Catherine Zeta-Jones'",
#  'catherine zeta jones': 'catherine zeta jones',
#  'Allison': 'Allison Williams',
#  'Ann Hathaway': 'Ann Hathaway',
#  'Julianna Moore': 'Julianna',
#  'Halle Barry': "Halle Betty's",
#  'Donna Karan': 'Donna Karan',
#  'Hayden Panettier': 'Hayden Panettiere',
#  "Sarah Palin's": "Sarah Palin's",
#  'Doily': 'Doily',
#  'Robert Downey Jr.': 'Robert Downey Jr.',
#  'Safe Haven': 'Safe Haven',
#  'Francesca Eastwood': 'Francesca Eastwood',
#  'Tracy Pollen': 'Tracy Pollen',
#  'j.lo': 'j.lo',
#  'Ohmygod Taylor': 'Taylor Swift',
#  "Tom Ford's": 'Tom Ford',
#  'Katherine Zeta Jones': 'Katherine Zeta Jones',
#  'Enamel Earring': 'Enamel Earring',
#  'Robert Pattinson News - Rob': 'Robert Downey Jr.',
#  'Presenters Robert': 'Robert Downey Jr.',
#  'eva longoria': 'eva longoria',
#  'Liza Minelli': 'Liza Minelli',
#  'Zsa Zsa Gabor': 'Zsa Zsa Gabor',
#  'Liza Minelli LOL': 'Liza Minelli LOL',
#  'MICHAEL J': 'MICHAEL J',
#  'Keepin': 'Keepin',
#  'mañana': 'mañana Joan Rivers',
#  'Liza': 'Liza Minelli LOL',
#  'Liborace': 'Liborace',
#  'Michael J Foxs': "Michael J. Fox'",
#  'Jeremy Irons': 'Jeremy Irons',
#  'Taylor Swift - Golden': 'Taylor Swift',
#  'Halle Looks': "Halle Betty's",
#  'Ooh': 'Ooh',
#  'Helen Hunt': 'Helen Hunt',
#  '@Eva Longoria Look': 'Longoria',
#  'Thandie Newton': 'Thandie Newton',
#  'Hall Berry': 'Hallie Berry',
#  "Rosario Dawson's": "Rosario Dawson's",
#  'Jennifer Lawrance': 'Jennifer Garner',
#  'Liza Minnelli': 'Liza Minelli LOL',
#  'Ohhhhhh Rosario Dawson': 'Ohhhhhh Rosario Dawson',
#  'Sorry Rosario Dawson': 'Sorry Rosario Dawson',
#  "Liza Minelli's": 'Liza Minelli LOL',
#  "Terri Schiavo's": "Terri Schiavo's",
#  'Hillary Clinton': 'Clinton',
#  'Ro-Daws': 'Ro-Daws',
#  'judy jetson': 'judy jetson',
#  'Gross': 'Gross',
#  'Silver Fox': 'Stun',
#  'Matt Leblanc': 'Matt Leblanc',
#  'Helen': 'Helen Hunt',
#  'Rosie Huntington-Whiteley': 'Rosie Huntington-Whiteley',
#  'Matt LeBlanc': 'Matt LeBlanc',
#  'Vivienne Westwood Couture': 'Vivienne Westwood Couture',
#  'Salma': 'Globes',
#  'Latinas': 'Latinas',
#  "Damien Lewis's": "Damien Lewis's",
#  'Steve': "Steve Odekerk's",
#  "Kaley Cuoco's": "Kaley Cuoco's",
#  'DAANNGGGG': 'DAANNGGGG',
#  'Deborah Lippman': 'Deborah Lippman',
#  'Steven': 'Spielberg',
#  'Joey': 'Joey',
#  'Will McAvoy': 'Will Ferrell',
#  'Selma Hayak': 'Selma Hayak',
#  'Damien Lewis': 'Damien Lewis',
#  'Hugh Laurie': 'Hugh Laurie',
#  'Brody': 'Brody',
#  'Damian Lewis': 'Damian Lewis',
#  'Steve Buscemi': 'Steve Buscemi',
#  'Golden Globe': 'Golden Globe',
#  'Marty Jr': 'Marty Jr',
#  'Marion Cotillard de @Dior': 'Marion Cotillard de @Dior',
#  'Jajaja': 'Jajaja',
#  'Holllaaaa': 'Holllaaaa',
#  '@joandiminich': '@joandiminich',
#  'Não vou': 'Não vou',
#  'muito': 'muito',
#  'Mmm Leonardo DiCaprio': 'Leonardo DiCaprio',
#  'Jackie Weaver': 'Jackie Weaver',
#  'Regina George': 'Regina George',
#  '@ivllagecanada': '@ivllagecanada',
#  "Salma Hayek's": 'Salma Hayek',
#  'Kerry @GoldenGlobes Dress': "Kerry Washington's",
#  'Allen Luddon': 'Allen Luddon',
#  'da Taylor': 'Taylor Swift',
#  'ela tá': 'ela tá',
#  'mais linda': 'mais linda',
#  'Whoah': 'Whoah',
#  'Saudades Justin Bieber': 'Saudades Justin Bieber',
#  'gato de': 'gato de',
#  'Harry Potter': 'Harry Potter',
#  'paul': 'paul',
#  'Claire': "Claire Danes'",
#  'Ava': 'Ava',
#  'Clare Danes': 'Clare Danes',
#  "Jennifer Garner's": 'Jennifer Garner',
#  'Vivienne Westwood': 'Vivienne Westwood',
#  '@AnnTaylor': '@AnnTaylor',
#  'Tina Looking': 'Tina Fey',
#  'Hopes She': 'Hopes She',
#  "Claire Danes'": "Claire Danes'",
#  'Calvin Klein': 'Calvin Klein',
#  'Michael J. Foxs': "Michael J. Fox'",
#  'Mine': 'Mine',
#  'Selena': 'Selena Gomez',
#  'jennifer lawrence': 'jennifer lawrence',
#  'mel gibson': 'mel gibson',
#  'Dana Brody': 'Brody',
#  "Zooey Deschanel's": "Zooey Deschanel's",
#  'Evan Longoria': 'Longoria',
#  'Mel Gib': 'Mel Gibson',
#  'Helen McCrory': 'Helen Hunt',
#  "Katharine McPhee's": "Katharine McPhee's",
#  "Kelly Osbourne's": 'Kelly Osbourne',
#  'jamie': 'jamie',
#  "Morena Baccarin's": "Morena Baccarin's",
#  'Halle Berry Allen': "Halle Betty's",
#  'Olivia Longoria Allen': 'Longoria',
#  'Saw Claire Danes': 'Yay',
#  'Angela Chase': 'Angela Chase',
#  '@SavannahGuthrie You': '@SavannahGuthrie You',
#  'Holler Homeland': 'Holler Homeland',
#  "Love Anne Hathaway's": "Anne Hathaway's",
#  'Adele Debuts': 'Adele',
#  'ko lang': 'ko lang',
#  'tinignan e.pati yung blog sa golden': 'tinignan e.pati yung blog sa golden',
#  'ako ng': 'ako ng',
#  'Dana': 'Brody',
#  'kannie': 'kannie',
#  '@CELEBUZZ': '@CELEBUZZ',
#  'Emily Blunt de @MichaelKors': 'Emily Blunt',
#  'Megan Fox - Here': 'Stun',
#  "John Goodman's": "John Goodman's",
#  'Jon': 'Jon Hamm',
#  'Jon Bon Jovi': 'Jon Bon Jovi',
#  '@kerrywashington': '@kerrywashington',
#  'Givenchy': 'Givenchy',
#  'john goodman': 'john goodman',
#  'Tony Mendez': 'Tony Mendez',
#  'Guy': 'XOXO Gossip Guy',
#  'RT @RollingOut': 'RT @xosdlc',
#  'John Goodman': 'John Goodman',
#  'Betty White': 'Betty White',
#  'Ben Afleck': 'Ben Affleck',
#  'lt;3 John Goodman': 'lt;3 John Goodman',
#  'jon Bon Jovi': 'jon Bon Jovi',
#  'Clooney': 'George Clooney',
#  'Dick Tracy': 'Dick Tracy',
#  'Jennifer Lopez - Golden': 'Jennifer Garner',
#  'Jessica Chastain - Golden': "Jessica Chastain's",
#  'Sienna Miller &': 'Sienna Miller',
#  'Jennifer Lopez SEMPRE': 'Jennifer Garner',
#  'hora de escolher': 'hora de escolher',
#  'Jennifer': 'Jennifer Garner',
#  'JoLo': 'J Lo',
#  'J-Lo': 'J-Lo',
#  'Se fue': 'Se fue',
#  'como salía': 'como salía',
#  'J Lo': 'J Lo',
#  'Jennifer Lopez - WOW': 'Jennifer Garner',
#  "Ben Affleck's": 'Ben Affleck',
#  'Cher': 'Cher',
#  'Jo Lo': 'J. Lo',
#  'J.lo': 'J.lo',
#  "Jason Statham's": "Jason Statham's",
#  "J Lo's": "J Lo's",
#  'Jenny': 'Jenny',
#  'Lovin': 'Lovin',
#  'Selena Gomez Looks': 'Selena Gomez',
#  'Dang': 'Dang',
#  'Raquel Welch': 'Raquel Welch',
#  'Hey J Lo': 'J. Lo',
#  "Scarlett O'Hara": "Scarlett O'Hara",
#  "J-Lo's": "J-Lo's",
#  'Beyonce': 'Beyonce',
#  '@MsLeaMichele': '@MsLeaMichele',
#  'God Bless Jennifer Lopez': 'Jennifer Garner',
#  "Jennifer Lopez'": 'Jennifer Garner',
#  'J.Lo': 'J Lo',
#  'Jay-Lo': 'Jay-Lo',
#  'Granny': 'Granny',
#  'Jennifer Anniston': 'Jennifer Garner',
#  'John Williams': 'John Williams',
#  'Gosshhh Anne': "Anne Hathaway's",
#  'Jennifer Lopez=': 'Jennifer Garner',
#  'Makeup Look': 'Makeup',
#  'Cake Boss': 'Cake Boss',
#  'RT @Lyfelong': 'RT @xosdlc',
#  'viendo la': 'viendo la',
#  'abuuuurrrroooo': 'abuuuurrrroooo',
#  'Michael Danna': "Michael J. Fox'",
#  'Tony Hawk': 'Tony Hawk',
# ...
#  'Jody',
#  "Kristin Wiig's",
#  'Jennifer Garner - geometric',
#  'Kelly Osborn',
#  '@evalongoria smokin',
#  'Waldo',
#  'Dayummm Tina Fey',
#  "Jon Hamm's",
#  'Mmm Jason Bateman',
#  "Catherine Zeta-Jones's",
#  'Glee',
#  'lucy liu',
#  '@cocoperez',
#  'Ann',
#  'zapatero',
#  'Idk',
#  '@Eva Longoria Look',
#  'Saw Claire Danes',
#  'Ooooo',
#  "Loved Nicole Kidman's",
#  '@RheaDurham',
#  'Kidman',
#  'Hey Anne Hathaway',
#  "Jennifer Garner-Affleck's",
#  '-Emily Blunt  ',
#  'paul',
#  'Hey Jennifer Lopez',
#  'Jennifer Lawrence Amy Adams',
#  'Charlie',
#  '@msleamichele Girl',
#  "Lena Durham's",
#  'Abe',
#  'Marta',
#  'Donna',
#  "Tom Ford's",
#  'Kristen Stewart',
#  'Omg Jennifer Garner',
#  'Megan Fox Stun',
#  'RT',
#  'Joey',
#  'GEORGE',
#  'j.lo',
#  'Majorly',
#  'bell',
#  'Halle',
#  'Grace',
#  'Jane Hathaway',
#  'Sharing',
#  'Blake',
#  'New Moms Adele',
#  'Vergara Golden Globes',
#  '@stellarsun',
#  'Meghan fox',
#  'Al',
#  'Julianna Moore',
#  '@EvaLongoria @msleamichele &amp',
#  'Alexander McQueen  2013',
#  'Olivia Longoria Allen',
#  "Jodie Foster DIDN'T",
#  'Tarantino',
#  'Seacrest',
#  'RT @LanceUlanoff',
#  'Shh',
#  'Classy',
#  'Speilberg',
#  "Megan Fox'",
#  'Rob',
#  'Tom',
#  'Taylor',
#  'Lo',
#  'Leo',
#  'Globes Taylor Swift',
#  'muito mais',
#  "Amy Adams'",
#  'Ballsy',
#  'Enjoy',
#  'XVera',
#  "Jennifer Garner's",
#  'Kristen Wigg',
#  'Adam',
#  'Muwahahaha',
#  'Michelle',
#  'J.Lo  ',
#  'Gucci',
#  'Taylor Swift Gorgeous On The Red Carpet',
#  '@katsura_nagato',
#  'RT @ETonlineAlert Gleeks',
#  'Sorry Sienna  ',
#  'Booya',
#  'JGarner',
#  'Helen',
#  'Yayyyyy Ben Affleck',
#  'Jenn',
#  'Lucy Liu’s',
#  'Ahhhhhhmaaaazing',
#  "Jennifer Lopez'",
#  'Jonah',
#  '@ Jonah Hill',
#  'Lucy liu looks',
#  '@NeNeLeakes Lookin',
#  '@joandiminich',
#  '@Krlossosa',
#  'LORL',
#  'Hotness',
#  'Presenters Robert',
#  'Seyfried',
#  '-BP',
#  'Kristen Wig',
#  'Lasheng',
#  'Renner',
#  'Linda Gray @',
#  "Liza Minelli's",
#  "Jessica Abla's",
#  'Anne Hathaways',
#  'Ini',
#  '@CanoElah',
#  "Allison Williams'",
#  'concordo',
#  'Kelly',
#  'Quentin',
#  "Ben Affleck's",
#  'RT @tomandlorenzo Nicole Kidman',
#  'Leonardo di Caprio',
#  'Matt Le',
#  'Jason Bateman',
#  'Amy Pohler',
#  "Steve Spielberg's",
#  'Lewinsky',
#  '@popcouturejjw4',
#  'Michael J. Fox Jr.',
#  'Claire Daines',
#  'Eva L',
#  'Jennifer Lawrence Wear Orange Dior Couture',
#  'Calvin',
#  'Nurse Hathaway',
#  'Robert De Niro',
#  'TAYLOR LOOKS SO',
#  'Helen McCrory',
#  'Waaaah',
#  'Saggy-boob',
#  'Burberry',
#  'Jonathan',
#  'Guiliana',
#  'Josh',
#  "Will Ferrell's",
#  'Mel Gib',
#  "J-Lo's",
#  'oooooh taylor',
#  'Para',
#  'Catherine Zeta - Jones',
#  'Longoria',
#  'Gosshhh Anne',
#  'Eva',
#  'mais linda',
#  'Gloria',
#  'Kiebler',
#  'XOXO Gossip Guy',
#  'Jenn Garner',
#  'Ben',
#  'Jennifer Lopez=',
#  'WOOOOW',
#  'Sylvester Stalone',
#  'Django',
#  'Hathway',
#  'Ben Afflevk',
#  '@CELEBUZZ',
#  'Winner',
#  "Lea Michele's",
#  'RT @amyodell',
#  'Michael',
#  'Jennifer Lawrance',
#  'Allyson',
#  'Julia Louis-Dreyfus @OfficialJLD',
#  'Cohen',
#  "Tina Fey's",
#  'Kerrys',
#  'Congrats Anne Hathaway',
#  'dick Lea',
#  'Okelah',
#  'god',
#  'Julianna Marguiles',
#  'da Taylor',
#  "Sylvester Stallone's",
#  'linda',
#  'Diana',
#  'Amy Poehlers',
#  'Michael Kors  ',
#  'Twitter',
#  "Leonardo DiCaprio's",
#  'RT @xosdlc',
#  'Omg Kerry Washington',
#  'Vanessa Hudgen',
#  'Qué',
#  'Fox',
#  'Lea Michele &',
#  'tan fan de las Red Carpet',
#  "Leonardo Dicaprio's",
#  'Hey Jennifer Lawerance',
#  'Halle Berry Golden Globes Dress',
#  'Debra',
#  '@DGJGodwin',
#  "Lucy Luu's",
#  'Aubrey',
#  "Sylvester Stalone's",
#  'Dennis Quads',
#  'Estamos',
#  'Elvis',
#  'Hubby',
#  'Yay Adele',
#  'Grinch',
#  'Jessica Chastian',
#  'Beyonce',
#  'Granny',
#  'Bill murrahy looks old',
#  'Anne Hathaway de @Chanel',
#  'Quanto',
#  'Leah Michelle',
#  'Heisenberg',
#  '@haydenpanettier',
#  'Nicole Kidman de de McQueen',
#  'Golden Globes HBO Emmy Party',
#  'Mary Crawley -',
#  '@mtvstyle',
#  'muito',
#  'Benny',
#  'tan',
#  'Lol You',
#  'Jon Jon',
#  'a Ben Affleck',
#  "Julia Robert's",
#  '@AnnTaylor',
#  'Ok Jennifer Lawrence',
#  'Tattoos',
#  'Bollywood',
#  'Lucy Lui',
#  'Stacey',
#  'Jennifer Lopez Shows Serious Skin',
#  'Robert Pattinson &',
#  'dk',
#  '@lovethebay',
#  'Ohhh Jessica',
#  'Que',
#  'Alan Arkin',
#  'Jon',
#  'Felt',
#  'Julia Louis-Dreyfus',
#  '@KChenoweth hahaha',
#  'Thatcher',
#  'Claire Danes - Golden',
#  'LOVED',
#  'kannie',
#  'XD xD',
#  '@stephfedorov',
#  "Jennifer Lopes'",
#  'Ava',
#  'Blunt',
#  'Doily',
#  '@EmilyB Tina',
#  'Hey J Lo',
#  'Julia',
#  '@NeNeLeakes',
#  'Jessica Rabbit-esque',
#  'Guy',
#  'Dennis',
#  '@RSVPMagazine Jennifer Lawrence',
#  'Jennifer Lopez Golden Globes',
#  'RT @OKMagazine',
#  '@katehudson @LeaMichele',
#  'Tina Fey + Amy Poehler',
#  'Que Hace @ALDORENDON',
#  'Death',
#  'Kristen Wing',
#  'GOREGOUS',
#  'Julianne',
#  'RT Adele Debuts',
#  'Madonna',
#  'Will McAvoy',
#  "Looooove Anne Hathaway's",
#  'Anjelica Huston',
#  'Parks',
#  'Damn Tina Fey',
#  'Schwartzenager',
#  'Hug',
#  'Marchesa',
#  'Suess',
#  "Kate Capshaw's",
#  'Keepin',
#  'Franz',
#  'awww',
#  'Agora',
#  'Lmfao',
#  'Lea',
#  'Joan',
#  "Jennifer Lawrence '",
#  'Spielberg',
#  'Benedict Cumberbatch - Red Carpet',
#  'Marty Jr',
#  'Meryl Strep',
#  'Lucy Luis',
#  'Swarzanegger',
#  '@katharinemcphee',
#  'Jessica Chastain/',
#  "Lena Dunham's",
#  'Dennis Haysbert',
#  'Eep',
#  'Adele - Golden Globes',
#  'Harvey Weinstein',
#  'Lol  ',
#  'Aaaaaaaaaaaaah',
#  'Jessica Chastain - Golden',
#  'Megan',
#  'Kristin Bell',
#  'Emily Blunt @ 2013 Golden Globes Photos – Makeup, Dress, Hair',
#  'Stun',
#  'Claire Dannes',
#  "Salma Hayek's",
#  'Ahhhhhhhh Lea',
#  'Steven',
#  'Kate Hudsons',
#  'Arkin',
#  'urg',
#  'Jessica - You',
#  'Lopez',
#  'Murray',
#  'Ben Fcuking Affleck',
#  "Rob Pattinson's",
#  'Jolie',
#  'Xena',
#  '@katehudson',
#  '@twhiddleston',
#  'Robert Downey jr',
#  'Lace',
#  'Robinson',
#  'Leonardo Decaprio',
#  'Definitivamente Gloria',
#  'Sam fox looks',
#  'Jennifer Gardner',
#  'RT @RobertVerdi',
#  '@RobertVerdi Anne Hathaway',
#  "Tina Fey'S",
#  'Brolin',
#  'Robert Downing Jr.',
#  "Lucy Lou's",
#  'Sienna',
#  'Kerry Washington Hits',
#  'Sam Michael Fox',
#  "Steve Odekerk's",
#  'J.lo',
#  'Rob Patterson',
#  'JoLo',
#  'Para Norman',
#  'Stifler',
#  'Ugh Anne Hathaway',
#  'Best Song',
#  'Willy Clinton',
#  "Jodie Foster's",
#  'Ro-Daws',
#  'Oroton',
#  'Award',
#  'RT @vogueoz\n',
#  'Bubba',
#  'abuuuurrrroooo',
#  'Joker',
#  'JAJAJAJAJAJJAJAJAJAJAJAJAJAJA',
#  'Berry',
#  'Claire Danes Looking',
#  '@MsSarahPaulson',
#  "Jennifer lawerence's",
#  'GORGEOUS',
#  'Costner',
#  'lucy',
#  'Foster',
#  'Catherine Zeta',
#  '@SuperModelCntrl',
#  'Salma',
#  'Salma Hayek - Golden Globes',
#  'Watson',
#  "Mel Gibson's",
#  'Nene Leakes',
#  'Copying Angelina Jolie',
#  'muito casual',
#  'Benedict Cumberbatch',
#  'Jason Statham -  ',
#  'jamie foxx looks',
#  'Danes',
#  'Brody',
#  'Douglas Golden',
#  'Marty MCfly',
#  'Mary Todd Lincoln',
#  'de Anne Hathaway',
#  '@NewsOnKidman',
#  'Andrew',
#  'Latina',
#  'Benedict Cumberbatch - Golden',
#  'Douglas',
#  'WANNA',
#  'Frankenstein',
#  "Claire Dane's",
#  'Jessica Albas',
#  'Song',
#  'Lmao Will Ferrell',
#  'Tom Jones',
#  "Julianna Moore's Custom",
#  'Wht',
#  'GORGEOUS tonight',
#  'Wanna',
#  'Hefty',
#  'Jessica Rabbit',
#  'Gorgas',
#  'Meghan',
#  'Jodies Foster',
#  "Jon Bon Jovi's",
#  '@pbrdawn',
#  'Judi Foster',
#  'JUMPSUIT',
#  'Adele ganhou merecidamente',
#  'Hooray RT @markgirl',
#  "Nicole Richie's",
#  "O'Hara",
#  'Clooney',
#  'Selena Gomez Looks',
#  'Lucy',
#  'Carla',
#  '@redbookmag',
#  'Anjelica',
#  'Megan Fox’s',
#  'Angie',
#  'Andrew!',
#  'Amy Adams Dress &gt;&gt;&gt;&gt',
#  'Chester A. Arthur',
#  'Bradley',
#  'nuevo look Lea Michelle',
#  'Golden Globes - Us Magazine',
#  'Marty',
#  'Liborace',
#  'Ben Assneck',
#  'Arnie',
#  'Schwarzenegger',
#  'Jody foster looks',
#  'Paranorman',
#  "i'mma",
#  'Harvey',
#  'Quentin T',
#  'Ahora',
#  'ANNE',
#  'jamie',
#  'Ron Burgundy',
#  'Damn Eva Longoria',
#  "Jennifer Lopezs'",
#  'Taylor Swift 1.',
#  'Meryl',
#  'Linda',
#  'Sideboob',
#  'Hillary',
#  'Gross',
#  'Lovin',
#  'Ann Taylor',
#  'amp;Hallie Berry',
#  'Hayden Paneittiere',
#  'Chris',
#  'Lol Taylor Swift',
#  'Quentin Tarantino.never',
#  "Kristen Wig's",
#  'berry',
#  'RT @MsShaunRobinson',
#  'Damn Helen Mirren',
#  'Learn',
#  'Halle Barry',
#  'Ben Affleck Goes',
#  'J.Lo',
#  'Makeup Look',
#  'Django Unchained',
#  'Babyface',
#  'Assistindo',
#  'A. Houston',
#  'Makeup How-',
#  'Quentin Tarentino',
#  '@Katehudson',
#  'Omg Jessica',
#  'Chillin',
#  'Hiesenberg',
#  'Jenny',
#  'Natalie',
#  'Jennifer Lopez - WOW',
#  'Klingon',
#  'Aaarrgghhh',
#  "Kristin Bell's",
#  "Lucy Luis's",
#  'Halle Berry-NO',
#  "Scarlett O'Hara",
#  'Hoffman',
#  "Jack Black's",
#  'Ravens',
#  'Spanx',
#  'EMILY',
#  'Greg',
#  'Whiskey',
#  'gusta el nuevo estilo de Kelly Osbourne',
#  'Host',
#  'Adele',
#  'mañana Joan Rivers',
#  "Kristen Wiig's",
#  'Johnny Depp - ha',
#  'J-Lo',
#  'blerg',
#  'Vanessa',
#  'Audrey',
#  'Sam',
#  'Kate Hudson - Golden',
#  'Abby',
#  'Ariel',
#  "Catherine Zeta-Jones'",
#  'Amy Poehler',
#  "Lucy Lui's",
#  'finito',
#  'Clinton',
#  'Jason',
#  '@MsLeaMichele',
#  'Quentin Taratino',
#  'Affleck Oscar',
#  '@kzarrilli',
#  'hahaha',
#  'XD',
#  'Mal',
#  'Woooow',
#  'Anne Hathaway - Golden',
#  'Tintin',
#  'Tayl',
#  'Jennifer Garner - Affleck',
#  'Xmas',
#  'Lovin Old Hollywood',
#  'Roseanne',
#  'Gwen',
#  '@RosaHwangCTV',
#  'Bold Berry Lip',
#  'Hudson',
#  "Emily Blunt 's",
#  'Jesus Christ',
#  'Ah-ma-zing',
#  "Bill Clinton's",
#  'Julia Louis Dreyfus',
#  'Kerry Washington KILLS',
#  'dresssss&gt;&gt;&gt;&gt',
#  'Hurry',
#  'Guilliana Rancic',
#  'Kristin',
#  'Mmm Leonardo',
#  'Leonardo',
#  'ROCKETS',
#  'Anne  is',
#  '@RachelZoe',
#  'GoldenGlobes',
#  'Jesus',
#  '@HeIenMirren',
#  'Emily Blunt &',
#  'jkras',
#  'Oscar James Franco',
#  '@msleamichele Waooo',
#  'Jennifer Lawrence Looks',
#  'Gilliana',
#  'Ooh',
#  '@itsMeRadikha',
#  'Globes',
#  "Love Anne Hathaway's",
#  'Dana',
#  'omg Lucy Liu',
#  "Michael Haneke's",
#  'pelo',
#  "Bill Murray's",
#  'Holllaaaa',
#  '@siennamiller',
#  'Jeeeez',
#  'Yessss',
#  'Amy Adams',
#  'Que decepción las dos',
#  'Walter',
#  "Julianna Margulies'",
#  'Vontrap',
#  'Rob Pattinson',
#  'makeup“@PerezHilton',
#  'Bahahahaha RT @MARLONLWAYANS',
#  'Fitter',
#  'Jenny Packham    ',
#  'Adele FTW',
#  'Look Julianne',
#  'RDJ',
#  "Lea Michelle's",
#  'Amy',
#  '@cfda',
#  'Arnold Schwarzenegger',
#  'Kelsie',
#  'wowza',
#  'Dennis Quaids',
#  'Ron',
#  'Yesss',
#  'WOWZA Jennifer Lawrence',
#  'Will',
#  'Aussie',
#  '@FashionBlogg',
#  'Jenn...',
#  '@DiBiaseAngel',
#  'Liza',
#  '@ShaPieLou Glad',
#  'cielo',
#  'Btw',
#  'Jennifer Lopez Shows',
#  'Woof',
#  'Jen',
#  'Liza Minneli',
#  'Lucy liu',
#  'Anne hatthaway',
#  'Oscar',
#  'Ben Affleck &',
#  'A. Richard Gere',
#  'Hall Berry',
#  'every1',
#  '@zacposen',
#  'Beautiful Lea',
#  'Maria',
#  'towel-y.',
#  '@nicolerichie',
#  'Mmm Leonardo DiCaprio',
#  'Corrie',
#  'RT @hmilfeld',
#  'Whoah',
#  'Sanders',
#  'Romulan',
#  "lucy lui's",
#  'TAYLOR',
#  'David Bowie',
#  'Ross',
#  'Mine',
#  'Jason Statham - Golden',
#  "Taylor Swift's",
#  'Megan Fox Is Cranky',
#  'Dracula',
#  'Woahhhhhh',
#  'RT @X_SML Award',
#  'Julia Roberts kinda',
#  'Marney',
#  'Pitbull',
#  'Thumb',
#  'Sally Fields',
#  'Edward Cullen',
#  'Lorax',
#  '@NeNeLeakes Getty Images',
#  "Jen Lawrence's",
#  'Lucy Lu',
#  'Tina Feys',
#  'Yum',
#  'Michelle Williams',
#  'Hayden Panettier',
#  'Omg Lea',
#  'Mel',
#  '@msleamichele',
#  '@janevw',
#  'Sylvester',
#  'Omgggg',
#  'Hey Kerry',
#  'Jack',
#  'Selena',
#  'Kristen',
#  'Amy Phoeler',
#  'Bill Murry',
#  "Halle Betty's",
#  '@michael5inco',
#  '@popsugar',
#  '@ivllagecanada',
#  'Jennifer Lawrenc',
#  'Kennedy',
#  'Fraulein Maria',
#  'mañana',
#  'Nene',
#  'Quaalude',
#  'Benedict',
#  'Anne Hathway’s',
#  'Nicole',
#  'Tom Cruise',
#  '@melduckie',
#  "Debra Messing's",
#  'Clint Eastwood',
#  "Michael J. Fox'",
#  'Jack Antonoff',
#  'wow lucy',
#  'RT @yess321',
#  'Sexiest',
#  'Fufufu',
#  'Glad',
#  'Taylor Swift - Golden',
#  'Lila',
#  'Jessie',
#  'Lakers',
#  'Lol',
#  '@DowntonAbbey',
#  'Cher',
#  'Anna Hathaway',
#  'Calc',
#  'Young',
#  'Julianne moore',
#  'Jamie Kennedy',
#  'Barbie',
#  'TSwift',
#  '@tedgibson',
#  'Jennifer Looks',
#  'Soo',
#  'Omg Lea Michelle',
#  'Jennifer Lopez SEMPRE',
#  'Colorful Jennifer',
#  'Taylor Swift’s',
#  '@kerrywashington',
#  'Amy Poehler - Ladies',
#  'jeeeez',
#  'Kathryn',
#  'Rockin',
#  'Catherine zeta jones',
#  'Freaken',
#  'David',
#  "Sally Fields'",
#  'Halle Berry Allen',
#  'Bitch',
#  'Amy Poehler Show',
#  'Garnier',
#  'Sally',
#  'Jodie Foster - Golden',
#  'Barbara Palvin',
#  'RT @GreggyBennett',
#  'Taylor Swift     ',
#  'Kelly O. es de Fashion',
#  'JAMIE',
#  "Bill Rodham Clinton'",
#  'David Faustino',
#  'Bill Maher',
#  'Ron Reagan',
#  'barbara',
#  'Ok Eva Longoria',
#  'GORGEOUS  ',
#  'lez',
#  'Jennifer Anniston',
#  '@Possessionista',
#  'Claire Dane',
#  'Fishtail',
#  'Xox',
#  'Salma n Eva',
#  'Yosemite Sam',
#  'RT @MTVNews',
#  "Amy Poehler's",
#  'Robert Goulet',
#  'Tasty',
#  '@msleamichele dang boo',
#  'Kate',
#  'Johnny',
#  'Abe Lincoln',
#  'Miren Adele',
#  'Eva longoria',
#  'Eddie',
#  'Swift',
#  'Amy Adams Golden',
#  'Steve',
#  "Natalie Morales'",
#  'Ahh @msleamichele',
#  'Doritos',
#  'Memoriam',
#  '@GLEEonFOX Lea Michele Is Ethereal',
#  'Sigh',
#  'Beatles',
#  'Damn Halle',
#  'Adele Debuts',
#  'Greenbriar',
#  "Jamie Foxx's",
#  'Mary',
#  'Quinton Tarantino',
#  'Gave Adele',
#  'Adele Debuts Post-Baby Body',
#  'Edward',
#  'Robert Downey Jr. Looked',
#  'RT @essencemag',
#  'Holywood',
#  'Amy Adams - Golden',
#  "Julianna Marguiles'",
#  '@prodigalsam',
#  "Amy Pohler's",
#  'Michael J Foxs',
#  'Jessica Rabbit  ',
#  'Grumpy',
#  'catch---&gt;“@EricIGN',
#  'Bill',
#  'Ben Afleck',
#  'Catherine',
#  '@Coops_tv',
#  'Dang',
#  'Harvey Keitel',
#  '@OfficialAdele',
#  'Mierda',
#  'Gif',
#  'Joaquin',
#  'Evan Longoria',
#  'Award Season',
#  "Taylor Swift Talks Writing '",
#  'Barbara',
#  'Ariel RT@NickFlora:',
#  'Gollum',
#  '@iloveFireangel Amy Adams',
#  'Liza Minnelli',
#  'Salma Hyek',
#  'Lol Jamie Foxx',
#  'Jessica Chastain’s',
#  'spencerbarnesla',
#  'Woah Megan Fox',
#  "Josh Charles'",
#  'Michael J. Foxs',
#  'Haley Berry',
#  'el look de Lea Michele',
#  'JLawrence',
#  'God',
#  'Malibu Barbie',
#  'Michael Kors  @emilyblunt',
#  'Jen Garner',
#  'Hellloo Salma HAYAK',
#  'McQueen',
#  'Emily Blunt de @MichaelKors',
#  'Jay-Lo',
#  'Sid',
#  'Walter White',
#  'Jajaja',
#  'Jennifer Lopez - Golden',
#  'Hubba',
#  'RT @AntDeRosa',
#  '@Burberry',
#  'Silver Fox',
#  'Robert Pattinson News - Rob',
#  'Micheal J. Fox',
#  'NOOOOWW',
#  'Leonardo Dicaprio',
#  '@abbymargaret',
#  'Helena Bonham Carter Golden Globes Dress',
#  'Jodie',
#  '@RHW',
#  'Halle Looks',
#  'Kinda',
#  'Jennifer',
#  'Kerry Washington Golden',
#  "Lucy Lu's",
#  'un link de los Golden Globes',
#  'Yay',
#  'Liza Minelli LOL',
#  'Extras',
#  "Sienna  Miller's",
#  'Lucy Lieu',
#  'Nic Kidman',
#  'Robby',
#  'Marshall',
#  '@1Mhari',
#  'Qué tal su',
#  'Anne',
#  'RT @BlogXilla',
#  'RT @RollingOut',
#  'Jessica',
#  'Mortimer',
#  'B. Leo',
#  'Jessica Chaistain',
#  'Debra...',
#  'Claire',
#  'Kerry @GoldenGlobes Dress',
#  'Beautifulllllllll',
#  'Drag',
#  'Jim Parsons',
#  '@elieandi',
#  'Mary Phillips',
#  'Matt',
#  'Mask',
#  'WOWOWOWOWOWOWOWW Eva Longoria',
#  '@evalongoria',
#  'Michael Cinco',
#  'JLaw',
#  "Lea michele's",
#  '-GM',
#  'Robert Downey JR',
#  'Beetlejuice',
#  "Amy Adam's",
#  'Givenchy',
#  'Family Guy',
#  'Yoplait',
#  'Rick',
#  'Catherine Zeta Johns',
#  'Lena',
#  'Jem',
#  'Megan Fox - Here',
#  "Jenn Law's",
#  'Steven Spielberg',
#  'Guilliana',
#  'Yoshiki',
#  'Jamie',
#  'Bahaha',
#  'Lucy Liu - Golden',
#  'Rosie Perez',
#  'Wolfman',
#  'Ben Affleck - Golden',
#  'Diulang',
#  'Eva @EvaLongoria',
#  'Nicole Kidmans',
#  'Sienna Miller &',
#  'Allison',
#  'Hysterical',
#  'Leo DiCaprio',
#  'gustó el  de Lucy Liu',
#  'Tina',
#  'Lo único que espero de los  es',
#  'Jo Lo',
#  'Kaepernick',
#  'App',
#  'God Bless Jennifer Lopez',
#  'Hooper',
#  'Annie',
#  'Hathaway',
#  '@rolandsmartin Jennifer',
#  'Hillary Clinton',
#  'swag',
#  'Amy Poehler +',
#  'Tom Selleck',
#  '@Bartonth07',
#  'Sienna Millers',
#  'EStá',
#  'RT @Lyfelong',
#  '@carlymckinley',
#  'Versace',
#  "Matt LeBlanc's",
#  'Julia Louis-Dreyfus Keep',
#  'Lols',
#  'Jessica Chastain Golden',
#  'Kerry w',
#  '@MeganFox',
#  'Gorge',
#  'Damn Johnny',
#  'Awww Jessica Chastain',
#  'Dana Brody',
#  'Down',
#  'Loved Kerry Washington',
#  'Jennifer Lawrence Paid',
#  "Kelly Osbourne's",
#  'Julianna',
#  'taylor',
#  'Leo Dicaprio',
#  'Jennifer Lawrence Wear Orange Dior Couture  ',
#  'Ohhh Mini J. Fox',
#  '@kevinpennant',
#  'Countess',
#  'Yuck',
#  'RT @catherinekamei',
#  '@NosnhojAiam',
#  ...}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/42/1tm0lh9x4mq_b_x54vd3y4700000gn/T/ipykernel_99030/2057355497.py in <module>
#      46 #combine counts in the entity_counts dictionary
#      47 for non_rep in entities_to_remove:
# ---> 48     entities_counts[entities_clusters[non_rep]] += entities_counts.pop(non_rep)
#      49
#      50 #entities_counts
#
# KeyError: 'Julia'

# %%
#find out if there is one host or multiple hosts

host_as_verb = [] #list of all tweets with host/hosts/hosting as a verb
host_as_noun = [] #list of all tweets with host/hosts as a noun
host_singular = 0 #count of all tweets implying a single host
host_plural = 0 #count of all tweets implying more than one host
for tweet in parsed_tweets:
    host_index = 0
    for token in tweet:
        if re.search("host", token.text.lower()):
            if token.pos_ == "VERB":
                host_as_verb.append(tweet)
                if token.text.lower() == "host":
                    host_plural += 1
                elif token.text.lower() == "hosts":
                    host_singular += 1
                break
            elif token.pos_ == "NOUN":
                host_as_noun.append(tweet)
                if token.text.lower() == "hosts":
                    host_plural += 1
                elif token.text.lower() == "host":
                    host_singular += 1
                break
        else:
            host_index += 1

#host_as_verb
#host_as_noun
#print("one host: " + str(host_singular) + "; multiple hosts: " + str(host_plural) + "\n")

if host_singular >= host_plural:
    likely_host = ""
    likely_host_count = 0
    for candidate in entities_counts:
        if entities_counts[candidate] >= likely_host_count:
            likely_host = candidate
            likely_host_count = entities_counts[candidate]
    print("The host is " + likely_host)
else:
    vote_distribution = list(entities_counts.values())
    average_count = sum(vote_distribution)/len(vote_distribution)
    likely_hosts = []
    for candidate in entities_counts:
        if entities_counts[candidate] >= average_count:
            likely_hosts.append(candidate)
    likely_hosts = sorted(likely_hosts, key = lambda e : entities_counts[e], reverse = True)
    #must be at least 2 hosts - start cutoffs at index 1
    for i in range(1, len(likely_hosts) - 1):
        if entities_counts[likely_hosts[i + 1]] / entities_counts[likely_hosts[i]] < 0.5:
            likely_hosts = likely_hosts[:i+1]
            break
    print("The hosts are " + str(likely_hosts))
# Out:
# The hosts are ['Amy Poehler', 'Tina Fey']

# %%
if "Julia" in entities_clusters:
    print("Julia is in here")
# Out:
# Julia is in here
