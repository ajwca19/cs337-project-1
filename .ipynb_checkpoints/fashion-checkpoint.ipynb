# %%
#importing necessary modules - pandas, nltk, regex, spacy, and RNG
import pandas as pd
import nltk
from nltk.tokenize import word_tokenize
from nltk.tag import pos_tag
import re
import math
import random
import spacy
from spacy import displacy
from spacytextblob.spacytextblob import SpacyTextBlob
from collections import Counter
import en_core_web_sm

nlp = en_core_web_sm.load()
nltk.download("punkt")
nlp.add_pipe('spacytextblob')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/adenweiser/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
# Setting up notebook to display multiple outputs in one cell
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
# Reading in and processing the gg2013 tweets file
tweets = pd.read_json('gg2013.json')

#takes in a tweet and removes the retweet and any hyperlinks
def clean_tweet(tweet_text):
    retweet_re = "^[rR][tT] @[a-zA-Z0-9_]*: "
    hyperlink_re = "http://[a-zA-Z0-9./-]*"
    hashtag_re = "#[a-zA-Z0-9_]+"
    return re.sub(hyperlink_re, "", re.sub(hashtag_re, "", tweet_text))

#read in tweets and make them nice and clean
for i in range(0, len(tweets)): 
    cleaned_tweet = clean_tweet(tweets.loc[i]['text'])
    tweets.at[i, 'text'] = cleaned_tweet
tweets

# Ceremony Name
ceremony_name = "Golden Globes 2013"
# Out:
#                                                      text  \
# 0                                          JLo's dress!
# 1       What's making Sofia Vergara's boobs stay like ...
# 2       RT @FabSugar: Kerry Washington is EVERYTHING. ...
# 3                       Anne Hathaway has got me living.
# 4                 Jennifer Lopez's lace dress? Thoughts?
# ...                                                   ...
# 174638  RT @authorViviAnna: I was sad that Mandy Patin...
# 174639  RT @_ItzelMartinez_: Jennifer Lawrence aceptan...
# 174640  Golden Globes, lots of fashion messes...but gl...
# 174641  Did they have mug shots at the golden globes?!...
# 174642  Says @BenAffleck: "I also didn't get the Actin...
#
#                                                      user                  id  \
# 0           {'screen_name': 'Dozaaa_xo', 'id': 557374298}  290620657987887104
# 1         {'screen_name': 'theAmberShow', 'id': 14648726}  290620657887219713
# 2             {'screen_name': 'SweetyPW', 'id': 35498686}  290620657828524032
# 3       {'screen_name': '_NicoleEdwards', 'id': 144430...  290620657799159809
# 4       {'screen_name': 'lolaogunnaike', 'id': 134953223}  290620657778188288
# ...                                                   ...                 ...
# 174638        {'screen_name': 'dana1204', 'id': 18091543}  290675889379876864
# 174639  {'screen_name': 'IamTrisEverdeen', 'id': 55126...  290675889128230914
# 174640   {'screen_name': 'Dpharmakis23', 'id': 852045842}  290675893024747523
# 174641  {'screen_name': 'reynaramirez22', 'id': 22732662}  290675888763314178
# 174642    {'screen_name': 'goldenglobes', 'id': 18667907}  290675893494484992
#
#               timestamp_ms
# 0      2013-01-14 00:45:38
# 1      2013-01-14 00:45:38
# 2      2013-01-14 00:45:38
# 3      2013-01-14 00:45:38
# 4      2013-01-14 00:45:38
# ...                    ...
# 174638 2013-01-14 04:25:07
# 174639 2013-01-14 04:25:07
# 174640 2013-01-14 04:25:08
# 174641 2013-01-14 04:25:08
# 174642 2013-01-14 04:25:08
#
# [174643 rows x 4 columns]

# %%
tweets_with_fashion_mention = [] #list of strings containing fashion-related-words
    
def is_fashion_relevant(tweet_text):
    fashion_keywords = ["dress", "outfit", "fashion", "red carpet", "suit", "look", "jewelry", "accessor[y|ies]"]
    for keyword in fashion_keywords:
        if re.search(keyword, tweet_text.lower()):
            return True
    return False

for i in range(0, len(tweets)):
    tweet_text = tweets.loc[i]['text']
    if is_fashion_relevant(tweet_text) and not re.search("^[Rr][Tt]", tweet_text):
        tweets_with_fashion_mention.append(tweet_text)

# %%
#TAG ENTITIES
entities_counts = {} #dictionary with key: entity name and value: number of appearances in tweets
entities_clusters = {} #dictionary with key: entity name and value: name of "representative" entity
entities_polarities = {}
parsed_tweets = []
for tweet in tweets_with_fashion_mention:
    parsed_tweet = nlp(tweet)
    parsed_tweets.append(parsed_tweet)
    for entity in parsed_tweet.ents:
        if entity.label_ == "PERSON" and re.match("[a-zA-Z0-9\.'’+-_@/]+", entity.text) and not re.search("\(|\)", entity.text):
            person = entity.text
            if person in entities_clusters:
                entities_polarities[person] = (entities_counts[person] * entities_polarities[person] + parsed_tweet._.blob.polarity) / (entities_counts[person] + 1) 
                entities_counts[person] += 1
            else:
                entities_counts[person] = 1
                entities_polarities[person] = parsed_tweet._.blob.polarity
                entities_clusters[person] = person
#entities_counts

entities_to_remove = set()
for entity_a in entities_clusters:
    #print("\n\n\n ENTITY A: " + entity_a)
    for entity_b in entities_clusters:
        #print("\n ENTITY B: " + entity_b + "\n_____________\n")
        if entities_counts[entity_a] >= entities_counts[entity_b]:
            #entity a is more popular than entity b
            entity_a_tokens = entity_a.split(" ")
            entity_b_tokens = entity_b.split(" ")
            for entity_a_token in entity_a_tokens:
                #print("entity a token: " + entity_a_token)
                if len(entity_a_token) >= len(entity_b) and re.search(entity_a_token, entity_b):
                    #entities are a match! cluster them accordingly
                    #print("clustering: " + entity_b + " in group led by " + entities_clusters[entity_a] + "\n")
                    entities_clusters[entity_b] = entities_clusters[entity_a]
                    entities_to_remove.add(entity_b)
                    break
            for entity_b_token in entity_b_tokens:
                #print("entity b token:" + entity_b_token)
                if len(entity_b_token) >= len(entity_a) and re.search(entity_b_token, entity_a):
                    #entities are a match! cluster them accordingly
                    #print("clustering: " + entity_b + " in group led by " + entities_clusters[entity_a] + "\n")
                    entities_clusters[entity_b] = entities_clusters[entity_a]
                    entities_to_remove.add(entity_b)
                    break
#entities_clusters
#entities_to_remove

#combine counts in the entity_counts dictionary
for non_rep in entities_to_remove:
    if entities_clusters[non_rep] in entities_counts:
        entities_polarities[entities_clusters[non_rep]] = (entities_polarities[entities_clusters[non_rep]] * entities_counts[entities_clusters[non_rep]] + entities_polarities[non_rep] * entities_counts[non_rep])/(entities_counts[entities_clusters[non_rep]] + entities_counts[non_rep])
        entities_counts[entities_clusters[non_rep]] += entities_counts.pop(non_rep)

#entities_polarities
# Out:
# {"Jennifer Lopez's": 0.24627976190476192,
#  'Hugh Jackman': 0.38830236892736897,
#  'Salmon Fishing': 0.01666666666666668,
#  'Kerry Washington': 0.4572348451196399,
#  'Miu Miu': 0.47812499999999997,
#  'Natalie Morales': -0.07499999999999996,
#  'Awkward Savannah': -0.39999999999999997,
#  "Kerry Washington's": 0.3799251700680272,
#  'Jlo': 0.19905222505668935,
#  "Jennifer Lawrence's": 0.19928951257076255,
#  'Ben Affleck': 0.23850413212159854,
#  'George Clooney': 0.31414007092198576,
#  'Helen Mirren': 0.36868686868686873,
#  'Drag': -0.1,
#  'Jennifer Lopez': 0.27201160309996525,
#  'Anjelica Huston': 0.0,
#  "Sienna Miller's": 0.145,
#  'Jennifer Lawrence': 0.2953335634644126,
#  'Rachel Weisz': 0.5285714285714286,
#  'Kristen Wiig': 0.3849396789965987,
#  'Anne Hathaway': 0.34287831926774615,
#  "Helen Mirren's": -0.1611111111111111,
#  'Yuck': -0.122,
#  "Anne Hathaway's": 0.21363510101010108,
#  'Kate Hudson': 0.45681283948851964,
#  'Marion Cotillard': 0.28396012050653596,
#  'Ewan McGregor': 0.3255208333333333,
#  'Sienna Miller': -0.11729870129870129,
#  "Looooove Anne Hathaway's": 0.0,
#  'Audrey': 0.06666666666666667,
#  'Ricky Gervais': 0.04999999999999999,
#  'Sofia Vergara': 0.3425963275935374,
#  "Kate Hudson's": 0.2511264810323545,
#  'Tina Fey': 0.39226665923311616,
#  'Amy Poehler': 0.32597063006438,
#  'Matt Lauer': 0.19637445887445887,
#  'Lea Michele': 0.23421654929577468,
#  'Jessica Chastain': 0.3209402163643235,
#  'Meryl Streep': 0.15,
#  'Paranorman': 0.7,
#  'Nicole Kidmans': 0.0,
#  'Anne Hathaways': 0.50625,
#  'Kristin Wiig': 0.20796085858585858,
#  'Leonardo Dicaprio': 0.43125,
#  'Nicole Kidman': 0.29378726287262874,
#  'Harry Winston': 0.0,
#  'Halle Berry': 0.12187142255892254,
#  'Jessica Chastain/': 0.0,
#  'Al Roker': -0.0033333333333333353,
#  'Hysterical': -1.0,
#  'Claire Danes': 0.2951088810179721,
#  'Kevin Dior': 0.8125,
#  "Jessica Chastain's": 0.21698452818627453,
#  'Jessica': 0.22817460317460317,
#  'Jessica Chastian': 0.0,
#  'David': 0.22000000000000003,
#  'Leonardo DiCaprio': 0.440330459770115,
#  'Kidman': 0.0,
#  'Lucy Liu': 0.27377570346320346,
#  'Hayden Panettiere': 0.2831944444444444,
#  'Roberto Cavalli': 0.07916666666666666,
#  'Leo DiCaprio': 0.22916666666666666,
#  'Julianne Moore': 0.39045493197278924,
#  'Jessica Rabbit': 0.5666666666666667,
#  'Salma Hayek': 0.30893787202380957,
#  '@HeIenMirren': 0.0,
#  'Miranda Kerr': 0.43353174603174605,
#  'jessica chastain': 0.37500000000000006,
#  'Julianna': 0.26805555555555555,
#  'Jon Hamm': 0.3896362433862434,
#  "i'mma": 0.0,
#  '@siennamiller': 0.35,
#  'Adele': 0.2889705963831391,
#  'Marshall': 0.16666666666666666,
#  'Orlando Bloom': 0.42170138888888886,
#  'Stacy Kiebler': -0.01499999999999999,
#  'Amy': 0.3503081101873716,
#  'Bradley Cooper': 0.3643856837606838,
#  "Julianna Margulies'": 1.0,
#  'Sofia Vagara': 0.0,
#  'XOXO Gossip Guy': 0.0625,
#  'Globes': 0.1924162257495591,
#  'Emily Blunt': 0.39406231628453847,
#  'George klooneys': 0.7,
#  'Ann Taylor': 0.25,
#  'Hathway': 0.25,
#  'Felt': 0.25,
#  'Katie Couric': 0.3,
#  'Rob Pattinson': 0.3458333333333334,
#  "Steve Odekerk's": 0.192,
#  'Thumb': 0.08,
#  'Alexander McQueen  ': 0.325,
#  "Nicole Richie's": 0.5,
#  'Thatcher': 0.494140625,
#  'Seacrest': 0.0,
#  'Lol': 0.5652777777777778,
#  'Damn @LeoDiCaprio': -0.04166666666666666,
#  'Lol  ': 0.39166666666666666,
#  'Amy Adams': 0.4358074294532628,
#  'Marchesa': 0.2368229166666666,
#  'anne hathaway': 0.0012500000000000011,
#  'Jessica Alba': 0.44595259319673386,
#  '@cocoperez': 0.23333333333333334,
#  'Stacey Keibler': 0.4739583333333333,
#  "Julianna Marguiles'": 0.625,
#  'Hellloo Salma HAYAK': 0.625,
#  'Looking Fab': 0.78125,
#  'Leonardo di Caprio': 0.25,
#  'Met Ball': 0.1875,
#  'Burberry': 0.17361111111111113,
#  'Stacy Keibler': 0.5111111111111112,
#  'Mel Gibson': -0.0827557882014308,
#  'Jack': 0.24666666666666667,
#  'Sophia Vergara': 0.4916666666666667,
#  'Jen': 0.41125000000000006,
#  'Jolie': 0.06666666666666667,
#  'Sofia Vergera': 0.0,
#  'Bollywood': 0.30000000000000004,
#  'Aziz Ansari': 0.3,
#  '@msleamichele': 0.563076636904762,
#  'Lea': 0.34420905080782305,
#  'Katherine McPhee': 0.5928571428571429,
#  'kerry washington': 0.6583333333333333,
#  'Blunt': 0.3392857142857143,
#  'John Hamm': 0.5666666666666667,
#  'Colombian Fran Drescher': 0.0,
#  'Isla Fisher': 0.5677579365079365,
#  'Nicole': 0.6444444444444445,
#  "Sofia Vergara's": 0.2,
#  "Amanda Seyfried's": 0.20833333333333334,
#  'matt lauer': -0.2333333333333333,
#  "Lorraine O'Neal": 0.0,
#  'Benedict Cumberbatch - Red Carpet': 0.0,
#  'Sarah Hyland': 0.35565476190476186,
#  'semana teremos looks de  por lá': 0.3125,
#  'the Sofia Vergara': 0.3,
#  "Lucy Liu's": 0.15266545174833218,
#  '@Bartonth07': 0.7,
#  "@kellidaisy Anne's": 0.5,
#  "Zosia Mamet's": 0.25,
#  'Nicole Richie': 0.304369212962963,
#  'Julianne Hough': 0.3814814814814815,
#  'Ariel Winter': 0.3330357142857143,
#  '@Andrew_Brawley Looks': 0.3,
#  'Ariel...  ': 0.375,
#  'Alyssa Sutter': 0.3,
#  'Gilliana': -0.20703125,
#  'Golden Globes': 0.26356770385974276,
#  'Taylor Swift': 0.1893382543087582,
#  'Atelier Gown  ': 0.175,
#  'Amanda Seifried': 0.390625,
#  'ainda ta': 0.0,
#  'Kelly Osbourne': 0.22857142857142856,
#  'Zac Posen': 0.925,
#  'Taylor': 0.31351731601731614,
#  'Lucy Lui': 0.046590909090909086,
#  'Nana Greenbergs': 0.3125,
#  '-BP': 0.15000000000000002,
#  'JE MEURS AVEC': 0.0,
#  'MEC BORDEL': 0.0,
#  'Sienna': -0.325,
#  'Lucy Luis': 0.08333333333333334,
#  'Kelly': 0.25,
#  'Que': 0.018750000000000003,
#  'la presi': 0.0,
#  'antejos negros': 0.0,
#  'EStá': 0.0,
#  'Giuliana Rancic': -0.178125,
#  'Haley Berry': 0.125,
#  'Que decepción las dos': 0.0,
#  'Qué': 0.0,
#  'RT @essencemag': 0.6625,
#  "Amy Poehler's": 0.31622807017543864,
#  'Sally': 0.3118506493506494,
#  'Julia Louis Dreyfus': 0.0,
#  'Megan Fox Is Cranky': 0.125,
#  'Michael Cinco': 0.0,
#  'Omg Sara Hyland': 0.0,
#  "Jay Leno's": 0.0,
#  'Alexander McQueen': 0.4405145202020202,
#  'Buahaha xD': 0.275,
#  '@cfda': 1.0,
#  'the Gretchen Wiener': 0.15,
#  'Jay Leno': 0.18143601190476188,
#  'Julianna Margulies': 0.2902777777777778,
#  'Jeremy Renner': 0.19157196969696966,
#  'Que Hace @ALDORENDON': 0.15,
#  "Ann Hathaway's": -0.11249999999999999,
#  'Ross': 0.0,
#  'Nurse Hathaway': 0.0,
#  'McQueen': 0.2620580808080808,
#  "Lena Dunham's": -0.12999999999999998,
#  'WOOOOW': 0.54,
#  'J. Lo': 0.29772727272727273,
#  'Qué tal su': 0.0,
#  'Premio al más hortera': 0.0,
#  'Love Anne Hathaway': 0.25,
#  'Gorge': 0.22916666666666666,
#  'Jesus': 0.06358024691358026,
#  '@haydenpanettier': 0.7,
#  'Dustin Hoffman': 0.01747222222222222,
#  "Lucy Luis's": -0.0078125,
#  'Guliana Rancic': 0.35,
#  "Emily Blunt's": 0.275,
#  'NICOLE RICHIE': 0.15,
#  'tan fan de las Red Carpet': 0.1595238095238095,
#  'Esto de mirar': 0.15,
#  '[ Sofia Vergara': -0.16666666666666666,
#  'Jennifer Lawrence Paid': -0.1625,
#  'Tom Ford': 0.19047880116959068,
#  'Ahora': 0.0,
#  'Rob': 0.2934698879551821,
#  'Ryan Seacrest': 0.08125,
#  'Linda Gray @': 0.25,
#  'Nene Leakes': 0.10868055555555556,
#  'Gloria': 0.0,
#  'Definitivamente Gloria': 0.0,
#  'Aaaaaaaaaaaaah': 1.0,
#  'Sarah Paulson': 0.21071428571428572,
#  'Lana Banana': 0.0,
#  'Michelle Dockery': 0.6006481481481483,
#  '@popcouturejjw4': 0.0,
#  'julianne margulis': -0.3499999999999999,
#  'me"-Dustin Hoffmann': 0.19642857142857142,
#  '@Burberry': 0.14636437908496733,
#  'Helena Bonham Carter': 0.16874999999999998,
#  'Any Poehler': 1.0,
#  'Anne Hathaway de @Chanel': 0.0,
#  "Julianna Moore's Custom": 0.0,
#  'Alyssa Milano': 1.0,
#  'Longoria': 0.42361111111111116,
#  'Seyfried': 0.0,
#  "bill belichick's": 0.1,
#  'Aubergine': 0.7729166666666667,
#  'Ravens': 0.3,
#  'Eva Longoria': 0.40703237734487735,
#  'Amanda Seyfried': 0.3923106060606061,
#  'Paul Rudd': 0.045039682539682525,
#  "Julianne Moore's": 0.17301136363636366,
#  "Dustin Hoffman's": 0.14285714285714285,
#  'Guilliana': 0.14375,
#  "Loved Nicole Kidman's": -0.11250000000000002,
#  'Winner': 0.2,
#  "Kate Capshaw's": 0.375,
#  'Crimson Chin': 0.0,
#  'Hayden': -0.2888888888888889,
#  '@MARIELhaenn @robzangardi  ': 1.0,
#  'every1': 0.0,
#  "Loving Stacy Keibler's": 0.9375,
#  'Saw Jay Leno': 0.0,
#  'Frankenstein': 0.041666666666666664,
#  'w/ Sofia Vergara': 0.4166666666666667,
#  'Katharine McPhee': 0.6416666666666667,
#  "vanno d'accordo": 0.0,
#  'io volevo vederla': 0.0,
#  'volevo porca miseria': 0.0,
#  'RT @tomandlorenzo Nicole Kidman': 1.0,
#  'Alexander McQueen  2013': 1.0,
#  'Jodie Foster': 0.27806206833878633,
#  'Yoplait': 0.12,
#  'Lisa Kudrow': 0.12,
#  'Guiliana': -0.05000000000000001,
#  '@BCBGMAXAZRIA @Sarah_Hyland': 0.7375,
#  'George Clooneys': 0.625,
#  'Stacey': 0.625,
#  'Naomi Watts': 0.7017857142857142,
#  'alguien tiene': 0.15,
#  'dirección para': 0.15,
#  "Natalie Morales'": 0.26875000000000004,
#  '@FashionBlogg': -1.0,
#  'esa tela de tapiz de Carolina Herrera': -1.0,
#  'gusta el nuevo estilo de Kelly Osbourne': 0.0,
#  "Amy Adams'": 0.04999999999999999,
#  "Sally Fields'": -0.5,
#  'RT @BlogXilla': 0.25,
#  "Tina Fey's": 0.37422483766233766,
#  'Tina': 0.4397615191772802,
#  'Taylor Swift 1.': 0.23333333333333334,
#  'Award': 0.11496598639455782,
#  'Bella': 0.0,
#  'nuevo look Lea Michelle': 0.0,
#  'Bill Murray': 0.0801918512658227,
#  'Xmas': 0.3666666666666667,
#  'Jamie Kennedy': 0.2642857142857143,
#  'Chillin': 0.15,
#  'Barbara': 0.24375000000000002,
#  'Photo Gallery - Yahoo': 0.1833333333333333,
#  'Tina Feys': 0.3,
#  'Upper Darby': 0.1953125,
#  "Bill Murray's": 0.1125,
#  'Tina Fey + Amy Poehler': 0.5,
#  'Murray': 0.125,
#  'Jennifer Garner': 0.2833809728949329,
#  'Amy Phoeler': 0.02499999999999998,
#  '@melduckie': 0.275,
#  'GORGEOUS': 0.5574074074074074,
#  'Bill murrahy looks old': 0.55,
#  'Ahhhhhhmaaaazing': 0.0,
#  'Claire Danes Looking': 0.5333333333333333,
#  'Olivia Munn': 0.13333333333333333,
#  'Nic Kidman': 0.19999999999999998,
#  '@kzarrilli': 0.48828125,
#  "Albert Finney's": 0.3,
#  '@niecie797 @mini_mo': 0.0,
#  'bill murray': 0.375,
#  'cielo': 0.0,
#  'Tarantino': 0.1929591836734694,
#  'Jessica Rabbit  ': 0.0,
#  'Zooey Deschanel': 0.12160569105691058,
#  'Rosario Dawson': 0.07322781385281384,
#  'Taylor Swift     ': 0.15681818181818183,
#  'Jennifer Lawerence': 0.21818181818181817,
#  'Amy Pohler': 0.3770833333333334,
#  "Loving Amy's": 0.3,
#  "Tina Fey'S": 0.732421875,
#  'wowza': 0.5,
#  'kristen wiig': 0.5,
#  'Glenn Close': -0.22359453837076823,
#  'Loretta Switt-esque': 0.44999999999999996,
#  'Damn Tina Fey': 0.7,
#  'Damn Helen Mirren': 0.5625,
#  'de la red carpet': 0.0,
#  'Ariel': 0.016369047619047616,
#  'Liz Lemon': 0.0,
#  'taylor': 0.28041666666666665,
#  'sarah hyland': 0.5,
#  'Selena Gomez': 0.4616907713498622,
#  'Vanessa Hudgen': 0.0,
#  'Robert Downey Jr': 0.34375,
#  'Mortimer': -0.09375,
#  'RT @xosdlc': 0.23827380952380958,
#  'David Faustino': 0.0,
#  'Dayummm Tina Fey': 0.55,
#  'robert pattinson': -0.5,
#  "Via BBC's": -0.39,
#  'BUT Miranda Kerr': 0.78125,
#  'Tiny Fey': 0.35,
#  'Sienna Miller Golden Globes': 0.10958333333333334,
#  'Kristen Bell': 0.3036638888888889,
#  'Waaaah': 0.17045454545454544,
#  'Ini': 0.17045454545454544,
#  'Fufufu': 0.17045454545454544,
#  'Jessica Chastain Golden': 0.1578125,
#  'Allison Williams Golden': 0.16999999999999998,
#  'Natalie': 0.3375,
#  'Matt': 0.3375,
#  'Al': 0.3375,
#  'Robby': 0.5,
#  'Richard Gere': 0.038888888888888876,
#  'Mel': -0.16597222222222222,
#  'Garnier': 0.0,
#  "Margaery Tyrell's": 0.0,
#  'Barbie': 0.23333333333333334,
#  'Megan Fox': 0.22493684895833332,
#  'Giorgio Armani': 0.07638888888888888,
#  "Amy Adam's": 0.5,
#  'Gibson': 0.0,
#  'Ben': 0.19074652777777779,
#  'ANNE': 0.6000000000000001,
#  'Grinch': 0.0,
#  '@evalongoria': 0.425,
#  'Jessica Rabbit-esque': 0.0,
#  'Amy Poehlers': 0.29523809523809524,
#  'Jennifer Garner - Affleck': 0.25,
#  'de Anne Hathaway': 0.0,
#  'Jenn Garner': 0.64,
#  'Robert Pattinson': 0.4218413978494624,
#  'Julia': 0.238671875,
#  'Amy Poehler - Ladies': -0.5,
#  'Hilary Swank': 0.3,
#  '@carlymckinley': 0.15,
#  'Lucy Liu’s': 0.3,
#  '@popsugar': 0.41006944444444443,
#  'Woooow': 0.9375000000000001,
#  '@JennmOneto Favorite': 0.3,
#  'heboh tereak2': 0.0,
#  'mato anne hathaway': 0.0,
#  'Quentin Tarantino': 0.04784461152882206,
#  'Yum': 0.0,
#  'Zooey Deschanel Recalls Joint Wardrobe Malfunction': 0.15,
#  'Donna Karan Atelier': 0.37659722222222225,
#  'Ang Lee': 0.024999999999999998,
#  'Mandy Patinkin': 0.47999999999999987,
#  'BILL MURRAY': 0.0,
#  'Vera Wang': 0.30000000000000004,
#  'Aziz Ansari Spoofs': 0.11409090909090909,
#  'Daniel Day Lewis': 0.07793650793650794,
#  '@EmilyB Tina': 0.0,
#  'Tintin': 0.0,
#  'Daniel Day-Lewis': 0.31251991349037245,
#  '@1Mhari': 0.2,
#  'Kate Hudsons': 0.17777777777777778,
#  'Rebecca Miller': 0.0,
#  'donna karan': 0.3,
#  'Kate': 0.35000000000000003,
#  'Tasty': 0.0,
#  'das indicadas': -0.25,
#  'Nicole Kidman de de McQueen': 0.0,
#  'Ahhhhhhhh Lea': 0.0,
#  'kate hudson': 0.1111111111111111,
#  "kate hudson's": 0.6000000000000001,
#  "Lea Michele's": 0.12722222222222224,
#  "Leonardo Dicaprio's": 0.875,
#  'Bradley': 0.30624999999999997,
#  '@EvaLongoria': 0.5227272727272727,
#  'un link de los Golden Globes': 0.15,
#  'Adele - Golden Globes': 0.15,
#  'Lea Michelle': 0.26409837136243386,
#  'Freaken': 0.6875,
#  'Goldie Hawn': -0.25,
#  'a Bob Mackie': 0.0,
#  'Ann': 0.15,
#  'Je...': 0.30000000000000004,
#  'Photo Gallery -': 0.09999999999999999,
#  'Tommy Lee Jones': 0.11037342287342283,
#  'Alexis Carrington': 0.1,
#  'Tommy lee jones': 0.11499999999999999,
#  "Taylor Swift's": 0.044588744588744594,
#  '@stephfedorov': 0.22499999999999998,
#  'Leo': 0.23979700854700856,
#  'Selma Hayek': 0.3175,
#  'Flash Gordon': 0.3125,
#  'Babyface': 0.0,
#  "Rob Pattinson's": 0.625,
#  'Omg Christoph Waltz': 0.16666666666666666,
#  'Daniel Craig': 0.4547727272727272,
#  'Leonardo': 0.10625000000000001,
#  'Christoph Waltz': 0.29666666666666663,
#  'Debra Messing': 0.20875,
#  'Tom': 0.15,
#  'Marky Mark': 0.7,
#  'Abe Lincoln': 0.25,
#  'Hudson': 0.0,
#  '@katehudson': 0.7333333333333334,
#  '@Katehudson': 0.0,
#  'Rip Van Winkle': 0.35,
#  'Damn Leonardo Dicaprio': 0.8,
#  'RT': 0.625,
#  'ardan los ojos': 0.0,
#  'Jew Hunter': 0.0,
#  '@redbookmag': 0.10416666666666666,
#  'bradley cooper': 0.3125,
#  'Glee': 0.14583333333333334,
#  'Leo Dicaprio': -1.0,
#  'Mierda': 0.1875,
#  'Mmm Leonardo': 0.4166666666666667,
#  'wow jennifer': -0.03333333333333333,
#  'Omg Kerry Washington': 0.0,
#  'Kerry Washington KILLS': 0.0,
#  'Kerry': 0.46680555555555553,
#  'Dennis Quaid': 0.10277777777777779,
#  '@MsSarahPaulson': 0.0,
#  'Kerry w': 0.625,
#  'Hey Kerry': 0.0,
#  'Blake': 0.08989898989898988,
#  'Leonardo Decaprio': 0.4,
#  'dick Lea': 0.625,
#  'Hayden Paneittiere': 0.4,
#  'Dennis Quads': 0.020000000000000018,
#  'Dennis': -0.5,
#  '@KateHudson': 0.0,
#  'GORGEOUS  ': 0.7,
#  'Ariel RT@NickFlora:': 0.15,
#  'Kerri Washington': 0.5315340909090909,
#  'Lucy Lieu': 0.5,
#  'Benedict': 0.1538095238095238,
#  'Dennis Quaids': 1.0,
#  'Lena Dunham': 0.06904143475572046,
#  "Jessica Alba's": 0.4583333333333333,
#  'Maggie Smith': 0.0,
#  'jessica alba': 0.0,
#  'Malibu Barbie': 0.5,
#  'James Cameron': 0.11666666666666665,
#  'Archie Panjabi': 0.5,
#  'Yessss': 0.0,
#  'Assistindo': 0.0,
#  'Randy Quaid': 0.5333333333333333,
#  'Oliver Stone': 0.3333333333333333,
#  'Sofia Vargara': 0.0,
#  'yo veo el': 0.15,
#  'GOREGOUS': 0.3,
#  'WANNA': -0.5,
#  'Beautifulllllllll': 0.0,
#  'a Ben Affleck': 0.0,
#  'Lo': 0.0,
#  'mal koegjfkejgegjt': 0.0,
#  'Hug': 0.85,
#  'Miren Adele': 0.575,
#  'Monique Lhuillier': 0.04288194444444441,
#  'Vanessa Hudgens': 0.37857142857142856,
#  'Michael Kors': 0.18875,
#  'Mark Cuban': -0.05,
#  'Coldwell Banker': -0.25,
#  'Django Unchained': 0.6,
#  'Taylor Swift Gorgeous On The Red Carpet': 0.3333333333333333,
#  'Estamos': 0.075,
#  'Ed Hardy': 0.0,
#  'Sofia Veraga': 0.0,
#  'Halle Berry Golden Globes Dress': 0.13571428571428573,
#  'Halley Berry': 0.06666666666666667,
#  'Eric Stonestreet': 0.19999999999999998,
#  'Julia Louis-Dreyfus Keep': 0.19999999999999998,
#  'Julianne Moore Golden': 0.26138888888888884,
#  'Eva': 0.39625,
#  'Nene': 0.09166666666666666,
#  "Eva Longoria's": 0.22778087797619048,
#  'Don Cheadle': 0.09091269841269842,
#  'Sam Fox': 0.08365384615384615,
#  'dresssss&gt;&gt;&gt;&gt': 0.0,
#  'Michael J Fox': 0.22890625,
#  'sam fox...': 0.0,
#  'Michael J. Fox': 0.0869047619047619,
#  'Eva longoria': 0.3898809523809524,
#  "Michael J Fox's": 0.058029513888888884,
#  "Michael J. Fox's": 0.06674107142857143,
#  'MICHAEL J. FOX': -0.8,
#  'Sam fox looks': 0.0,
#  'Angelina Jolie': 0.09999999999999999,
#  "Michael J. Fox'": 0.22199074074074074,
#  'Damn Eva Longoria': 0.5875,
#  'Sam': 0.15625,
#  'WOWOWOWOWOWOWOWW Eva Longoria': 0.625,
#  'Alex P Keaton': 1.0,
#  'Pure Fah-shon': 0.21428571428571427,
#  'Julian Moore': 0.55,
#  'Brian Austin Green': 0.016666666666666663,
#  'Kerrys': 0.7583333333333333,
#  'Kim Kardashian': 0.4928571428571428,
#  'Helena Bonham Carter Golden Globes Dress': 0.14999999999999997,
#  'Tony Parker': 0.5,
#  'Michael': 0.525,
#  'Glad': 0.5901041666666667,
#  'GoldenGlobes': 0.0,
#  'Alex P. Keaton': 0.2,
#  "Loving Eva's": 0.6,
#  'Patrick Adams': 0.7,
#  '@zacposen': 0.25,
#  'Jonathan': 0.37326388888888884,
#  'Danny Strong': 0.18229166666666663,
#  'A. Richard Gere': 0.2125,
#  'B. Leo': 0.2125,
#  'RT @amyodell': 0.0,
#  'Versace': 0.04666666666666667,
#  "Halle Berry's": -0.11035466269841265,
#  'John Shearer  ': 0.26666666666666666,
#  '@evalongoria smokin': 0.0,
#  'Linda': 0.0,
#  'Marty MCfly': 0.8,
#  'Bitch': 0.875,
#  'Angie': 0.55,
#  'James Bond': 0.34375,
#  'Kaley Cuoco': -0.08333333333333333,
#  'Diulang': 0.0,
#  'ini Megan': 0.0,
#  'Quaalude': 0.2857142857142857,
#  'Jennifer Lawrence Amy Adams': 0.30000000000000004,
#  'Pica Nutalli': 0.0,
#  'Si los  Fuesen': 0.0,
#  'haria el tierrudo de la': 0.0,
#  'mistook sarah paulson': -0.15555555555555559,
#  'ALLYN GOLDEN': 0.19999999999999998,
#  "Allison Williams'": 0.0,
#  "Nicole Kidman's": 0.34761904761904766,
#  'Chris Farley': -0.8,
#  "Sienna  Miller's": 0.0,
#  'Micheal J. Fox': 0.16666666666666666,
#  '@KeithUrban Woo': 1.0,
#  'Jessica Lange': 0.17571097883597886,
#  'Katharine McPhee Flashes': 0.06527777777777778,
#  'Sideboob': 0.06527777777777778,
#  'Adele Debuts Post-Baby Body': 0.14999999999999994,
#  'Jullianne Hough': 0.41250000000000003,
#  'Taylor Swift Wears Sexy': 0.22125,
#  'Zac Posen Gown': 0.3,
#  'Eva L': 0.6302083333333334,
#  'JULIANNE MOORE': 0.0,
#  'jeeeez': 0.7,
#  'Oscar Snubs': 0.36768518518518517,
#  '@NewsOnKidman': 0.7500000000000001,
#  'Mary': 0.57265625,
#  'Julianne': 0.05694444444444445,
#  'Joan Rivers': 0.14791666666666667,
#  'Jullian Moore': 0.7,
#  'Julianne Morre': 0.6000000000000001,
#  'Look Julianne': 0.4375,
#  "Julianne Hough's": 0.16464646464646468,
#  'Vanessa': 0.875,
#  'Julieanne Moore': 0.1,
#  '@mtvstyle': 0.43333333333333335,
#  'Taylor Swifts': 0.1,
#  'kinda blah  ': 0.0,
#  'encantaron las tendencias': -0.125,
#  '-Emily Blunt  ': 0.0,
#  'Catherine Zeta - Jones': 0.7083333333333334,
#  'Catherine Zeta-Jones': 0.090625,
#  'Bi Polar Zeta-Jones': 0.20833333333333334,
#  "Catherine Zeta-Jones'": 0.33245287698412695,
#  'Catherine': 0.0,
#  "Catherine Zeta Jones'": 0.4,
#  'Marty McFly': 0.125,
#  'Catherine Zeta Jones': 0.228030303030303,
#  'catherine zeta jonest': 0.0,
#  'Catherine Zeta': 0.4464285714285714,
#  'Catharine Zeta-Jones': 0.475,
#  'Catherine Zeta Johns': -0.5625,
#  '@Coops_tv': 0.0,
#  'Julianne moore': 0.6000000000000001,
#  'Darcy St. Fudge': 1.0,
#  'mañana Joan Rivers': 0.09,
#  'hará sentir': 0.15,
#  'Les Misérables': 1.0,
#  "Catherine Zeta-Jones's": 0.0,
#  'Peter Pan': -1.0,
#  'Kelly Osborn': 0.4,
#  'sienna miller': -0.6875,
#  'Lovin Old Hollywood': 0.3,
#  'Huff': 0.15,
#  "J. Lo's": 0.019675925925925944,
#  'venus williams': 0.875,
#  'angelina jolie looks': 0.16666666666666666,
#  'Kelly O. es de Fashion': 0.0,
#  '@NeNeLeakes Getty Images': 0.10000000000000002,
#  'TSwift': 0.0,
#  '@RSVPMagazine Jennifer Lawrence': -0.625,
#  'amp;Hallie Berry': -0.625,
#  'Catherine zeta jones': 0.85,
#  'catherine zeta jones': 0.9099999999999999,
#  'Allison': 0.49015151515151517,
#  'Ann Hathaway': 0.23862179487179486,
#  'Julianna Moore': 0.7333333333333334,
#  'Halle Barry': 0.25,
#  'Donna Karan': -0.03680555555555555,
#  'Hayden Panettier': 0.875,
#  "Sarah Palin's": 0.35,
#  'Doily': 0.0,
#  'Robert Downey Jr.': 0.23313795853269537,
#  'Safe Haven': 0.7000000000000001,
#  'Francesca Eastwood': 0.375,
#  'Tracy Pollen': 0.375,
#  'j.lo': -0.4,
#  'Ohmygod Taylor': 0.125,
#  "Tom Ford's": 0.0,
#  'Katherine Zeta Jones': 0.7,
#  'Enamel Earring': -0.01,
#  'Robert Pattinson News - Rob': 0.275,
#  'Presenters Robert': 0.14545454545454545,
#  'eva longoria': 0.0,
#  'Liza Minelli': 0.1,
#  'Zsa Zsa Gabor': 0.0,
#  'Liza Minelli LOL': 0.125,
#  'MICHAEL J': 0.7,
#  'Keepin': 0.5859375,
#  'mañana': 0.15,
#  'Liza': -0.1,
#  'Liborace': -0.1,
#  'Michael J Foxs': 0.0,
#  'Jeremy Irons': 0.10556500377928951,
#  'Taylor Swift - Golden': 0.15,
#  'Halle Looks': 0.6000000000000001,
#  'Ooh': 0.19374999999999998,
#  'Helen Hunt': 0.27621527777777777,
#  '@Eva Longoria Look': 0.9375000000000001,
#  'Thandie Newton': 0.15,
#  'Hall Berry': 0.2296875,
#  "Rosario Dawson's": -0.041666666666666664,
#  'Jennifer Lawrance': 0.0,
#  'Liza Minnelli': 0.4,
#  'Ohhhhhh Rosario Dawson': 0.0,
#  'Sorry Rosario Dawson': -0.5,
#  "Liza Minelli's": 0.0,
#  "Terri Schiavo's": 0.0,
#  'Hillary Clinton': 0.2916666666666667,
#  'Ro-Daws': 0.2,
#  'judy jetson': -0.16666666666666666,
#  'Gross': 0.0,
#  'Silver Fox': 0.0,
#  'Matt Leblanc': -0.034375,
#  'Helen': 1.0,
#  'Rosie Huntington-Whiteley': 0.0,
#  'Matt LeBlanc': 0.2,
#  'Vivienne Westwood Couture': 0.0,
#  'Salma': 0.4166666666666667,
#  'Latinas': 1.0,
#  "Damien Lewis's": 0.6,
#  'Steve': 0.6,
#  "Kaley Cuoco's": 0.5,
#  'DAANNGGGG': 0.5,
#  'Deborah Lippman': 0.46875,
#  'Steven': 0.65,
#  'Joey': 0.07543402777777777,
#  'Will McAvoy': 0.0,
#  'Selma Hayak': 0.79375,
#  'Damien Lewis': -0.04652777777777779,
#  'Hugh Laurie': 1.0,
#  'Brody': -0.2265625,
#  'Damian Lewis': 0.20833333333333334,
#  'Steve Buscemi': -0.0875,
#  'Golden Globe': 0.23958333333333334,
#  'Marty Jr': 0.12291666666666667,
#  'Marion Cotillard de @Dior': -0.5,
#  'Jajaja': 0.0,
#  'Holllaaaa': 0.5,
#  '@joandiminich': 0.25,
#  'Não vou': 0.0,
#  'muito': -1.1102230246251566e-17,
#  'Mmm Leonardo DiCaprio': 1.0,
#  'Jackie Weaver': -0.5,
#  'Regina George': 0.0,
#  '@ivllagecanada': 0.35357142857142854,
#  "Salma Hayek's": 0.037500000000000006,
#  'Kerry @GoldenGlobes Dress': 0.390625,
#  'Allen Luddon': 0.0,
#  'da Taylor': 0.15,
#  'ela tá': 0.15,
#  'mais linda': 0.16510416666666666,
#  'Whoah': 1.0,
#  'Saudades Justin Bieber': 0.16666666666666666,
#  'gato de': 0.16666666666666666,
#  'Harry Potter': 0.041666666666666664,
#  'paul': -0.375,
#  'Claire': 0.3333333333333333,
#  'Ava': 0.46875,
#  'Clare Danes': 0.2583333333333333,
#  "Jennifer Garner's": 0.15895833333333334,
#  'Vivienne Westwood': 0.2635416666666667,
#  '@AnnTaylor': 0.6125,
#  'Tina Looking': 0.15,
#  'Hopes She': 0.14545454545454545,
#  "Claire Danes'": 0.2971938775510204,
#  'Calvin Klein': 0.15743055555555557,
#  'Michael J. Foxs': 0.3125,
#  'Mine': 1.0,
#  'Selena': 0.21818181818181817,
#  'jennifer lawrence': 0.29444444444444445,
#  'mel gibson': -0.16666666666666666,
#  'Dana Brody': -0.3125,
#  "Zooey Deschanel's": 0.3375,
#  'Evan Longoria': 0.375,
#  'Mel Gib': 0.275,
#  'Helen McCrory': 0.033333333333333326,
#  "Katharine McPhee's": 0.0,
#  "Kelly Osbourne's": -0.5,
#  'jamie': -0.09464285714285714,
#  "Morena Baccarin's": 0.3666666666666667,
#  'Halle Berry Allen': 0.3333333333333333,
#  'Olivia Longoria Allen': 0.3333333333333333,
#  'Saw Claire Danes': 0.24999999999999997,
#  'Angela Chase': 0.24999999999999997,
#  '@SavannahGuthrie You': 0.25,
#  'Holler Homeland': 0.08333333333333334,
#  "Love Anne Hathaway's": 0.3425,
#  'Adele Debuts': 0.125,
#  'ko lang': 0.15,
#  'tinignan e.pati yung blog sa golden': 0.15,
#  'ako ng': 0.15,
#  'Dana': -0.2333333333333333,
#  'kannie': 0.5,
#  '@CELEBUZZ': 0.4479166666666667,
#  'Emily Blunt de @MichaelKors': 0.0,
#  'Megan Fox - Here': 0.020000000000000007,
#  "John Goodman's": 0.0,
#  'Jon': 0.7125,
#  'Jon Bon Jovi': 0.6784722222222223,
#  '@kerrywashington': 0.65,
#  'Givenchy': 0.6,
#  'john goodman': 0.0,
#  'Tony Mendez': 0.30000000000000004,
#  'Guy': 0.25,
#  'RT @RollingOut': 0.15,
#  'John Goodman': 0.10416666666666666,
#  'Betty White': 0.128125,
#  'Ben Afleck': 0.402587890625,
#  'lt;3 John Goodman': 0.0,
#  'jon Bon Jovi': 1.0,
#  'Clooney': 0.0,
#  'Dick Tracy': 0.0,
#  'Jennifer Lopez - Golden': 0.18124999999999997,
#  'Jessica Chastain - Golden': 0.09999999999999999,
#  'Sienna Miller &': 0.2857142857142857,
#  'Jennifer Lopez SEMPRE': 0.0,
#  'hora de escolher': 0.0,
#  'Jennifer': 0.20833333333333331,
#  'JoLo': 0.7,
#  'J-Lo': 0.13639136904761903,
#  'Se fue': 0.0,
#  'como salía': 0.0,
#  'J Lo': 0.20016447368421056,
#  'Jennifer Lopez - WOW': 0.45,
#  "Ben Affleck's": 0.2182291666666667,
#  'Cher': 0.1888888888888889,
#  'Jo Lo': 0.1,
#  'J.lo': 0.2712962962962963,
#  "Jason Statham's": 0.06818181818181818,
#  "J Lo's": 0.6725,
#  'Jenny': 0.3090909090909091,
#  'Lovin': 0.3219534737723214,
#  'Selena Gomez Looks': 0.875,
#  'Dang': 0.35,
#  'Raquel Welch': 0.78125,
#  'Hey J Lo': 0.7,
#  "Scarlett O'Hara": 0.0,
#  "J-Lo's": 0.14641927083333336,
#  'Beyonce': 0.03333333333333333,
#  '@MsLeaMichele': 0.28750000000000003,
#  'God Bless Jennifer Lopez': 0.7,
#  "Jennifer Lopez'": 0.562037037037037,
#  'J.Lo': 0.06666666666666667,
#  'Jay-Lo': 0.0,
#  'Granny': -0.17500000000000002,
#  'Jennifer Anniston': 0.25,
#  'John Williams': 0.0,
#  'Gosshhh Anne': 0.525,
#  'Jennifer Lopez=': -0.07500000000000001,
#  'Makeup Look': 0.26666666666666666,
#  'Cake Boss': 0.0,
#  'RT @Lyfelong': 0.0,
#  'viendo la': 0.15,
#  'abuuuurrrroooo': 0.15,
#  'Michael Danna': 0.0,
#  'Tony Hawk': 0.0,
#  'Rockin': 0.47265625000000006,
#  'Jason Statham': 0.22916666666666666,
#  'Rosie Perez': 0.43125,
#  'Spanx': 0.7,
#  'Elie Saab': 0.21749999999999997,
#  'Ah-ma-zing': 0.42500000000000004,
#  'RT @OKMagazine': 0.42500000000000004,
#  'Bahahahaha RT @MARLONLWAYANS': -0.05,
#  'Parks': 0.14545454545454545,
#  'Ok Eva Longoria': 0.75,
#  'Yoshiki': 0.0,
#  "Jennifer Lopez 's": 0.0,
#  'RT @ETonlineAlert Gleeks': 0.275,
#  'Bob Mackie Barbie': 0.5,
#  'jon bon': 0.8,
#  'Jennifer Looks': 0.6000000000000001,
#  'Klingon': 0.29166666666666663,
#  'Lace': 0.08333333333333334,
#  'Mychael Danna "': 0.6875,
#  'Lasheng': 0.0,
#  'Lols': 0.0,
#  'Mira @JLo': 0.0,
#  'dale chica': 0.0,
#  'Liked Skyfall': -0.125,
#  'Latina': 0.0,
#  'EMILY': 0.06666666666666667,
#  '@rolandsmartin Jennifer': 0.375,
#  'Jennifer Lopez Shows': -0.016666666666666663,
#  'Tay Tay': 0.09999999999999999,
#  'XD': 0.25,
#  'pat': 0.0,
#  'Best Song': 0.5656249999999999,
#  'Statham': 0.0,
#  'Jon Jon': 0.3,
#  'dk': 0.9,
#  'oooooh taylor': -0.4,
#  'ella ganó': 0.0,
#  'su mismo': 0.0,
#  'Greg': 0.25,
#  'Eliza Doolittle': 0.5,
#  'Hubba': 0.0,
#  "Jon Bon Jovi's": 0.6979166666666667,
#  'Woahhhhhh': 0.8,
#  'Jody Foster': 0.4257142857142857,
#  'Twitter': 0.28824404761904765,
#  'Aaarrgghhh': 0.3,
#  "Leonardo DiCaprio's": -0.024999999999999994,
#  'Globes Taylor Swift': 0.0,
#  'Julliane Hough': 0.65,
#  'Claire Danes - Golden': 0.15,
#  'Amy Adams - Golden': 0.15,
#  'Lol Taylor Swift': 0.1875,
#  'Lol You': 0.2,
#  'Idk': 0.5800000000000001,
#  '@GLEEonFOX Lea Michele Is Ethereal': 0.0,
#  'Allison Williams': 0.5753314393939395,
#  'Gave Adele': 0.09999999999999999,
#  'Adele ganhou merecidamente': 0.0,
#  'Ela arrasa': 0.0,
#  'ya adele': 0.390625,
#  'Eddie Redmayne': 0.29017857142857145,
#  'Yay Adele': 0.35000000000000003,
#  'RT Adele Debuts': 0.35000000000000003,
#  'Jennifer Lopez Golden Globes': 0.15,
#  'Moi aussi.': 0.5,
#  'Taylor Swift’s': 0.5,
#  'Harry Styles': -0.7111111111111111,
#  "Marion Cottiard's": 0.28125,
#  'Salma n Eva': 0.25,
#  'Paul Epworth': 0.6875,
#  'lea michele': 0.5,
#  'Adele FTW': 0.346875,
#  'Omg Jessica': 0.5,
#  'Kevin Costner': 0.10402083333333335,
#  'Ohhh Jessica': 0.0,
#  'Jeeeez': 1.0,
#  'Benedict Cumberbatch': 0.21583333333333332,
#  'TIm Gunn': 0.3125,
#  'Johnny': 0.011309523809523806,
#  'RT @LanceUlanoff': -0.6,
#  'Kiefer Sutherland': 0.55,
#  'Michelle Williams': 0.0,
#  'Fuuuuuuuuuuuuuuuuuuuuuuu Y U LOOK SO': 0.875,
#  'jessica albas': 0.5,
#  'Song': 0.496875,
#  'Keifer Sutherland': 0.0,
#  'Bonham Carter': 0.2396825396825397,
#  'J.Lo  ': 0.475,
#  'David Bowie': 0.55,
#  'Damn Johnny': 0.3125,
#  'Terry Allen': 0.39166666666666666,
#  'Lila': 0.0,
#  'Johnny Depp - ha': 0.0,
#  'Lady Gaga': 0.3,
#  'Costner': 0.1,
#  "Kevin Costner's": 0.0,
#  'Louis CK': 0.33333333333333337,
#  'Reality Bites': 0.0,
#  'Hubby': 0.375,
#  'Adele Taylor': 0.1625,
#  'Kiebler': 0.0,
#  'Sharing': 0.5,
#  '@KChenoweth hahaha': 0.15238095238095237,
#  '-GM': -0.225,
#  'Any Polher': 1.0,
#  'Naeem Kahn': 0.5,
#  'Juilianne Hough': 0.5,
#  'Harvey Weinstein': 0.02500000000000001,
#  "Looove JAlba's": 1.0,
#  'kevin costner': 0.875,
#  "Jessica Abla's": 0.9,
#  'Clinton': 0.2939200680272109,
#  'Swift': 0.0,
#  'Bill Clinton': 0.2189483522465859,
#  'Hilary Clinton': 0.2857142857142857,
#  'Bill': 0.47416666666666674,
#  'Darrell Hammond': 0.6000000000000001,
#  'Jennifer Lopez Shows Serious Skin': -0.016666666666666663,
#  'Clint Eastwood': 0.4,
#  'Bubba': 0.3,
#  'Hillary': 0.0,
#  'Willy Clinton': 0.3,
#  'George W': 0.732421875,
#  'Ooooo': 0.25,
#  'Gorgas': 0.0,
#  "Bill Clinton's": 0.0,
#  '@jerrycferrara \nAdele': 0.65,
#  'bill clinton': 0.23068181818181818,
#  'Fitter': 0.2178571428571429,
#  'Billy C. kinda': 0.2,
#  'Lewinsky': 0.0,
#  'Romulan': 0.0,
#  'feliz de que haya': 0.0,
#  'Spielberg': 0.3916666666666666,
#  '@DGJGodwin': 0.45,
#  'spencerbarnesla': 0.5,
#  "Kristen Wig's": 0.175,
#  'Kristin': 0.3070454545454545,
#  'Jamie Foxx': 0.326984126984127,
#  'Samuel Jackson': -0.12222222222222223,
#  'encanta su': 0.0,
#  'Kristen': 0.16597222222222224,
#  "Kristin Wiig's": 0.7875,
#  'kristin wig': -0.7999999999999999,
#  'Golden Globes - Us Magazine': 0.2,
#  'Bruce Willis': -0.04999999999999999,
#  'Anjelica Houston': 0.08749999999999998,
#  'Joker': 0.0,
#  'Eep': -0.25,
#  'Will Farrell': 0.75,
#  'Ron Burgundy': 0.44999999999999996,
#  'muito casual': -0.33333333333333337,
#  'concordo': -0.33333333333333337,
#  'Kristin Wigg': 0.0,
#  'swag': 0.15,
#  'Anjelica': 0.3499999999999999,
#  'A. Houston': 0.0,
#  'Ohhh Mini J. Fox': 0.0,
#  'Marty': 0.0,
#  'Mitt Romney': 0.3,
#  "Kristen Wiig's": -0.07182539682539682,
#  'Colorful Jennifer': 0.18125,
#  'RT @vogueoz\n': 0.16666666666666669,
#  'NOOOOWW': 0.47747395833333334,
#  'Kristen Wig': 0.4145833333333333,
#  'Will Ferrell': 0.2492435515873016,
#  'Diane Keaton': -0.5,
#  'Rona Pfeiffer': 0.0,
#  'Steven Spielberg': 0.3,
#  'Alison Williams': 0.35,
#  'Garth Brooks': 0.5,
#  'Will': -0.5,
#  'Tom Selleck': -0.5,
#  'Emmy Rossum': 0.40735930735930737,
#  'Kristen Wing': 0.8,
#  'Kristen Wigg': 0.3125,
#  'Hollywood Dentists': 0.6166666666666667,
#  'Bahaha': -0.4,
#  "Liked Kristen's": 0.4166666666666667,
#  'Tommy Lee': 0.148046875,
#  ...}

# %%
vote_distribution = list(entities_counts.values())
average_count = sum(vote_distribution)/len(vote_distribution)
fashion_icons = []
for candidate in entities_counts:
    if entities_counts[candidate] >= average_count:
        fashion_icons.append(candidate)
fashion_icons = sorted(fashion_icons, key = lambda e : entities_counts[e] * entities_polarities[e], reverse = True)
for icon in fashion_icons:
    print(icon + ": " + str(entities_polarities[icon]))
print("the top 5 fashion icons were: " + str(fashion_icons[:5]))
print("the top 5 fashion disasters were: " + str(fashion_icons[-5:]))
# Out:
# Amy: 0.3503081101873716
# Tina Fey: 0.39226665923311616
# Kate Hudson: 0.45681283948851964
# Adele: 0.2889705963831391
# Jessica Alba: 0.44595259319673386
# Jennifer Lawrence: 0.2953335634644126
# @msleamichele: 0.563076636904762
# Anne Hathaway: 0.34287831926774615
# Taylor Swift: 0.1893382543087582
# Jodie Foster: 0.27806206833878633
# Jennifer Garner: 0.2833809728949329
# Claire Danes: 0.2951088810179721
# Kerry Washington: 0.4572348451196399
# Jennifer Lopez: 0.27201160309996525
# Ben Affleck: 0.23850413212159854
# Golden Globes: 0.26356770385974276
# Lucy Liu: 0.27377570346320346
# Lucy Liu's: 0.15266545174833218
# Kate Hudson's: 0.2511264810323545
# Jessica Chastain: 0.3209402163643235
# Eva Longoria: 0.40703237734487735
# Julianne Moore: 0.39045493197278924
# Bradley Cooper: 0.3643856837606838
# Lea Michele: 0.23421654929577468
# Kristen Bell: 0.3036638888888889
# Bill Clinton: 0.2189483522465859
# George Clooney: 0.31414007092198576
# Julia Roberts: 0.2925520833333334
# Kerry Washington's: 0.3799251700680272
# Robert Pattinson: 0.4218413978494624
# Leonardo DiCaprio: 0.440330459770115
# Globes: 0.1924162257495591
# Nicole Kidman: 0.29378726287262874
# Lea Michelle: 0.26409837136243386
# Amanda Seyfried: 0.3923106060606061
# Anne Hathaway's: 0.21363510101010108
# @EvaLongoria: 0.5227272727272727
# Megan Fox: 0.22493684895833332
# Kristen Wiig: 0.3849396789965987
# Emily Blunt: 0.39406231628453847
# GORGEOUS: 0.5574074074074074
# Rob: 0.2934698879551821
# Sofia Vergara: 0.3425963275935374
# Julianne Hough: 0.3814814814814815
# Michelle Dockery: 0.6006481481481483
# Salma Hayek: 0.30893787202380957
# Tommy Lee Jones: 0.11037342287342283
# taylor: 0.28041666666666665
# Jlo: 0.19905222505668935
# Halle Berry: 0.12187142255892254
# Yay: 0.38983901515151514
# Jessica Chastain's: 0.21698452818627453
# Nicole Richie: 0.304369212962963
# RT @xosdlc: 0.23827380952380958
# Alexander McQueen: 0.4405145202020202
# Hugh Jackman: 0.38830236892736897
# Lol: 0.5652777777777778
# Oscar Snubs: 0.36768518518518517
# Bill Murray: 0.0801918512658227
# Leo: 0.23979700854700856
# Ann Hathaway: 0.23862179487179486
# @AnnTaylor: 0.6125
# Miranda Kerr: 0.43353174603174605
# Jodi Foster: 0.4022879464285714
# Jessica Alba's: 0.4583333333333333
# Jon Hamm: 0.3896362433862434
# Ariel Winter: 0.3330357142857143
# Catherine Zeta-Jones': 0.33245287698412695
# Jennifer Lawrence's: 0.19928951257076255
# Jennifer Lopez's: 0.24627976190476192
# Selena Gomez: 0.4616907713498622
# Daniel Craig: 0.4547727272727272
# Kristin Wiig: 0.20796085858585858
# Zooey Deschanel: 0.12160569105691058
# @Burberry: 0.14636437908496733
# Marion Cotillard: 0.28396012050653596
# Glad: 0.5901041666666667
# Sally Field: 0.33615019240019245
# Benedict: 0.1538095238095238
# Allison Williams: 0.5753314393939395
# Eva Longoria - Golden: 0.28763020833333336
# Cohen: 0.45999999999999996
# Jamie Foxx: 0.326984126984127
# Robert Downey Jr.: 0.23313795853269537
# Lena Dunham: 0.06904143475572046
# Jody Foster: 0.4257142857142857
# Hayden Panettiere: 0.2831944444444444
# Claire Danes': 0.2971938775510204
# Jen: 0.41125000000000006
# Helen Mirren: 0.36868686868686873
# Michael J. Fox': 0.22199074074074074
# Julianne Moore Golden: 0.26138888888888884
# Miu Miu: 0.47812499999999997
# J Lo: 0.20016447368421056
# Orlando Bloom: 0.42170138888888886
# Makeup: 0.4677083333333333
# Eva Longoria's: 0.22778087797619048
# Tom Ford: 0.19047880116959068
# @CELEBUZZ: 0.4479166666666667
# Stun: 0.1673520923520924
# Daniel Day-Lewis: 0.31251991349037245
# Robert Downey Jr: 0.34375
# Helen Hunt: 0.27621527777777777
# J. Lo: 0.29772727272727273
# Julianna: 0.26805555555555555
# Kelly Osbourne: 0.22857142857142856
# Selma Hayek: 0.3175
# Jessica Lange: 0.17571097883597886
# Will Ferrell: 0.2492435515873016
# Christoph Waltz: 0.29666666666666663
# Jason Statham: 0.22916666666666666
# J-Lo: 0.13639136904761903
# Arnold: 0.12372835497835499
# Kevin Costner: 0.10402083333333335
# Catherine Zeta Jones: 0.228030303030303
# Jenny: 0.3090909090909091
# Heidi Klum: 0.26962962962962966
# Tommy Lee Jones Looks: 0.3009375
# Grumpy Cat: 0.3009375
# Photo Gallery - Yahoo: 0.1833333333333333
# lucy liu's: 0.23125
# Twitter: 0.28824404761904765
# Jeremy Irons: 0.10556500377928951
# Elie Saab: 0.21749999999999997
# Jeremy Renner: 0.19157196969696966
# Debra Messing: 0.20875
# Burberry: 0.17361111111111113
# Barbara: 0.24375000000000002
# Gucci: 0.23571428571428574
# @cocoperez: 0.23333333333333334
# Julianne Hough's: 0.16464646464646468
# Julianne Moore's: 0.17301136363636366
# Helena Bonham Carter: 0.16874999999999998
# Michael J. Fox's: 0.06674107142857143
# Liza Minelli LOL: 0.125
# Dennis Quaid: 0.10277777777777779
# Hugh Dancy - Golden: 0.13333333333333336
# Meryl Streep: 0.15
# Jonah Hill: 0.11875
# Joan Rivers: 0.14791666666666667
# J-Lo's: 0.14641927083333336
# Jesus: 0.06358024691358026
# Hallie Berry: 0.1242691798941799
# Sienna Miller Golden Globes: 0.10958333333333334
# Sam Fox: 0.08365384615384615
# Rosario Dawson: 0.07322781385281384
# Don Cheadle: 0.09091269841269842
# Quentin Tarantino: 0.04784461152882206
# Halle Betty's: 0.06923076923076922
# Paul Rudd: 0.045039682539682525
# Sylvester Stallone: 0.03236438041125542
# Michael J Fox's: 0.058029513888888884
# Michael J. Fox: 0.0869047619047619
# Eva Longoria Stuns: 0.06666666666666667
# Revealing Gown: 0.06666666666666667
# Versace: 0.04666666666666667
# Que: 0.018750000000000003
# Ang Lee: 0.024999999999999998
# J. Lo's: 0.019675925925925944
# Dustin Hoffman: 0.01747222222222222
# Johnny: 0.011309523809523806
# Al Roker: -0.0033333333333333353
# Yuck: -0.122
# Halle Berry's: -0.11035466269841265
# Brody: -0.2265625
# Sienna Miller: -0.11729870129870129
# Mel Gibson: -0.0827557882014308
# Glenn Close: -0.22359453837076823
# the top 5 fashion icons were: ['Amy', 'Tina Fey', 'Kate Hudson', 'Adele', 'Jessica Alba']
# the top 5 fashion disasters were: ["Halle Berry's", 'Brody', 'Sienna Miller', 'Mel Gibson', 'Glenn Close']
